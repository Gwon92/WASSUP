# %%
import requests, json, pandas as pd

# %%
URL ='http://www.krei.re.kr:18181/chart/main_chart/index/kind/W/sdate/2019-01-01/edate/2019-12-31'
resp = requests.get(URL)

# %%
resp
# Out:
# <Response [200]>

# %%
data1 = resp.text
print(type(data1), len(data1))
print(data1)
# Out:
# <class 'str'> 37824
# [{"id":"41596","date":"20190102","symbol":null,"open":"184.63","close":"186.29","high":"187.67","low":"184.17","settlement":"186.2","volume":"91835"},{"id":"41597","date":"20190103","symbol":null,"open":"186.2","close":"188.77","high":"189.59","low":"185.92","settlement":"188.77","volume":"78995"},{"id":"41603","date":"20190104","symbol":null,"open":"188.77","close":"189.59","high":"190.6","low":"188.49","settlement":"189.96","volume":"70816"},{"id":"41609","date":"20190107","symbol":null,"open":"190.33","close":"189.78","high":"190.51","low":"188.68","settlement":"189.87","volume":"68009"},{"id":"41610","date":"20190108","symbol":null,"open":"189.78","close":"190.79","high":"192.72","low":"188.77","settlement":"190.24","volume":"118268"},{"id":"41617","date":"20190109","symbol":null,"open":"190.97","close":"190.88","high":"192.44","low":"190.42","settlement":"191.06","volume":"87637"},{"id":"41624","date":"20190110","symbol":null,"open":"190.88","close":"188.77","high":"191.16","low":"188.12","settlement":"188.77","volume":"85133"},{"id":"41625","date":"20190111","symbol":null,"open":"188.77","close":"190.97","high":"192.44","low":"188.4","settlement":"190.88","volume":"109574"},{"id":"41626","date":"20190114","symbol":null,"open":"191.06","close":"189.14","high":"192.35","low":"188.58","settlement":"188.95","volume":"79482"},{"id":"41631","date":"20190115","symbol":null,"open":"189.14","close":"187.94","high":"190.42","low":"186.65","settlement":"187.76","volume":"83823"},{"id":"41635","date":"20190116","symbol":null,"open":"187.76","close":"187.94","high":"189.87","low":"187.76","settlement":"188.31","volume":"70772"},{"id":"41639","date":"20190117","symbol":null,"open":"187.94","close":"190.24","high":"191.98","low":"187.02","settlement":"190.24","volume":"93805"},{"id":"41643","date":"20190118","symbol":null,"open":"190.97","close":"190.15","high":"192.07","low":"189.32","settlement":"190.24","volume":"79155"},{"id":"41647","date":"20190122","symbol":null,"open":"190.33","close":"191.52","high":"193.27","low":"188.95","settlement":"191.52","volume":"107526"},{"id":"41651","date":"20190123","symbol":null,"open":"191.98","close":"193.45","high":"193.64","low":"191.71","settlement":"193.27","volume":"70276"},{"id":"41655","date":"20190124","symbol":null,"open":"193.64","close":"191.43","high":"194.37","low":"191.43","settlement":"191.62","volume":"80757"},{"id":"41659","date":"20190125","symbol":null,"open":"191.25","close":"191.43","high":"192.17","low":"189.87","settlement":"191.06","volume":"86152"},{"id":"41662","date":"20190128","symbol":null,"open":"191.34","close":"190.51","high":"192.35","low":"189.59","settlement":"190.6","volume":"76387"},{"id":"41667","date":"20190129","symbol":null,"open":"190.24","close":"189.14","high":"191.8","low":"187.67","settlement":"188.58","volume":"110959"},{"id":"41671","date":"20190130","symbol":null,"open":"188.58","close":"190.15","high":"190.33","low":"188.03","settlement":"189.87","volume":"70046"},{"id":"41675","date":"20190131","symbol":null,"open":"190.24","close
settlement': '190.24', 'volume': '79155'}, {'id': '41647', 'date': '20190122', 'symbol': None, 'open': '190.33', 'close': '191.52', 'high': '193.27', 'low': '188.95', 'settlement': '191.52', 'volume': '107526'}, {'id': '41651', 'date': '20190123', 'symbol': None, 'open': '191.98', 'close': '193.45', 'high': '193.64', 'low': '191.71', 'settlement': '193.27', 'volume': '70276'}, {'id': '41655', 'date': '20190124', 'symbol': None, 'open': '193.64', 'close': '191.43', 'high': '194.37', 'low': '191.43', 'settlement': '191.62', 'volume': '80757'}, {'id': '41659', 'date': '20190125', 'symbol': None, 'open': '191.25', 'close': '191.43', 'high': '192.17', 'low': '189.87', 'settlement': '191.06', 'volume': '86152'}, {'id': '41662', 'date': '20190128', 'symbol': None, 'open': '191.34', 'close': '190.51', 'high': '192.35', 'low': '189.59', 'settlement': '190.6', 'volume': '76387'}, {'id': '41667', 'date': '20190129', 'symbol': None, 'open': '190.24', 'close': '189.14', 'high': '191.8', 'low': '187.67', 'settlement': '188.58', 'volume': '110959'}, {'id': '41671', 'date': '20190130', 'symbol': None, 'open': '188.58', 'close': '190.15', 'high': '190.33', 'low': '188.03', 'settlement': '189.87', 'volume': '70046'}, {'id': '41675', 'date': '20190131', 'symbol': None, 'open': '190.24', 'close': '189.78', 'high': '191.06', 'low': '188.68', 'settlement': '189.78', 'volume': '89614'}, {'id': '41679', 'date': '20190201', 'symbol': None, 'open': '189.5', 'close': '192.72', 'high': '193.45', 'low': '189.32', 'settlement': '192.63', 'volume': '142005'}, {'id': '41683', 'date': '20190204', 'symbol': None, 'open': '192.81', 'close': '192.99', 'high': '194.37', 'low': '191.52', 'settlement': '193.18', 'volume': '142681'}, {'id': '41687', 'date': '20190205', 'symbol': None, 'open': '192.99', 'close': '193.64', 'high': '194.1', 'low': '191.25', 'settlement': ...

# %%
data2
# Out:
# [{'id': '41596',
#   'date': '20190102',
#   'symbol': None,
#   'open': '184.63',
#   'close': '186.29',
#   'high': '187.67',
#   'low': '184.17',
#   'settlement': '186.2',
#   'volume': '91835'},
#  {'id': '41597',
#   'date': '20190103',
#   'symbol': None,
#   'open': '186.2',
#   'close': '188.77',
#   'high': '189.59',
#   'low': '185.92',
#   'settlement': '188.77',
#   'volume': '78995'},
#  {'id': '41603',
#   'date': '20190104',
#   'symbol': None,
#   'open': '188.77',
#   'close': '189.59',
#   'high': '190.6',
#   'low': '188.49',
#   'settlement': '189.96',
#   'volume': '70816'},
#  {'id': '41609',
#   'date': '20190107',
#   'symbol': None,
#   'open': '190.33',
#   'close': '189.78',
#   'high': '190.51',
#   'low': '188.68',
#   'settlement': '189.87',
#   'volume': '68009'},
#  {'id': '41610',
#   'date': '20190108',
#   'symbol': None,
#   'open': '189.78',
#   'close': '190.79',
#   'high': '192.72',
#   'low': '188.77',
#   'settlement': '190.24',
#   'volume': '118268'},
#  {'id': '41617',
#   'date': '20190109',
#   'symbol': None,
#   'open': '190.97',
#   'close': '190.88',
#   'high': '192.44',
#   'low': '190.42',
#   'settlement': '191.06',
#   'volume': '87637'},
#  {'id': '41624',
#   'date': '20190110',
#   'symbol': None,
#   'open': '190.88',
#   'close': '188.77',
#   'high': '191.16',
#   'low': '188.12',
#   'settlement': '188.77',
#   'volume': '85133'},
#  {'id': '41625',
#   'date': '20190111',
#   'symbol': None,
#   'open': '188.77',
#   'close': '190.97',
#   'high': '192.44',
#   'low': '188.4',
#   'settlement': '190.88',
#   'volume': '109574'},
#  {'id': '41626',
#   'date': '20190114',
#   'symbol': None,
#   'open': '191.06',
#   'close': '189.14',
#   'high': '192.35',
#   'low': '188.58',
#   'settlement': '188.95',
#   'volume': '79482'},
#  {'id': '41631',
#   'date': '20190115',
#   'symbol': None,
#   'open': '189.14',
#   'close': '187.94',
#   'high': '190.42',
#   'low': '186.65',
#   'settlement': '187.76',
#   'volume': '83823'},
#  {'id': '41635',
#   'date': '20190116',
#   'symbol': None,
#   'open': '187.76',
#   'close': '187.94',
#   'high': '189.87',
#   'low': '187.76',
#   'settlement': '188.31',
#   'volume': '70772'},
#  {'id': '41639',
#   'date': '20190117',
#   'symbol': None,
#   'open': '187.94',
#   'close': '190.24',
#   'high': '191.98',
#   'low': '187.02',
#   'settlement': '190.24',
#   'volume': '93805'},
#  {'id': '41643',
#   'date': '20190118',
#   'symbol': None,
#   'open': '190.97',
#   'close': '190.15',
#   'high': '192.07',
#   'low': '189.32',
#   'settlement': '190.24',
#   'volume': '79155'},
#  {'id': '41647',
#   'date': '20190122',
#   'symbol': None,
#   'open': '190.33',
#   'close': '191.52',
#   'high': '193.27',
#   'low': '188.95',
#   'settlement': '191.52',
#   'volume': '107526'},
#  {'id': '41651',
#   'date': '20190123',
#   'symbol': None,
#   'open': '191.98',
#   'close': '193.45',
#   'high': '193.64',
#   'low': '191.71',
#   'settlement': '193.27',
#   'volume': '70276'},
#  {'id': '41655',
#   'date': '20190124',
#   'symbol': None,
#   'open': '193.64',
#   'close': '191.43',
#   'high': '194.37',
#   'low': '191.43',
#   'settlement': '191.62',
#   'volume': '80757'},
#  {'id': '41659',
#   'date': '20190125',
#   'symbol': None,
#   'open': '191.25',
#   'close': '191.43',
#   'high': '192.17',
#   'low': '189.87',
#   'settlement': '191.06',
#   'volume': '86152'},
#  {'id': '41662',
#   'date': '20190128',
#   'symbol': None,
#   'open': '191.34',
#   'close': '190.51',
#   'high': '192.35',
#   'low': '189.59',
#   'settlement': '190.6',
#   'volume': '76387'},
#  {'id': '41667',
#   'date': '20190129',
#   'symbol': None,
#   'open': '190.24',
#   'close': '189.14',
#   'high': '191.8',
#   'low': '187.67',
#   'settlement': '188.58',
#   'volume': '110959'},
#  {'id': '41671',
#   'date': '20190130',
#   'symbol': None,
#   'open': '188.58',
#   'close': '190.15',
#   'high': '190.33',
#   'low': '188.03',
#   'settlement': '189.87',
#   'volume': '70046'},
#  {'id': '41675',
#   'date': '20190131',
#   'symbol': None,
#   'open': '190.24',
#   'close': '189.78',
#   'high': '191.06',
#   'low': '188.68',
#   'settlement': '189.78',
#   'volume': '89614'},
#  {'id': '41679',
#   'date': '20190201',
#   'symbol': None,
#   'open': '189.5',
#   'close': '192.72',
#   'high': '193.45',
#   'low': '189.32',
#   'settlement': '192.63',
#   'volume': '142005'},
#  {'id': '41683',
#   'date': '20190204',
#   'symbol': None,
#   'open': '192.81',
#   'close': '192.99',
#   'high': '194.37',
#   'low': '191.52',
#   'settlement': '193.18',
#   'volume': '142681'},
#  {'id': '41687',
#   'date': '20190205',
#   'symbol': None,
#   'open': '192.99',
#   'close': '193.64',
#   'high': '194.1',
#   'low': '191.25',
#   'settlement': '193.73',
#   'volume': '143716'},
#  {'id': '41691',
#   'date': '20190206',
#   'symbol': None,
#   'open': '193.64',
#   'close': '193.27',
#   'high': '195.2',
#   'low': '192.63',
#   'settlement': '193.27',
#   'volume': '139816'},
#  {'id': '41695',
#   'date': '20190207',
#   'symbol': None,
#   'open': '192.99',
#   'close': '189.14',
#   'high': '192.99',
#   'low': '188.31',
#   'settlement': '188.58',
#   'volume': '203091'},
#  {'id': '41699',
#   'date': '20190208',
#   'symbol': None,
#   'open': '189.14',
#   'close': '190.33',
#   'high': '191.89',
#   'low': '188.68',
#   'settlement': '190.05',
#   'volume': '210179'},
#  {'id': '41703',
#   'date': '20190211',
#   'symbol': None,
#   'open': '190.05',
#   'close': '190.42',
#   'high': '190.7',
#   'low': '188.12',
#   'settlement': '190.42',
#   'volume': '164571'},
#  {'id': '41707',
#   'date': '20190212',
#   'symbol': None,
#   'open': '190.51',
#   'close': '191.06',
#   'high': '191.34',
#   'low': '189.04',
#   'settlement': '191.06',
#   'volume': '172425'},
#  {'id': '41711',
#   'date': '20190213',
#   'symbol': None,
#   'open': '190.97',
#   'close': '191.62',
#   'high': '192.53',
#   'low': '190.6',
#   'settlement': '191.89',
#   'volume': '163435'},
#  {'id': '41715',
#   'date': '20190214',
#   'symbol': None,
#   'open': '191.62',
#   'close': '186.38',
#   'high': '191.98',
#   'low': '185.92',
#   'settlement': '186.29',
#   'volume': '215486'},
#  {'id': '41719',
#   'date': '20190215',
#   'symbol': None,
#   'open': '186.56',
#   'close': '184.91',
#   'high': '186.93',
#   'low': '183.44',
#   'settlement': '185.28',
#   'volume': '188274'},
#  {'id': '41723',
#   'date': '20190219',
#   'symbol': None,
#   'open': '184.63',
#   'close': '180.13',
#   'high': '185.64',
#   'low': '179.49',
#   'settlement': '179.95',
#   'volume': '191117'},
#  {'id': '41727',
#   'date': '20190220',
#   'symbol': None,
#   'open': '180.04',
#   'close': '176.27',
#   'high': '181.33',
#   'low': '174.81',
#   'settlement': '176.64',
#   'volume': '239765'},
#  {'id': '41731',
#   'date': '20190221',
#   'symbol': None,
#   'open': '176.55',
#   'close': '178.94',
#   'high': '180.59',
#   'low': '176.46',
#   'settlement': '178.76',
#   'volume': '169530'},
#  {'id': '41735',
#   'date': '20190222',
#   'symbol': None,
#   'open': '179.49',
#   'close': '178.85',
#   'high': '181.14',
#   'low': '178.02',
#   'settlement': '178.85',
#   'volume': '142235'},
#  {'id': '41739',
#   'date': '20190225',
#   'symbol': None,
#   'open': '179.95',
#   'close': '171.31',
#   'high': '180.04',
#   'low': '171.31',
#   'settlement': '171.5',
#   'volume': '208986'},
#  {'id': '41743',
#   'date': '20190226',
#   'symbol': None,
#   'open': '171.59',
#   'close': '169.11',
#   'high': '171.96',
#   'low': '167.64',
#   'settlement': '169.11',
#   'volume': '184086'},
#  {'id': '41747',
#   'date': '20190227',
#   'symbol': None,
#   'open': '169.11',
#   'close': '168.83',
#   'high': '171.87',
#   'low': '168.38',
#   'settlement': '169.39',
#   'volume': '105743'},
#  {'id': '41751',
#   'date': '20190228',
#   'symbol': None,
#   'open': '171.96',
#   'close': '168.65',
#   'high': '172.23',
#   'low': '168.19',
#   'settlement': '168.83',
#   'volume': '109120'},
#  {'id': '41755',
#   'date': '20190301',
#   'symbol': None,
#   'open': '168.83',
#   'close': '168.01',
#   'high': '169.48',
#   'low': '164.33',
#   'settlement': '168.01',
#   'volume': '164169'},
#  {'id': '41759',
#   'date': '20190304',
#   'symbol': None,
#   'open': '168.01',
#   'close': '167.92',
#   'high': '169.48',
#   'low': '166.91',
#   'settlement': '167.36',
#   'volume': '101184'},
#  {'id': '41763',
#   'date': '20190305',
#   'symbol': None,
#   'open': '167.92',
#   'close': '170.12',
#   'high': '170.49',
#   'low': '166.45',
#   'settlement': '170.03',
#   'volume': '91553'},
#  {'id': '41767',
#   'date': '20190306',
#   'symbol': None,
#   'open': '170.58',
#   'close': '165.25',
#   'high': '170.58',
#   'low': '165.07',
#   'settlement': '165.34',
#   'volume': '99039'},
#  {'id': '41771',
#   'date': '20190307',
#   'symbol': None,
#   'open': '165.62',
#   'close': '161.03',
#   'high': '165.99',
#   'low': '160.75',
#   'settlement': '161.03',
#   'volume': '143114'},
#  {'id': '41775',
#   'date': '20190308',
#   'symbol': None,
#   'open': '160.93',
#   'close': '161.12',
#   'high': '163.23',
#   'low': '159.56',
#   'settlement': '161.49',
#   'volume': '133612'},
#  {'id': '41779',
#   'date': '20190311',
#   'symbol': None,
#   'open': '161.49',
#   'close': '157.54',
#   'high': '162.31',
#   'low': '156.89',
#   'settlement': '157.44',
#   'volume': '130712'},
#  {'id': '41783',
#   'date': '20190312',
#   'symbol': None,
#   'open': '157.44',
#   'close': '167.18',
#   'high': '167.92',
#   'low': '157.08',
#   'settlement': '166.45',
#   'volume': '202514'},
#  {'id': '41787',
#   'date': '20190313',
#   'symbol': None,
#   'open': '166.81',
#   'close': '164.43',
#   'high': '167.55',
#   'low': '161.76',
#   'settlement': '164.33',
#   'volume': '139481'},
#  {'id': '41791',
#   'date': '20190314',
#   'symbol': None,
#   'open': '164.33',
#   'close': '166.54',
#   'high': '169.29',
#   'low': '164.24',
#   'settlement': '166.35',
#   'volume': '79820'},
#  {'id': '41795',
#   'date': '20190315',
#   'symbol': None,
#   'open': '166.26',
#   'close': '169.11',
#   'high': '170.12',
#   'low': '164.79',
#   'settlement': '169.84',
#   'volume': '110990'},
#  {'id': '41799',
#   'date': '20190318',
#   'symbol': None,
#   'open': '170.21',
#   'close': '167.92',
#   'high': '170.49',
#   'low': '167',
#   'settlement': '167.82',
#   'volume': '87536'},
#  {'id': '41803',
#   'date': '20190319',
#   'symbol': None,
#   'open': '168.47',
#   'close': '167.73',
#   'high': '169.94',
#   'low': '166.72',
#   'settlement': '167.73',
#   'volume': '85047'},
#  {'id': '41807',
#   'date': '20190320',
#   'symbol': None,
#   'open': '167.82',
#   'close': '170.76',
#   'high': '170.86',
#   'low': '167.09',
#   'settlement': '170.76',
#   'volume': '90449'},
#  {'id': '41811',
#   'date': '20190321',
#   'symbol': None,
#   'open': '170.67',
#   'close': '171.31',
#   'high': '171.77',
#   'low': '168.28',
#   'settlement': '171.41',
#   'volume': '93571'},
#  {'id': '41815',
#   'date': '20190322',
#   'symbol': None,
#   'open': '171.04',
#   'close': '170.86',
#   'high': '174.07',
#   'low': '170.4',
#   'settlement': '171.22',
#   'volume': '110930'},
#  {'id': '41819',
#   'date': '20190325',
#   'symbol': None,
#   'open': '171.41',
#   'close': '172.23',
#   'high': '173.34',
#   'low': '170.12',
#   'settlement': '172.51',
#   'volume': '90183'},
#  {'id': '41823',
#   'date': '20190326',
#   'symbol': None,
#   'open': '172.69',
#   'close': '172.6',
#   'high': '175.63',
#   'low': '171.59',
#   'settlement': '172.42',
#   'volume': '144859'},
#  {'id': '41827',
#   'date': '20190327',
#   'symbol': None,
#   'open': '172.69',
#   'close': '172.51',
#   'high': '173.34',
#   'low': '171.41',
#   'settlement': '172.51',
#   'volume': '98569'},
#  {'id': '41831',
#   'date': '20190328',
#   'symbol': None,
#   'open': '172.14',
#   'close': '170.4',
#   'high': '172.42',
#   'low': '168.83',
#   'settlement': '170.67',
#   'volume': '79565'},
#  {'id': '41835',
#   'date': '20190329',
#   'symbol': None,
#   'open': '170.4',
#   'close': '168.74',
#   'high': '170.76',
#   'low': '166.26',
#   'settlement': '168.19',
#   'volume': '134239'},
#  {'id': '41839',
#   'date': '20190401',
#   'symbol': None,
#   'open': '168.83',
#   'close': '170.03',
#   'high': '172.05',
#   'low': '167.55',
#   'settlement': '170.03',
#   'volume': '115149'},
#  {'id': '41843',
#   'date': '20190402',
#   'symbol': None,
#   'open': '170.3',
#   'close': '170.49',
#   'high': '171.13',
#   'low': '167.55',
#   'settlement': '170.49',
#   'volume': '90738'},
#  {'id': '41847',
#   'date': '20190403',
#   'symbol': None,
#   'open': '170.12',
#   'close': '172.88',
#   'high': '173.7',
#   'low': '170.12',
#   'settlement': '173.06',
#   'volume': '115240'},
#  {'id': '41851',
#   'date': '20190404',
#   'symbol': None,
#   'open': '173.06',
#   'close': '172.97',
#   'high': '175.45',
#   'low': '171.96',
#   'settlement': '172.97',
#   'volume': '123153'},
#  {'id': '41855',
#   'date': '20190405',
#   'symbol': None,
#   'open': '172.33',
#   'close': '171.87',
#   'high': '172.51',
#   'low': '170.58',
#   'settlement': '171.87',
#   'volume': '154717'},
#  {'id': '41859',
#   'date': '20190408',
#   'symbol': None,
#   'open': '171.68',
#   'close': '167.73',
#   'high': '173.06',
#   'low': '169.66',
#   'settlement': '170.95',
#   'volume': '160367'},
#  {'id': '41863',
#   'date': '20190409',
#   'symbol': None,
#   'open': '169.75',
#   'close': '168.83',
#   'high': '169.94',
#   'low': '167.64',
#   'settlement': '168.83',
#   'volume': '165491'},
#  {'id': '41867',
#   'date': '20190410',
#   'symbol': None,
#   'open': '168.65',
#   'close': '168.19',
#   'high': '169.66',
#   'low': '167.36',
#   'settlement': '168.28',
#   'volume': '128791'},
#  {'id': '41871',
#   'date': '20190411',
#   'symbol': None,
#   'open': '167.92',
#   'close': '169.66',
#   'high': '169.94',
#   'low': '167.82',
#   'settlement': '169.2',
#   'volume': '167790'},
#  {'id': '41875',
#   'date': '20190412',
#   'symbol': None,
#   'open': '169.75',
#   'close': '170.67',
#   'high': '170.95',
#   'low': '168.1',
#   'settlement': '170.67',
#   'volume': '136038'},
#  {'id': '41879',
#   'date': '20190415',
#   'symbol': None,
#   'open': '170.4',
#   'close': '169.75',
#   'high': '170.49',
#   'low': '168.19',
#   'settlement': '168.83',
#   'volume': '184103'},
#  {'id': '41883',
#   'date': '20190416',
#   'symbol': None,
#   'open': '168.56',
#   'close': '163.51',
#   'high': '169.11',
#   'low': '162.5',
#   'settlement': '163.51',
#   'volume': '216028'},
#  {'id': '41887',
#   'date': '20190417',
#   'symbol': None,
#   'open': '164.06',
#   'close': '164.43',
#   'high': '165.34',
#   'low': '163.41',
#   'settlement': '164.24',
#   'volume': '142549'},
#  {'id': '41891',
#   'date': '20190418',
#   'symbol': None,
#   'open': '164.33',
#   'close': '163.69',
#   'high': '164.7',
#   'low': '161.39',
#   'settlement': '163.23',
#   'volume': '134057'},
#  {'id': '41895',
#   'date': '20190422',
#   'symbol': None,
#   'open': '163.23',
#   'close': '160.48',
#   'high': '163.23',
#   'low': '159.92',
#   'settlement': '160.11',
#   'volume': '121735'},
#  {'id': '41899',
#   'date': '20190423',
#   'symbol': None,
#   'open': '159.92',
#   'close': '160.84',
#   'high': '162.13',
#   'low': '159.1',
#   'settlement': '161.21',
#   'volume': '152463'},
#  {'id': '41903',
#   'date': '20190424',
#   'symbol': None,
#   'open': '160.93',
#   'close': '158.55',
#   'high': '161.49',
#   'low': '157.9',
#   'settlement': '158.82',
#   'volume': '128076'},
#  {'id': '41906',
#   'date': '20190425',
#   'symbol': None,
#   'open': '160.48',
#   'close': '161.85',
#   'high': '162.96',
#   'low': '159.65',
#   'settlement': '162.22',
#   'volume': '121831'},
#  {'id': '41911',
#   'date': '20190426',
#   'symbol': None,
#   'open': '161.58',
#   'close': '162.77',
#   'high': '163.78',
#   'low': '161.49',
#   'settlement': '162.59',
#   'volume': '101725'},
#  {'id': '41915',
#   'date': '20190429',
#   'symbol': None,
#   'open': '162.86',
#   'close': '159.83',
#   'high': '164.15',
#   'low': '159.37',
#   'settlement': '159.92',
#   'volume': '128808'},
#  {'id': '41921',
#   'date': '20190430',
#   'symbol': None,
#   'open': '159.56',
#   'close': '157.81',
#   'high': '160.02',
#   'low': '156.53',
#   'settlement': '157.54',
#   'volume': '115710'},
#  {'id': '41922',
#   'date': '20190501',
#   'symbol': None,
#   'open': '157.26',
#   'close': '160.38',
#   'high': '160.84',
#   'low': '157.17',
#   'settlement': '160.2',
#   'volume': '103620'},
#  {'id': '41927',
#   'date': '20190502',
#   'symbol': None,
#   'open': '160.48',
#   'close': '163.51',
#   'high': '164.79',
#   'low': '160.02',
#   'settlement': '163.14',
#   'volume': '104415'},
#  {'id': '41931',
#   'date': '20190503',
#   'symbol': None,
#   'open': '163.51',
#   'close': '160.75',
#   'high': '164.61',
#   'low': '160.2',
#   'settlement': '160.93',
#   'volume': '74065'},
#  {'id': '41935',
#   'date': '20190506',
#   'symbol': None,
#   'open': '158',
#   'close': '160.84',
#   'high': '161.49',
#   'low': '157.26',
#   'settlement': '160.66',
#   'volume': '69046'},
#  {'id': '41939',
#   'date': '20190507',
#   'symbol': None,
#   'open': '160.38',
#   'close': '161.85',
#   'high': '162.5',
#   'low': '158.45',
#   'settlement': '161.49',
#   'volume': '103235'},
#  {'id': '41943',
#   'date': '20190508',
#   'symbol': None,
#   'open': '161.76',
#   'close': '160.84',
#   'high': '162.96',
#   'low': '159.65',
#   'settlement': '161.3',
#   'volume': '93146'},
#  {'id': '41947',
#   'date': '20190509',
#   'symbol': None,
#   'open': '160.84',
#   'close': '157.81',
#   'high': '160.93',
#   'low': '157.26',
#   'settlement': '157.81',
#   'volume': '91878'},
#  {'id': '41951',
#   'date': '20190510',
#   'symbol': None,
#   'open': '158.73',
#   'close': '155.97',
#   'high': '159.56',
#   'low': '154.87',
#   'settlement': '156.07',
#   'volume': '117488'},
#  {'id': '41955',
#   'date': '20190513',
#   'symbol': None,
#   'open': '156.34',
#   'close': '160.2',
#   'high': '161.95',
#   'low': '153.77',
#   'settlement': '160.57',
#   'volume': '125818'},
#  {'id': '41959',
#   'date': '20190514',
#   'symbol': None,
#   'open': '162.13',
#   'close': '164.79',
#   'high': '165.62',
#   'low': '160.93',
#   'settlement': '164.79',
#   'volume': '104647'},
#  {'id': '41963',
#   'date': '20190515',
#   'symbol': None,
#   'open': '165.9',
#   'close': '164.61',
#   'high': '170.49',
#   'low': '164.24',
#   'settlement': '164.88',
#   'volume': '142008'},
#  {'id': '41967',
#   'date': '20190516',
#   'symbol': None,
#   'open': '163.97',
#   'close': '171.87',
#   'high': '172.14',
#   'low': '163.97',
#   'settlement': '171.59',
#   'volume': '109320'},
#  {'id': '41971',
#   'date': '20190517',
#   'symbol': None,
#   'open': '172.33',
#   'close': '170.12',
#   'high': '173.89',
#   'low': '169.94',
#   'settlement': '170.86',
#   'volume': '121717'},
#  {'id': '41975',
#   'date': '20190520',
#   'symbol': None,
#   'open': '172.6',
#   'close': '176.37',
#   'high': '177.84',
#   'low': '171.96',
#   'settlement': '175.72',
#   'volume': '134368'},
#  {'id': '41979',
#   'date': '20190521',
#   'symbol': None,
#   'open': '178.66',
#   'close': '174.9',
#   'high': '181.05',
#   'low': '174.16',
#   'settlement': '175.91',
#   'volume': '168323'},
#  {'id': '41983',
#   'date': '20190522',
#   'symbol': None,
#   'open': '174.81',
#   'close': '174.07',
#   'high': '176.73',
#   'low': '172.14',
#   'settlement': '173.7',
#   'volume': '103759'},
#  {'id': '41987',
#   'date': '20190523',
#   'symbol': None,
#   'open': '173.79',
#   'close': '172.42',
#   'high': '178.39',
#   'low': '171.31',
#   'settlement': '172.78',
#   'volume': '124571'},
#  {'id': '41991',
#   'date': '20190524',
#   'symbol': None,
#   'open': '172.6',
#   'close': '180.13',
#   'high': '180.32',
#   'low': '171.68',
#   'settlement': '179.86',
#   'volume': '117529'},
#  {'id': '41995',
#   'date': '20190528',
#   'symbol': None,
#   'open': '181.88',
#   'close': '185.19',
#   'high': '187.11',
#   'low': '181.69',
#   'settlement': '185.46',
#   'volume': '179950'},
#  {'id': '41999',
#   'date': '20190529',
#   'symbol': None,
#   'open': '189.23',
#   'close': '180.22',
#   'high': '191.71',
#   'low': '179.12',
#   'settlement': '180.22',
#   'volume': '203058'},
#  {'id': '42003',
#   'date': '20190530',
#   'symbol': None,
#   'open': '189.23',
#   'close': '188.86',
#   'high': '189.23',
#   'low': '177.1',
#   'settlement': '189.04',
#   'volume': '183633'},
#  {'id': '42007',
#   'date': '20190531',
#   'symbol': None,
#   'open': '189.04',
#   'close': '185.83',
#   'high': '191.06',
#   'low': '183.99',
#   'settlement': '184.82',
#   'volume': '184556'},
#  {'id': '42011',
#   'date': '20190603',
#   'symbol': None,
#   'open': '185.83',
#   'close': '191.06',
#   'high': '192.07',
#   'low': '184.82',
#   'settlement': '190.97',
#   'volume': '149282'},
#  {'id': '42015',
#   'date': '20190604',
#   'symbol': None,
#   'open': '193.27',
#   'close': '185.74',
#   'high': '194.37',
#   'low': '184.17',
#   'settlement': '186.38',
#   'volume': '211513'},
#  {'id': '42019',
#   'date': '20190605',
#   'symbol': None,
#   'open': '186.29',
#   'close': '180.32',
#   'high': '186.84',
#   'low': '179.49',
#   'settlement': '180.32',
#   'volume': '172772'},
#  {'id': '42023',
#   'date': '20190606',
#   'symbol': None,
#   'open': '180.78',
#   'close': '187.39',
#   'high': '188.86',
#   'low': '179.21',
#   'settlement': '187.39',
#   'volume': '254285'},
#  {'id': '42027',
#   'date': '20190607',
#   'symbol': None,
#   'open': '187.76',
#   'close': '185',
#   'high': '188.4',
#   'low': '184.45',
#   'settlement': '185.37',
#   'volume': '165558'},
#  {'id': '42032',
#   'date': '20190610',
#   'symbol': None,
#   'open': '185.64',
#   'close': '185.92',
#   'high': '186.84',
#   'low': '181.24',
#   'settlement': '186.47',
#   'volume': '135329'},
#  {'id': '42035',
#   'date': '20190611',
#   'symbol': None,
#   'open': '185.19',
#   'close': '190.42',
#   'high': '190.6',
#   'low': '183.81',
#   'settlement': '190.33',
#   'volume': '191218'},
#  {'id': '42039',
#   'date': '20190612',
#   'symbol': None,
#   'open': '190.97',
#   'close': '193.18',
#   'high': '194',
#   'low': '188.49',
#   'settlement': '193.36',
#   'volume': '198495'},
#  {'id': '42043',
#   'date': '20190613',
#   'symbol': None,
#   'open': '193.27',
#   'close': '196.76',
#   'high': '197.13',
#   'low': '192.81',
#   'settlement': '196.76',
#   'volume': '166650'},
#  {'id': '42047',
#   'date': '20190614',
#   'symbol': None,
#   'open': '196.76',
#   'close': '198.23',
#   'high': '199.88',
#   'low': '195.01',
#   'settlement': '197.86',
#   'volume': '193327'},
#  {'id': '42051',
#   'date': '20190617',
#   'symbol': None,
#   'open': '198.5',
#   'close': '198.05',
#   'high': '201.81',
#   'low': '197.49',
#   'settlement': '198.23',
#   'volume': '165736'},
#  {'id': '42055',
#   'date': '20190618',
#   'symbol': None,
#   'open': '198.32',
#   'close': '195.11',
#   'high': '235.52',
#   'low': '192.99',
#   'settlement': '195.29',
#   'volume': '145184'},
#  {'id': '42059',
#   'date': '20190619',
#   'symbol': None,
#   'open': '194.83',
#   'close': '191.89',
#   'high': '195.11',
#   'low': '188.95',
#   'settlement': '191.89',
#   'volume': '190466'},
#  {'id': '42063',
#   'date': '20190620',
#   'symbol': None,
#   'open': '191.34',
#   'close': '193.82',
#   'high': '194.37',
#   'low': '189.41',
#   'settlement': '193.45',
#   'volume': '128947'},
#  {'id': '42067',
#   'date': '20190621',
#   'symbol': None,
#   'open': '193.82',
#   'close': '193.27',
#   'high': '194.65',
#   'low': '192.17',
#   'settlement': '193.27',
#   'volume': '121220'},
#  {'id': '42070',
#   'date': '20190624',
#   'symbol': None,
#   'open': '193.27',
#   'close': '197.77',
#   'high': '198.41',
#   'low': '191.89',
#   'settlement': '197.68',
#   'volume': '127268'},
#  {'id': '42075',
#   'date': '20190625',
#   'symbol': None,
#   'open': '198.5',
#   'close': '196.58',
#   'high': '200.43',
#   'low': '196.21',
#   'settlement': '196.85',
#   'volume': '133151'},
#  {'id': '42079',
#   'date': '20190626',
#   'symbol': None,
#   'open': '196.39',
#   'close': '199.51',
#   'high': '200.34',
#   'low': '195.57',
#   'settlement': '199.79',
#   'volume': '164353'},
#  {'id': '42083',
#   'date': '20190627',
#   'symbol': None,
#   'open': '201.08',
#   'close': '199.61',
#   'high': '204.75',
#   'low': '199.06',
#   'settlement': '200.89',
#   'volume': '138920'},
#  {'id': '42087',
#   'date': '20190628',
#   'symbol': None,
#   'open': '200.62',
#   'close': '193.27',
#   'high': '203.83',
#   'low': '191.98',
#   'settlement': '193.73',
#   'volume': '165296'},
#  {'id': '42090',
#   'date': '20190701',
#   'symbol': None,
#   'open': '194.74',
#   'close': '188.77',
#   'high': '195.11',
#   'low': '186.84',
#   'settlement': '188.03',
#   'volume': '124624'},
#  {'id': '42095',
#   'date': '20190702',
#   'symbol': None,
#   'open': '188.03',
#   'close': '185',
#   'high': '189.5',
#   'low': '184.17',
#   'settlement': '184.91',
#   'volume': '133451'},
#  {'id': '42099',
#   'date': '20190703',
#   'symbol': None,
#   'open': '184.45',
#   'close': '188.68',
#   'high': '189.04',
#   'low': '184.08',
#   'settlement': '188.86',
#   'volume': '66632'},
#  {'id': '42103',
#   'date': '20190705',
#   'symbol': None,
#   'open': '188.86',
#   'close': '189.87',
#   'high': '189.96',
#   'low': '185.64',
#   'settlement': '189.23',
#   'volume': '59329'},
#  {'id': '42107',
#   'date': '20190708',
#   'symbol': None,
#   'open': '190.33',
#   'close': '187.67',
#   'high': '190.7',
#   'low': '186.38',
#   'settlement': '187.76',
#   'volume': '99910'},
#  {'id': '42111',
#   'date': '20190709',
#   'symbol': None,
#   'open': '187.39',
#   'close': '184.54',
#   'high': '187.76',
#   'low': '183.26',
#   'settlement': '184.73',
#   'volume': '110693'},
#  {'id': '42114',
#   'date': '20190710',
#   'symbol': None,
#   'open': '183.81',
#   'close': '185.09',
#   'high': '186.2',
#   'low': '182.98',
#   'settlement': '185.46',
#   'volume': '105795'},
#  {'id': '42119',
#   'date': '20190711',
#   'symbol': None,
#   'open': '185.55',
#   'close': '191.8',
#   'high': '192.17',
#   'low': '183.81',
#   'settlement': '191.62',
#   'volume': '138310'},
#  {'id': '42123',
#   'date': '20190712',
#   'symbol': None,
#   'open': '191.62',
#   'close': '192.07',
#   'high': '193.18',
#   'low': '189.87',
#   'settlement': '192.17',
#   'volume': '96453'},
#  {'id': '42127',
#   'date': '20190715',
#   'symbol': None,
#   'open': '192.63',
#   'close': '187.21',
#   'high': '195.29',
#   'low': '185.92',
#   'settlement': '186.56',
#   'volume': '99325'},
#  {'id': '42130',
#   'date': '20190716',
#   'symbol': None,
#   'open': '186.54',
#   'close': '186.56',
#   'high': '187.39',
#   'low': '184.08',
#   'settlement': '186.47',
#   'volume': '77040'},
#  {'id': '42136',
#   'date': '20190717',
#   'symbol': None,
#   'open': '186.38',
#   'close': '186.01',
#   'high': '188.86',
#   'low': '184.45',
#   'settlement': '185.74',
#   'volume': '59828'},
#  {'id': '42139',
#   'date': '20190718',
#   'symbol': None,
#   'open': '185.19',
#   'close': '182.06',
#   'high': '185.64',
#   'low': '181.14',
#   'settlement': '181.33',
#   'volume': '87098'},
#  {'id': '42143',
#   'date': '20190719',
#   'symbol': None,
#   'open': '181.79',
#   'close': '185.19',
#   'high': '189.87',
#   'low': '180.96',
#   'settlement': '184.63',
#   'volume': '100386'},
#  {'id': '42146',
#   'date': '20190722',
#   'symbol': None,
#   'open': '185.64',
#   'close': '179.58',
#   'high': '185.64',
#   'low': '178.94',
#   'settlement': '179.03',
#   'volume': '105183'},
#  {'id': '42151',
#   'date': '20190723',
#   'symbol': None,
#   'open': '179.21',
#   'close': '179.95',
#   'high': '181.33',
#   'low': '177.56',
#   'settlement': '179.03',
#   'volume': '97771'},
#  {'id': '42155',
#   'date': '20190724',
#   'symbol': None,
#   'open': '179.03',
#   'close': '182.89',
#   'high': '183.26',
#   'low': '179.03',
#   'settlement': '182.89',
#   'volume': '111697'},
#  {'id': '42158',
#   'date': '20190725',
#   'symbol': None,
#   'open': '182.89',
#   'close': '183.35',
#   'high': '186.47',
#   'low': '180.87',
#   'settlement': '183.53',
#   'volume': '119402'},
#  {'id': '42162',
#   'date': '20190726',
#   'symbol': None,
#   'open': '183.53',
#   'close': '182.25',
#   'high': '183.81',
#   'low': '181.33',
#   'settlement': '182.25',
#   'volume': '66225'},
#  {'id': '42167',
#   'date': '20190729',
#   'symbol': None,
#   'open': '181.97',
#   'close': '184.63',
#   'high': '186.38',
#   'low': '180.96',
#   'settlement': '185',
#   'volume': '111424'},
#  {'id': '42171',
#   'date': '20190730',
#   'symbol': None,
#   'open': '184.54',
#   'close': '182.61',
#   'high': '184.91',
#   'low': '181.88',
#   'settlement': '182.71',
#   'volume': '76885'},
#  {'id': '42175',
#   'date': '20190731',
#   'symbol': None,
#   'open': '182.8',
#   'close': '178.76',
#   'high': '183.9',
#   'low': '178.02',
#   'settlement': '179.03',
#   'volume': '116997'},
#  {'id': '42179',
#   'date': '20190801',
#   'symbol': None,
#   'open': '178.85',
#   'close': '176.27',
#   'high': '179.49',
#   'low': '173.34',
#   'settlement': '174.81',
#   'volume': '139045'},
#  {'id': '42183',
#   'date': '20190802',
#   'symbol': None,
#   'open': '176.09',
#   'close': '179.86',
#   'high': '180.59',
#   'low': '174.9',
#   'settlement': '180.32',
#   'volume': '149310'},
#  {'id': '42187',
#   'date': '20190805',
#   'symbol': None,
#   'open': '180.13',
#   'close': '181.51',
#   'high': '181.88',
#   'low': '176.09',
#   'settlement': '181.69',
#   'volume': '133236'},
#  {'id': '42191',
#   'date': '20190806',
#   'symbol': None,
#   'open': '181.14',
#   'close': '178.02',
#   'high': '182.15',
#   'low': '177.38',
#   'settlement': '177.84',
#   'volume': '118511'},
#  {'id': '42195',
#   'date': '20190807',
#   'symbol': None,
#   'open': '177.84',
#   'close': '179.21',
#   'high': '180.13',
#   'low': '175.45',
#   'settlement': '179.4',
#   'volume': '188222'},
#  {'id': '42199',
#   'date': '20190808',
#   'symbol': None,
#   'open': '179.86',
#   'close': '183.07',
#   'high': '184.73',
#   'low': '178.57',
#   'settlement': '183.16',
#   'volume': '174882'},
#  {'id': '42203',
#   'date': '20190809',
#   'symbol': None,
#   'open': '183.07',
#   'close': '183.62',
#   'high': '185.64',
#   'low': '182.25',
#   'settlement': '183.53',
#   'volume': '159086'},
#  {'id': '42207',
#   'date': '20190812',
#   'symbol': None,
#   'open': '183.72',
#   'close': '173.15',
#   'high': '184.45',
#   'low': '171.41',
#   'settlement': '173.34',
#   'volume': '201928'},
#  {'id': '42211',
#   'date': '20190813',
#   'symbol': None,
#   'open': '173.06',
#   'close': '173.43',
#   'high': '175.91',
#   'low': '171.04',
#   'settlement': '173.43',
#   'volume': '167571'},
#  {'id': '42215',
#   'date': '20190814',
#   'symbol': None,
#   'open': '174.44',
#   'close': '174.53',
#   'high': '176.37',
#   'low': '173.15',
#   'settlement': '174.07',
#   'volume': '132214'},
#  {'id': '42219',
#   'date': '20190815',
#   'symbol': None,
#   'open': '174.81',
#   'close': '172.69',
#   'high': '175.36',
#   'low': '172.14',
#   'settlement': '172.33',
#   'volume': '117220'},
#  {'id': '42223',
#   'date': '20190816',
#   'symbol': None,
#   'open': '172.78',
#   'close': '173.15',
#   'high': '173.79',
#   'low': '171.68',
#   'settlement': '172.97',
#   'volume': '103802'},
#  {'id': '42227',
#   'date': '20190819',
#   'symbol': None,
#   'open': '174.62',
#   'close': '173.06',
#   'high': '175.17',
#   'low': '173.06',
#   'settlement': '173.61',
#   'volume': '110537'},
#  {'id': '42231',
#   'date': '20190820',
#   'symbol': None,
#   'open': '173.06',
#   'close': '171.22',
#   'high': '174.81',
#   'low': '170.3',
#   'settlement': '171.41',
#   'volume': '106205'},
#  {'id': '42235',
#   'date': '20190821',
#   'symbol': None,
#   'open': '171.41',
#   'close': '171.96',
#   'high': '172.23',
#   'low': '169.66',
#   'settlement': '171.96',
#   'volume': '97961'},
#  {'id': '42239',
#   'date': '20190822',
#   'symbol': None,
#   'open': '171.96',
#   'close': '173.43',
#   'high': '174.35',
#   'low': '171.22',
#   'settlement': '173.34',
#   'volume': '86726'},
#  {'id': '42243',
#   'date': '20190823',
#   'symbol': None,
#   'open': '173.15',
#   'close': '175.26',
#   'high': '175.82',
#   'low': '171.13',
#   'settlement': '175.54',
#   'volume': '115843'},
#  {'id': '42247',
#   'date': '20190826',
#   'symbol': None,
#   'open': '174.9',
#   'close': '174.44',
#   'high': '176.83',
#   'low': '173.7',
#   'settlement': '174.62',
#   'volume': '85454'},
#  {'id': '42251',
#   'date': '20190827',
#   'symbol': None,
#   'open': '174.35',
#   'close': '174.9',
#   'high': '176.27',
#   'low': '173.7',
#   'settlement': '175.17',
#   'volume': '91652'},
#  {'id': '42253',
#   'date': '20190828',
#   'symbol': None,
#   'open': '175.36',
#   'close': '174.53',
#   'high': '175.72',
#   'low': '172.23',
#   'settlement': '174.62',
#   'volume': '82184'},
#  {'id': '42259',
#   'date': '20190829',
#   'symbol': None,
#   'open': '174.53',
#   'close': '173.7',
#   'high': '175.45',
#   'low': '173.34',
#   'settlement': '173.7',
#   'volume': '55498'},
#  {'id': '42263',
#   'date': '20190830',
#   'symbol': None,
#   'open': '173.7',
#   'close': '169.94',
#   'high': '173.7',
#   'low': '168.74',
#   'settlement': '169.94',
#   'volume': '152288'},
#  {'id': '42267',
#   'date': '20190903',
#   'symbol': None,
#   'open': '170.12',
#   'close': '167',
#   'high': '170.12',
#   'low': '165.53',
#   'settlement': '166.63',
#   'volume': '115679'},
#  {'id': '42271',
#   'date': '20190904',
#   'symbol': None,
#   'open': '166.81',
#   'close': '169.29',
#   'high': '170.86',
#   'low': '166.81',
#   'settlement': '169.29',
#   'volume': '95306'},
#  {'id': '42275',
#   'date': '20190905',
#   'symbol': None,
#   'open': '169.2',
#   'close': '171.5',
#   'high': '172.51',
#   'low': '169.11',
#   'settlement': '171.31',
#   'volume': '65955'},
#  {'id': '42279',
#   'date': '20190906',
#   'symbol': None,
#   'open': '171.22',
#   'close': '169.94',
#   'high': '171.5',
#   'low': '169.11',
#   'settlement': '170.4',
#   'volume': '50144'},
#  {'id': '42283',
#   'date': '20190909',
#   'symbol': None,
#   'open': '169.39',
#   'close': '174.16',
#   'high': '174.9',
#   'low': '169.11',
#   'settlement': '174.35',
#   'volume': '103065'},
#  {'id': '42287',
#   'date': '20190910',
#   'symbol': None,
#   'open': '174.81',
#   'close': '177.1',
#   'high': '177.65',
#   'low': '174.07',
#   'settlement': '177.19',
#   'volume': '80756'},
#  {'id': '42295',
#   'date': '20190911',
#   'symbol': None,
#   'open': '176.92',
#   'close': '175.54',
#   'high': '177.29',
#   'low': '174.53',
#   'settlement': '175.45',
#   'volume': '74317'},
#  {'id': '42296',
#   'date': '20190912',
#   'symbol': None,
#   'open': '176',
#   'close': '178.2',
#   'high': '178.57',
#   'low': '173.61',
#   'settlement': '177.74',
#   'volume': '91409'},
#  {'id': '42297',
#   'date': '20190913',
#   'symbol': None,
#   'open': '178.39',
#   'close': '177.38',
#   'high': '180.41',
#   'low': '176.55',
#   'settlement': '177.65',
#   'volume': '71015'},
#  {'id': '42303',
#   'date': '20190916',
#   'symbol': None,
#   'open': '179.31',
#   'close': '179.21',
#   'high': '180.04',
#   'low': '177.19',
#   'settlement': '179.58',
#   'volume': '65822'},
#  {'id': '42307',
#   'date': '20190917',
#   'symbol': None,
#   'open': '179.21',
#   'close': '178.11',
#   'high': '179.21',
#   'low': '176.64',
#   'settlement': '177.93',
#   'volume': '63434'},
#  {'id': '42311',
#   'date': '20190918',
#   'symbol': None,
#   'open': '177.93',
#   'close': '179.86',
#   'high': '180.96',
#   'low': '177.01',
#   'settlement': '179.86',
#   'volume': '71278'},
#  {'id': '42315',
#   'date': '20190919',
#   'symbol': None,
#   'open': '179.77',
#   'close': '178.85',
#   'high': '180.78',
#   'low': '178.02',
#   'settlement': '179.31',
#   'volume': '70035'},
#  {'id': '42319',
#   'date': '20190920',
#   'symbol': None,
#   'open': '178.76',
#   'close': '178.11',
#   'high': '180.5',
#   'low': '177.65',
#   'settlement': '177.93',
#   'volume': '53943'},
#  {'id': '42323',
#   'date': '20190923',
#   'symbol': None,
#   'open': '178.2',
#   'close': '176.92',
#   'high': '179.12',
#   'low': '176.83',
#   'settlement': '177.47',
#   'volume': '38851'},
#  {'id': '42327',
#   'date': '20190924',
#   'symbol': None,
#   'open': '177.01',
#   'close': '176.64',
#   'high': '177.93',
#   'low': '175.45',
#   'settlement': '177.01',
#   'volume': '56325'},
#  {'id': '42331',
#   'date': '20190925',
#   'symbol': None,
#   'open': '176.73',
#   'close': '175.26',
#   'high': '177.19',
#   'low': '174.99',
#   'settlement': '175.36',
#   'volume': '53810'},
#  {'id': '42335',
#   'date': '20190926',
#   'symbol': None,
#   'open': '175.26',
#   'close': '178.2',
#   'high': '178.85',
#   'low': '175.17',
#   'settlement': '177.93',
#   'volume': '67670'},
#  {'id': '42339',
#   'date': '20190927',
#   'symbol': None,
#   'open': '178.57',
#   'close': '178.94',
#   'high': '180.22',
#   'low': '177.29',
#   'settlement': '179.03',
#   'volume': '56932'},
#  {'id': '42343',
#   'date': '20190930',
#   'symbol': None,
#   'open': '179.31',
#   'close': '181.88',
#   'high': '184.08',
#   'low': '177.56',
#   'settlement': '182.15',
#   'volume': '117028'},
#  {'id': '42347',
#   'date': '20191001',
#   'symbol': None,
#   'open': '182.43',
#   'close': '182.71',
#   'high': '183.44',
#   'low': '179.95',
#   'settlement': '183.26',
#   'volume': '90605'},
#  {'id': '42353',
#   'date': '20191002',
#   'symbol': None,
#   'open': '182.43',
#   'close': '179.67',
#   'high': '183.35',
#   'low': '178.3',
#   'settlement': '179.67',
#   'volume': '85618'},
#  {'id': '42354',
#   'date': '20191003',
#   'symbol': None,
#   'open': '179.31',
#   'close': '179.58',
#   'high': '181.14',
#   'low': '178.48',
#   'settlement': '179.58',
#   'volume': '48479'},
#  {'id': '42359',
#   'date': '20191004',
#   'symbol': None,
#   'open': '179.77',
#   'close': '180.32',
#   'high': '180.87',
#   'low': '178.76',
#   'settlement': '180.22',
#   'volume': '44879'},
#  {'id': '42363',
#   'date': '20191007',
#   'symbol': None,
#   'open': '180.78',
#   'close': '179.58',
#   'high': '181.69',
#   'low': '179.49',
#   'settlement': '179.77',
#   'volume': '57258'},
#  {'id': '42369',
#   'date': '20191008',
#   'symbol': None,
#   'open': '179.95',
#   'close': '182.8',
#   'high': '184.54',
#   'low': '178.85',
#   'settlement': '183.81',
#   'volume': '89069'},
#  {'id': '42370',
#   'date': '20191009',
#   'symbol': None,
#   'open': '183.9',
#   'close': '183.81',
#   'high': '185.37',
#   'low': '182.71',
#   'settlement': '183.81',
#   'volume': '72521'},
#  {'id': '42375',
#   'date': '20191010',
#   'symbol': None,
#   'open': '183.53',
#   'close': '180.5',
#   'high': '185.28',
#   'low': '179.12',
#   'settlement': '181.14',
#   'volume': '104214'},
#  {'id': '42379',
#   'date': '20191011',
#   'symbol': None,
#   'open': '180.68',
#   'close': '187.48',
#   'high': '188.4',
#   'low': '180.5',
#   'settlement': '186.65',
#   'volume': '127633'},
#  {'id': '42383',
#   'date': '20191014',
#   'symbol': None,
#   'open': '188.49',
#   'close': '187.76',
#   'high': '189.23',
#   'low': '186.2',
#   'settlement': '187.76',
#   'volume': '88812'},
#  {'id': '42387',
#   'date': '20191015',
#   'symbol': None,
#   'open': '187.39',
#   'close': '209.53',
#   'high': '187.85',
#   'low': '185.28',
#   'settlement': '186.29',
#   'volume': '56056'},
#  {'id': '42391',
#   'date': '20191016',
#   'symbol': None,
#   'open': '185.83',
#   'close': '188.12',
#   'high': '188.95',
#   'low': '185.37',
#   'settlement': '188.58',
#   'volume': '85603'},
#  {'id': '42395',
#   'date': '20191017',
#   'symbol': None,
#   'open': '188.95',
#   'close': '192.53',
#   'high': '193.64',
#   'low': '188.4',
#   'settlement': '193.08',
#   'volume': '111859'},
#  {'id': '42399',
#   'date': '20191018',
#   'symbol': None,
#   'open': '193.27',
#   'close': '195.01',
#   'high': '195.75',
#   'low': '191.43',
#   'settlement': '195.57',
#   'volume': '90692'},
#  {'id': '42403',
#   'date': '20191021',
#   'symbol': None,
#   'open': '195.47',
#   'close': '191.98',
#   'high': '196.58',
#   'low': '192.07',
#   'settlement': '192.35',
#   'volume': '87206'},
#  {'id': '42407',
#   'date': '20191022',
#   'symbol': None,
#   'open': '192.17',
#   'close': '190.15',
#   'high': '195.57',
#   'low': '190.05',
#   'settlement': '190.33',
#   'volume': '91593'},
#  {'id': '42411',
#   'date': '20191023',
#   'symbol': None,
#   'open': '190.33',
#   'close': '191.52',
#   'high': '192.44',
#   'low': '189.5',
#   'settlement': '191.34',
#   'volume': '63192'},
#  {'id': '42415',
#   'date': '20191024',
#   'symbol': None,
#   'open': '191.98',
#   'close': '189.96',
#   'high': '192.44',
#   'low': '189.41',
#   'settlement': '189.59',
#   'volume': '55212'},
#  {'id': '42419',
#   'date': '20191025',
#   'symbol': None,
#   'open': '190.05',
#   'close': '189.87',
#   'high': '191.8',
#   'low': '189.04',
#   'settlement': '190.24',
#   'volume': '62760'},
#  {'id': '42423',
#   'date': '20191028',
#   'symbol': None,
#   'open': '190.33',
#   'close': '188.12',
#   'high': '190.51',
#   'low': '187.39',
#   'settlement': '188.03',
#   'volume': '80756'},
#  {'id': '42427',
#   'date': '20191029',
#   'symbol': None,
#   'open': '188.49',
#   'close': '187.94',
#   'high': '189.59',
#   'low': '186.75',
#   'settlement': '187.94',
#   'volume': '84232'},
#  {'id': '42431',
#   'date': '20191030',
#   'symbol': None,
#   'open': '187.85',
#   'close': '187.39',
#   'high': '188.86',
#   'low': '186.29',
#   'settlement': '187.11',
#   'volume': '61294'},
#  {'id': '42434',
#   'date': '20191031',
#   'symbol': None,
#   'open': '187.39',
#   'close': '186.65',
#   'high': '188.22',
#   'low': '184.08',
#   'settlement': '186.93',
#   'volume': '96671'},
#  {'id': '42438',
#   'date': '20191101',
#   'symbol': None,
#   'open': '186.93',
#   'close': '189.14',
#   'high': '189.78',
#   'low': '186.2',
#   'settlement': '189.59',
#   'volume': '90117'},
#  {'id': '42444',
#   'date': '20191104',
#   'symbol': None,
#   'open': '188.95',
#   'close': '187.39',
#   'high': '189.32',
#   'low': '186.65',
#   'settlement': '187.3',
#   'volume': '66887'},
#  {'id': '42445',
#   'date': '20191105',
#   'symbol': None,
#   'open': '187.76',
#   'close': '189.41',
#   'high': '189.59',
#   'low': '187.02',
#   'settlement': '189.32',
#   'volume': '87816'},
#  {'id': '42450',
#   'date': '20191106',
#   'symbol': None,
#   'open': '189.41',
#   'close': '189.96',
#   'high': '191.71',
#   'low': '188.68',
#   'settlement': '189.87',
#   'volume': '109432'},
#  {'id': '42454',
#   'date': '20191107',
#   'symbol': None,
#   'open': '190.15',
#   'close': '188.12',
#   'high': '190.97',
#   'low': '187.76',
#   'settlement': '188.31',
#   'volume': '134075'},
#  {'id': '42458',
#   'date': '20191108',
#   'symbol': None,
#   'open': '188.31',
#   'close': '187.85',
#   'high': '190.24',
#   'low': '185.74',
#   'settlement': '187.48',
#   'volume': '149400'},
#  {'id': '42463',
#   'date': '20191111',
#   'symbol': None,
#   'open': '186.65',
#   'close': '186.1',
#   'high': '187.57',
#   'low': '185.09',
#   'settlement': '185.83',
#   'volume': '149474'},
#  {'id': '42466',
#   'date': '20191112',
#   'symbol': None,
#   'open': '186.01',
#   'close': '189.78',
#   'high': '190.05',
#   'low': '185.64',
#   'settlement': '189.96',
#   'volume': '153829'},
#  {'id': '42470',
#   'date': '20191113',
#   'symbol': None,
#   'open': '189.78',
#   'close': '186.93',
#   'high': '189.87',
#   'low': '186.1',
#   'settlement': '187.02',
#   'volume': '132802'},
#  {'id': '42474',
#   'date': '20191114',
#   'symbol': None,
#   'open': '186.93',
#   'close': '186.47',
#   'high': '188.12',
#   'low': '185.74',
#   'settlement': '186.56',
#   'volume': '117396'},
#  {'id': '42478',
#   'date': '20191115',
#   'symbol': None,
#   'open': '186.56',
#   'close': '184.82',
#   'high': '186.84',
#   'low': '184.27',
#   'settlement': '184.73',
#   'volume': '108421'},
#  {'id': '42482',
#   'date': '20191118',
#   'symbol': None,
#   'open': '184.91',
#   'close': '186.38',
#   'high': '187.67',
#   'low': '183.16',
#   'settlement': '186.38',
#   'volume': '144970'},
#  {'id': '42487',
#   'date': '20191119',
#   'symbol': None,
#   'open': '186.01',
#   'close': '187.94',
#   'high': '189.32',
#   'low': '185.92',
#   'settlement': '188.12',
#   'volume': '167413'},
#  {'id': '42490',
#   'date': '20191120',
#   'symbol': None,
#   'open': '188.12',
#   'close': '189.23',
#   'high': '189.5',
#   'low': '186.65',
#   'settlement': '189.41',
#   'volume': '95846'},
#  {'id': '42494',
#   'date': '20191121',
#   'symbol': None,
#   'open': '189.23',
#   'close': '186.75',
#   'high': '190.88',
#   'low': '186.75',
#   'settlement': '187.02',
#   'volume': '109089'},
#  {'id': '42499',
#   'date': '20191122',
#   'symbol': None,
#   'open': '216.88',
#   'close': '188.86',
#   'high': '190.51',
#   'low': '186.75',
#   'settlement': '189.32',
#   'volume': '115621'},
#  {'id': '42501',
#   'date': '20191125',
#   'symbol': None,
#   'open': '189.23',
#   'close': '194.83',
#   'high': '195.66',
#   'low': '189.23',
#   'settlement': '195.11',
#   'volume': '182442'},
#  {'id': '42506',
#   'date': '20191126',
#   'symbol': None,
#   'open': '195.01',
#   'close': '194.65',
#   'high': '195.38',
#   'low': '193.08',
#   'settlement': '194.83',
#   'volume': '126892'},
#  {'id': '42510',
#   'date': '20191127',
#   'symbol': None,
#   'open': '194.74',
#   'close': '193.36',
#   'high': '195.84',
#   'low': '193.18',
#   'settlement': '194.19',
#   'volume': '101014'},
#  {'id': '42514',
#   'date': '20191129',
#   'symbol': None,
#   'open': '195.66',
#   'close': '201.08',
#   'high': '202.27',
#   'low': '195.66',
#   'settlement': '201.17',
#   'volume': '109643'},
#  {'id': '42519',
#   'date': '20191202',
#   'symbol': None,
#   'open': '201.9',
#   'close': '200.62',
#   'high': '202',
#   'low': '199.42',
#   'settlement': '199.61',
#   'volume': '108698'},
#  {'id': '42523',
#   'date': '20191203',
#   'symbol': None,
#   'open': '200.53',
#   'close': '195.47',
#   'high': '201.35',
#   'low': '195.47',
#   'settlement': '194.92',
#   'volume': '130451'},
#  {'id': '42534',
#   'date': '20191204',
#   'symbol': None,
#   'open': '195.11',
#   'close': '196.76',
#   'high': '196.76',
#   'low': '194.55',
#   'settlement': '196.58',
#   'volume': '73602'},
#  {'id': '42535',
#   'date': '20191205',
#   'symbol': None,
#   'open': '196.67',
#   'close': '195.38',
#   'high': '197.49',
#   'low': '195.38',
#   'settlement': '195.47',
#   'volume': '64478'},
#  {'id': '42536',
#   'date': '20191206',
#   'symbol': None,
#   'open': '195.75',
#   'close': '194.74',
#   'high': '195.75',
#   'low': '194.37',
#   'settlement': '195.66',
#   'volume': '70713'},
#  {'id': '42537',
#   'date': '20191209',
#   'symbol': None,
#   'open': '195.66',
#   'close': '195.47',
#   'high': '195.93',
#   'low': '195.11',
#   'settlement': '195.47',
#   'volume': '68478'},
#  {'id': '42544',
#   'date': '20191210',
#   'symbol': None,
#   'open': '195.57',
#   'close': '196.58',
#   'high': '197.49',
#   'low': '194.65',
#   'settlement': '196.48',
#   'volume': '67707'},
#  {'id': '42548',
#   'date': '20191211',
#   'symbol': None,
#   'open': '196.39',
#   'close': '194.65',
#   'high': '196.39',
#   'low': '194',
#   'settlement': '195.01',
#   'volume': '70108'},
#  {'id': '42552',
#   'date': '20191212',
#   'symbol': None,
#   'open': '194.65',
#   'close': '198.05',
#   'high': '199.88',
#   'low': '194.28',
#   'settlement': '198.14',
#   'volume': '98145'},
#  {'id': '42556',
#   'date': '20191213',
#   'symbol': None,
#   'open': '195.84',
#   'close': '195.75',
#   'high': '197.03',
#   'low': '193.18',
#   'settlement': '195.66',
#   'volume': '97223'},
#  {'id': '42560',
#   'date': '20191216',
#   'symbol': None,
#   'open': '196.48',
#   'close': '201.81',
#   'high': '204.57',
#   'low': '196.48',
#   'settlement': '202',
#   'volume': '144782'},
#  {'id': '42566',
#   'date': '20191217',
#   'symbol': None,
#   'open': '203.28',
#   'close': '203.65',
#   'high': '204.75',
#   'low': '200.25',
#   'settlement': '204.38',
#   'volume': '107215'},
#  {'id': '42567',
#   'date': '20191218',
#   'symbol': None,
#   'open': '203.28',
#   'close': '201.26',
#   'high': '203.92',
#   'low': '200.33',
#   'settlement': '201.44',
#   'volume': '97039'},
#  {'id': '42574',
#   'date': '20191219',
#   'symbol': None,
#   'open': '201.17',
#   'close': '200.43',
#   'high': '203.37',
#   'low': '199.88',
#   'settlement': '200.34',
#   'volume': '66478'},
#  {'id': '42575',
#   'date': '20191220',
#   'symbol': None,
#   'open': '200.34',
#   'close': '199.15',
#   'high': '201.72',
#   'low': '197.95',
#   'settlement': '199.24',
#   'volume': '69350'},
#  {'id': '42580',
#   'date': '20191223',
#   'symbol': None,
#   'open': '199.51',
#   'close': '198.41',
#   'high': '200.98',
#   'low': '197.95',
#   'settlement': '198.23',
#   'volume': '56373'},
#  {'id': '42584',
#   'date': '20191224',
#   'symbol': None,
#   'open': '198.23',
#   'close': '198.78',
#   'high': '200.25',
#   'low': '197.86',
#   'settlement': '198.78',
#   'volume': '34733'},
#  {'id': '42588',
#   'date': '20191226',
#   'symbol': None,
#   'open': '198.69',
#   'close': '202.18',
#   'high': '202.82',
#   'low': '198.5',
#   'settlement': '201.72',
#   'volume': '45165'},
#  {'id': '42592',
#   'date': '20191227',
#   'symbol': None,
#   'open': '202',
#   'close': '204.38',
#   'high': '206.13',
#   'low': '201.81',
#   'settlement': '204.38',
#   'volume': '77164'},
#  {'id': '42596',
#   'date': '20191230',
#   'symbol': None,
#   'open': '205.76',
#   'close': '204.11',
#   'high': '207.41',
#   'low': '202.64',
#   'settlement': '204.29',
#   'volume': '65888'},
#  {'id': '42600',
#   'date': '20191231',
#   'symbol': None,
#   'open': '203.92',
#   'close': '205.3',
#   'high': '205.67',
#   'low': '203.19',
#   'settlement': '205.3',
#   'volume': '58268'}]

# %%
a, b, c, d = [], [], [], []
type(a), type(b), type(c), type(d)
# Out:
# (list, list, list, list)

# %%
id_, date, symbol, open_, close= [], [], [], [], []

for item in data2 :
    id_.append(item['id'])
    date.append(item['date'])
    symbol.append(item['symbol'])
    open_.append(item['open'])
    close.append(item['close'])

# %%
df = pd.DataFrame({
    'id' : id_,
    'date' : date,
    'symbol' :symbol,
    'open' : open_,
    'close' : close,
})

# %%
df.head()
# Out:
#       id      date symbol    open   close
# 0  41596  20190102   None  184.63  186.29
# 1  41597  20190103   None   186.2  188.77
# 2  41603  20190104   None  188.77  189.59
# 3  41609  20190107   None  190.33  189.78
# 4  41610  20190108   None  189.78  190.79

# %%
import requests
from bs4 import BeautifulSoup

date = '201512'
region_code = '11110'
apikey = '1jnWNsoq%2FH0klvITIVP%2F%2Faq5EEJ%2Fnd0pQ%2FGx56hU7dKOOCyNUoDYjKJ2cWH3wTSe5H%2B4wG6l5KVlUMPYB5Vg1w%3D%3D'
url = f'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?LAWD_CD={region_code}&DEAL_YMD={date}&serviceKey={apikey}'


res = requests.get(url)
textsrc = res.text

soup = BeautifulSoup(textsrc, 'xml')

items = soup.select('item')

# %%
items
# Out:
# [<item><거래금액>      82,500</거래금액><거래유형> </거래유형><건축년도>2008</건축년도><년>2015</년><등기일자> </등기일자><법정동> 사직동</법정동><아파트>광화문스페이스본(101동~105동)</아파트><월>12</월><일>10</일><전용면적>94.51</전용면적><중개사소재지> </중개사소재지><지번>9</지번><지역코드>11110</지역코드><층>11</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>      60,000</거래금액><거래유형> </거래유형><건축년도>1981</건축년도><년>2015</년><등기일자> </등기일자><법정동> 당주동</법정동><아파트>롯데미도파광화문빌딩</아파트><월>12</월><일>22</일><전용면적>149.95</전용면적><중개사소재지> </중개사소재지><지번>145</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>     130,000</거래금액><거래유형> </거래유형><건축년도>2004</건축년도><년>2015</년><등기일자> </등기일자><법정동> 내수동</법정동><아파트>킹스매너</아파트><월>12</월><일>8</일><전용면적>194.43</전용면적><중개사소재지> </중개사소재지><지번>110-15</지번><지역코드>11110</지역코드><층>6</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액
층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>      63,490</거래금액><거래유형> </거래유형><건축년도>2000</건축년도><년>2015</년><등기일자> </등기일자><법정동> 무악동</법정동><아파트>현대</아파트><월>12</월><일>15</일><전용면적>114.9</전용면적><중개사소재지> </중개사소재지><지번>82</지번><지역코드>11110</지역코드><층>6</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>      62,000</거래금액><거래유형> </거래유형><건축년도>2008</건축년도><년>2015</년><등기일자> </등기일자><법정동> 무악동</법정동><아파트>인왕산아이파크</아파트><월>12</월><일>16</일><전용면적>84.858</전용면적><중개사소재지> </중개사소재지><지번>60</지번><지역코드>11110</지역코드><층>5</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>      63,400</거래금액><거래유형> </거래유형><건축년도>2015</건축년도><년>2015</년><등기일자> </등기일자><법정동> 무악동</법정동><아파트>인왕산2차아이파크</아파트><월>12</월><일>22</일><전용면적>84.0284</전용면적><중개사소재지> </중개사소재지><지번>88</지번><지역코드>11110</지역코드><층>10</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>      61,000</거래금액><거래유형> </거래유형><건축년도>2008</건축년도><년>2015</년><등기일자> </등기일자><법정동> 무악동</법정동><아파트>인왕산아이파크</아파트><월>12</월><일>25</일><전용면적>84.858</전용면적><중개사소재지> </중개사소재지><지번>60</지번><지역코드>11110</지역코드><층>13</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>]

# %%
items[0].select_one('거래금액').text
# Out:
# '      82,500'

# %%
import requests
from bs4 import BeautifulSoup

date = '201512'
region_code = '11110'
apikey = 'QjITnZtxSg5%2Bhzh%2BWR8hYLMstCDRuf1REcb5E59648Wy77%2B7z8aQBHgv95ylOhyoP31mFZWlyiqd2TrMu7HTuw%3D%3D'
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?LAWD_CD={region_code}&DEAL_YMD={date}&serviceKey={apikey}'

res = requests.get(url)
textsrc = res.text

soup = BeautifulSoup(textsrc, 'xml')

items = soup.select('response > body > items > item') 

for item in items:
    print(item.select_one('거래금액').text.strip(),
          item.select_one('건축년도').text,
          item.select_one('년').text,
          item.select_one('법정동').text.strip(),
          item.select_one('아파트').text,
          item.select_one('월').text,
          item.select_one('일').text,
          item.select_one('전용면적').text,
          item.select_one('지번').text,
          item.select_one('지역코드').text,
          item.select_one('층').text)
# Out:
# 82,500 2008 2015 사직동 광화문스페이스본(101동~105동) 12 10 94.51 9 11110 11
# 60,000 1981 2015 당주동 롯데미도파광화문빌딩 12 22 149.95 145 11110 8
# 130,000 2004 2015 내수동 킹스매너 12 8 194.43 110-15 11110 6
# 105,000 2004 2015 내수동 경희궁의아침2단지 12 14 124.17 71 11110 8
# 120,000 2003 2015 내수동 경희궁파크팰리스 12 24 146.33 95 11110 4
# 17,000 2014 2015 연건동 이화에수풀 12 17 16.98 195-10 11110 8
# 17,000 2014 2015 연건동 이화에수풀 12 18 16.98 195-10 11110 4
# 57,000 2006 2015 명륜1가 렉스빌 12 29 106.98 19 11110 3
# 44,000 1995 2015 명륜2가 아남1 12 1 84.8 4 11110 18
# 52,000 1995 2015 명륜2가 아남1 12 10 84.9 4 11110 12

# %%
# 반복되는 코드 정리
item_list = ['거래금액', '건축년도', '년', '법정동', '아파트', '월', '일', '전용면적', '지번', '지역코드', '층']

for item in items:
    for i in item_list:
        print(item.select_one(i).text.strip(), end=' ')
    print()
# Out:
# 82,500 2008 2015 사직동 광화문스페이스본(101동~105동) 12 10 94.51 9 11110 11
# 60,000 1981 2015 당주동 롯데미도파광화문빌딩 12 22 149.95 145 11110 8
# 130,000 2004 2015 내수동 킹스매너 12 8 194.43 110-15 11110 6
# 105,000 2004 2015 내수동 경희궁의아침2단지 12 14 124.17 71 11110 8
# 120,000 2003 2015 내수동 경희궁파크팰리스 12 24 146.33 95 11110 4
# 17,000 2014 2015 연건동 이화에수풀 12 17 16.98 195-10 11110 8
# 17,000 2014 2015 연건동 이화에수풀 12 18 16.98 195-10 11110 4
# 57,000 2006 2015 명륜1가 렉스빌 12 29 106.98 19 11110 3
# 44,000 1995 2015 명륜2가 아남1 12 1 84.8 4 11110 18
# 52,000 1995 2015 명륜2가 아남1 12 10 84.9 4 11110 12

# %%
import requests, pandas as pd
from bs4 import BeautifulSoup

def default_text(node, text):
    if node != None:
        return node.text.strip()
    else:
        return text
date = '201512'
region_code = '11110'
apikey = 'QjITnZtxSg5%2Bhzh%2BWR8hYLMstCDRuf1REcb5E59648Wy77%2B7z8aQBHgv95ylOhyoP31mFZWlyiqd2TrMu7HTuw%3D%3D'
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?LAWD_CD={region_code}&DEAL_YMD={date}&serviceKey={apikey}'   
    

res = requests.get(url)
textsrc = res.text

soup = BeautifulSoup(textsrc, 'xml')
items = soup.select('response > body > items > item') 

item_list = ['거래금액', '건축년도', '년', '법정동', '아파트', '월', '일', '전용면적', '지번', '지역코드', '층']
data_list = []

for item in items:
    data_list.append([ default_text(item.select_one(i), '') for i in item_list]) # value를 행기준으로 맞춤, 110 X 11

df = pd.DataFrame(data_list, columns=item_list)
df.to_csv('./sample/아파트매매 실거래자료.csv', index=False, encoding='utf-8')

# %%
import datetime, dateutil
start_datetime = datetime.datetime(2023, 1, 1)
start_datetime
# Out:
# datetime.datetime(2023, 1, 1, 0, 0)

# %%
date = start_datetime.strftime('%Y%m') #
date
# Out:
# '202301'

# %%
start_datetime = start_datetime + dateutil.relativedelta.relativedelta(months=1)
start_datetime
# Out:
# datetime.datetime(2023, 2, 1, 0, 0)

# %%
import requests, datetime, dateutil, pandas as pd
from bs4 import BeautifulSoup

def default_text(node, text):
    if node != None:
        return node.text.strip()
    else:
        return text
    
start_datetime = datetime.datetime(2023, 1, 1)

data_list = []
item_list = ['거래금액', '건축년도', '년', '법정동', '아파트', '월', '일', '전용면적', '지번', '지역코드', '층']

while True:
    date = start_datetime.strftime('%Y%m') #202301
    
    if date >= '202309':
        break
        
    region_code = '11110'
    apikey = 'QjITnZtxSg5%2Bhzh%2BWR8hYLMstCDRuf1REcb5E59648Wy77%2B7z8aQBHgv95ylOhyoP31mFZWlyiqd2TrMu7HTuw%3D%3D'
    url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?LAWD_CD={region_code}&DEAL_YMD={date}&serviceKey={apikey}'

    res = requests.get(url)
    textsrc = res.text

    soup = BeautifulSoup(textsrc, 'xml')
    items = soup.select('response > body > items > item') 

    for item in items:
        data_list.append([ default_text(item.select_one(i), '') for i in item_list]) # value를 행기준으로 맞춤, 110 X 11
    
    start_datetime = start_datetime + dateutil.relativedelta.relativedelta(months=1)  # += 1달 

df = pd.DataFrame(data_list, columns=item_list)
print(df)
df.to_csv('./sample/아파트매매 실거래자료.csv', index=False, encoding='cp949')
# Out:
#        거래금액  건축년도     년   법정동             아파트  월   일     전용면적      지번   지역코드  \
# 0   200,000  2008  2023   사직동  광화문스페이스본(106동)  1  20   163.33     9-1  11110
# 1    79,000  2006  2023   인의동         효성쥬얼리시티  1  26     84.7    48-2  11110
# 2    12,200  2014  2023   숭인동       숭인한양LEEPS  1  20    12.78  1421-2  11110
# 3   169,000  2017  2023   홍파동      경희궁자이(2단지)  1  27  84.8359     199  11110
# 4    18,900  1997  2023   평창동           갑을아파트  1  28    30.46     595  11110
# ..      ...   ...   ...   ...             ... ..  ..      ...     ...    ...
# 72   21,000  2014  2023   연건동           이화에수풀  8  16    19.86  195-10  11110
# 73  119,000  1995  2023  명륜2가             아남1  8   2     84.9       4  11110
# 74  205,000  1999  2023  명륜2가             아남3  8  11   172.17     237  11110
# 75  205,000  1999  2023  명륜2가             아남3  8  11   172.17     237  11110
# 76   84,000  1999  2023   창신동              두산  8  19    59.95     232  11110
#
#      층
# 0   12
# 1   17
# 2    7
# 3   12
# 4    6
# ..  ..
# 72   7
# 73  10
# 74   3
# 75   3
# 76   1
#
# [77 rows x 11 columns]

# %%
import requests, datetime, dateutil, pandas as pd
from bs4 import BeautifulSoup

def default_text(node, text):
    if node != None:
        return node.text.strip()
    else:
        return text

item_list = ['거래금액', '건축년도', '년', '법정동', '아파트', '월', '일', '전용면적', '지번', '지역코드', '층']
data_list = []        
lawd_cds = [11140, 11170, 11200]
# lawd_cds = [11110, 11140, 11170, 11200, 11215, 11230, 11260, 11290, 11305,
#        11320, 11350, 11380, 11410, 11440, 11470, 11500, 11530, 11545,
#        11560, 11590, 11620, 11650, 11680, 11710, 11740]

start_datetime = datetime.datetime(2023, 1, 1)

while True:
    apikey = 'QjITnZtxSg5%2Bhzh%2BWR8hYLMstCDRuf1REcb5E59648Wy77%2B7z8aQBHgv95ylOhyoP31mFZWlyiqd2TrMu7HTuw%3D%3D'    
    
    date = start_datetime.strftime('%Y%m') #202301
    if date >= '202309':
        break
        
    for lawd_cd in lawd_cds:
        print('='*5, date, lawd_cd, '='*5)
        url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?LAWD_CD={lawd_cd}&DEAL_YMD={date}&serviceKey={apikey}'

        res = requests.get(url)
        textsrc = res.text

        soup = BeautifulSoup(textsrc, 'xml')
        items = soup.select('response > body > items > item') 
           
        for item in items:
            data_list.append([ default_text(item.select_one(i), '') for i in item_list]) # value를 행기준으로 맞춤, 110 X 11
        print(data_list)
        
        start_datetime = start_datetime + dateutil.relativedelta.relativedelta(months=1) #  += 1달

df = pd.DataFrame(data_list, columns=item_list)
df.to_csv('./sample/아파트매매 실거래자료.csv', index=False, encoding='cp949')
print('저장 완료')
# Out:
# ===== 202301 11140 =====
# [['21,500', '2016', '2023', '충무로5가', '충무로엘크루메크로시티2차', '1', '18', '22.75', '36-2', '11140', '5'], ['27,000', '1968', '2023', '인현동2가', '인현상가(신성아파트)', '1', '30', '52.1', '192-30', '11140', '6'], ['18,250', '1981', '2023', '장충동2가', '장충', '1', '6', '62.48', '193-29', '11140', '1'], ['145,000', '2002', '2023', '신당동', '남산타운', '1', '6', '114.88', '844', '11140', '14'], ['117,500', '2002', '2023', '신당동', '남산타운', '1', '7', '84.88', '844', '11140', '8'], ['114,500', '2011', '2023', '신당동', '청구e편한세상', '1', '9', '84.95', '852', '11140', '2'], ['89,500', '2002', '2023', '신당동', '남산타운', '1', '14', '59.94', '844', '11140', '12'], ['128,000', '2011', '2023', '신당동', '래미안하이베르', '1', '17', '117', '851', '11140', '11'], ['90,000', '2002', '2023', '신당동', '남산타운', '1', '25', '59.94', '844', '11140', '13'], ['23,000', '2021', '2023', '신당동', '약수역더시티', '1', '26', '19.06', '857', '11140', '4']]
# ===== 202301 11170 =====
# [['21,500', '2016', '2023', '충무로5가', '충무로엘크루메크로시티2차', '1', '18', '22.75', '36-2', '11140', '5'], ['27,000', '1968', '2023', '인현동2가', '인현상가(신성아파트)', '1', '30', '52.1', '192-30', '11140', '6'], ['18,250', '1981', '2023', '장충동2가', '장충', '1', '6', '62.48', '193-29', '11140', '1'], ['145,000', '2002', '2023', '신당동', '남산타운', '1', '6', '114.88', '844', '11140', '14'], ['117,500', '2002', '2023', '신당동', '남산타운', '1', '7', '84.88', '844', '11140', '8'], ['114,500', '2011', '2023', '신당동', '청구e편한세상', '1', '9', '84.95', '852', '11140', '2'], ['89,500', '2002', '2023', '신당동', '남산타운', '1', '14', '59.94', '844', '11140', '12'], ['128,000', '2011', '2023', '신당동', '래미안하이베르', '1', '17', '117', '851', '11140', '11'], ['90,000', '2002', '2023', '신당동', '남산타운', '1', '25', '59.94', '844', '11140', '13'], ['23,000', '2021', '2023', '신당동', '약수역더시티', '1', '26', '19.06', '857', '11140', '4'], ['105,000', '1980', '2023', '후암동', '후암미주', '1', '26', '63.44', '423-1', '11170', '4'], ['85,000', '2004', '2023', '후암동', '신주에지앙', '1', '30', '106.83', '302', '11170', '4'], ['152,500', '2014', '2023', '원효로1가', '용산더프라임', '1', '14', '84.976', '41', '11170', '11'], ['90,000', '1971', '
'20', '84.89', '404', '11170', '8'], ['155,000', '2016', '2023', '하왕십리동', '센트라스', '1', '11', '84.96', '1070', '11200', '21'], ['82,500', '2009', '2023', '하왕십리동', '왕십리지웰', '1', '12', '84.957', '1064', '11200', '11'], ['108,000', '2016', '2023', '하왕십리동', '센트라스', '1', '17', '59.94', '1070', '11200', '15'], ['95,000', '2001', '2023', '하왕십리동', '한진해모로', '1', '19', '112.26', '1050', '11200', '15'], ['93,000', '2015', '2023', '하왕십리동', '텐즈힐(1단지)', '1', '22', '84.96', '1066', '11200', '19'], ['73,000', '1996', '2023', '하왕십리동', '무학현대', '1', '28', '84.675', '992', '11200', '9'], ['77,500', '2004', '2023', '하왕십리동', '왕십리풍림아이원', '1', '31', '59.936', '1061', '11200', '4'], ['67,000', '1998', '2023', '마장동', '현대', '1', '3', '59.91', '818', '11200', '14'], ['68,000', '1998', '2023', '마장동', '현대', '1', '7', '59.91', '818', '11200', '25'], ['69,000', '1998', '2023', '마장동', '현대', '1', '27', '59.94', '818', '11200', '28'], ['43,000', '1975', '2023', '회현동1가', '삼풍', '4', '17', '63.87', '146-1', '11140', '5'], ['21,500', '2016', '2023', '충무로5가', '충무로엘크루메크로시티2차', '4', '10', '22.75', '36-2', '11140', '17'], ['56,500', '1968', '2023', '인현동2가', '인현상가(신성아파트)', '4', '13', '87.44', '192-30', '11140', '6'], ['291,000', '2000', '2023', '장충동1가', '장충동라임카운티', '4', '19', '244.47', '105-1', '11140', '5'], ['46,000', '2021', '2023', '오장동', '오장동오팰리오', '4', '12', '29.48', '139-7', '11140', '9'], ['57,000', '2021', '2023', '오장동', '오장동오팰리오', '4', '14', '39.69', '139-7', '11140', '11'], ['16,500', '2020', '2023', '오장동', '오렌지카운티을지로', '4', '17', '12.43', '145-1', '11140', '8'], ['47,000', '2021', '2023', '오장동', '오장동오팰리오', '4', '19', '29.2', '139-7', '11140', '13'], ['57,000', '2021', '2023', '오장동', '오장동오팰리오', '4', '28', '39.69', '139-7', '11140', '12'], ['104,000', '2011', '2023', '신당동', '래미안하이베르', '4', '1', '84.85', '851', '11140', '2'], ['168,000', '2013', '2023', '동자동', '센트레빌아스테리움서울', '4', '17', '128.06', '45', '11170', '21'], ['143,000', '2001', '2023', '산천동', '리버힐삼성', '4', '3', '114.48', '193', '11170', '17'], ['81,000', '2001', '2023', '산천동', '한강타운', '4', '6', '59.69', '204', '11170', '3'], ['135,000', '2001', '2023', '산천동', '리버힐삼성', '4', '24', '114.48', '193', '11170', '10'], ['105,000', '2001', '2023', '산천동', '리버힐삼성', '4', '28', '59.55', '193', '11170', '14'], ['300,000' ...
# 저장 완료

# %%
import requests, time, os, json
from html import unescape

# %%
# input
client_id = 'y_xnlepsAUdkj_zKQl5J'
client_secret = 'hUv2OlgBdF'

queries = ['전주 여행', '경주 여행']
goal_page = 5

# %%
# setting
user_agent = "Mozilla/5.0 (Windows NT 10.0; WOW64) " + \
             "AppleWebKit/537.36 (KHTML, like Gecko) " + \
             "Chrome/51.0.2704.103 Safari/537.36"

headers = {"User-Agent": user_agent,
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret}

# %%
file_name = './sample/naver_kin.txt'

with open(file_name, 'w', encoding='utf-8') as f :
    f.write('query\tno\ttitle\tlink\tdescription\ttotal_text\n')

# %%
url = "https://openapi.naver.com/v1/search/kin.json?display=100&query=" + queries[0] + "&start=" + str(1)
response = requests.get(url, headers=headers)
elements = json.loads(response.text)['items']
elements[0]
# Out:
# {'title': '<b>전주여행</b> 갈곳, 전시회 추천',
#  'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=438462586&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0',
#  'description': '제가 이번달 말에 남자친구랑 <b>전주여행</b>을 가는데요. 전주한옥마을만 가기엔 그래서 갈만한 곳, 공방, 전시회같은거 있음 추천부탁드려요ㅠㅠ 안녕하세요. 질문하신 [<b>전주여행</b>] 관련 답변 드리도록 하겠습니다. 전주로 놀러가시나 봅니다... '}

# %%
def get_list(query, page):
    print('='*5, query, page, '='*5)
    url = "https://openapi.naver.com/v1/search/kin.json?display=100&query=" + query + "&start=" + str(page+1)
    response = requests.get(url, headers=headers)
    elements = json.loads(response.text)['items']

    for i, elm in enumerate(elements):
        title = elm['title'].replace("<b>", "").replace("</b>", "")
        title = unescape(title) # escape된 문자를 unescape문자로 변경
        link = elm['link']
        description = elm['description'].replace("<b>", "").replace("</b>", "")
        description = unescape(description)
        
        print([query, (page*100)+(i+1), title, link, description, title+" "+description])

        with open(file_name, 'a', encoding='utf-8') as f: # overwrite 안되도록 add할 것
            f.write( f'{query}\t{(page*100)+(i+1)}\t{title}\t{link}\t{description}\t{title+" "+description}\n')

    return

# %%
for query in queries:
    for page in range(goal_page):
        kin_list = get_list(query, page)
        time.sleep(0.5) #웹페이지 크롤링 매너 최소 6초
# Out:
# ===== 전주 여행 0 =====
# ['전주 여행', 1, '전주여행 갈곳, 전시회 추천', 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=438462586&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0', '제가 이번달 말에 남자친구랑 전주여행을 가는데요. 전주한옥마을만 가기엔 그래서 갈만한 곳, 공방, 전시회같은거 있음 추천부탁드려요ㅠㅠ 안녕하세요. 질문하신 [전주여행] 관련 답변 드리도록 하겠습니다. 전주로 놀러가시나 봅니다... ', '전주여행 갈곳, 전시회 추천 제가 이번달 말에 남자친구랑 전주여행을 가는데요. 전주한옥마을만 가기엔 그래서 갈만한 곳, 공방, 전시회같은거 있음 추천부탁드려요ㅠㅠ 안녕하세요. 질문하신 [전주여행] 관련 답변 드리도록 하겠습니다. 전주로 놀러가시나 봅니다... ']
# ['전주 여행', 2, '전주 여행', 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=457210792&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0', '... 전주 여행을 가시려하는군요! 그렇다면 전주에서 연인들이 제일 많이 찾는 곳들 추천해드리겠습니다. ▶전주한옥마을 ▶전주동물원 ▶한국도로공사수목원 ▶전주향교 ▶덕진공원... ', '전주 여행 ... 전주 여행을 가시려하는군요! 그렇다면 전주에서 연인들이 제일 많이 찾는 곳들 추천해드리겠습니다. ▶전주한옥마을 ▶전주동물원 ▶한국도로공사수목원 ▶전주향교 ▶덕진공원... ']
# ['전주 여행', 3, '전주여행!', 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=459792395&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8&section=kin.qna&rank
https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8030205&docId=419488145&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8&section=kin.qna&rank=104&search_sort=0&spq=0', '경주여행 야경 좋은곳  경주의 야간 관광명소 베스트 5 동궁과월지 월정교 신라밀레니엄파크 첨성대 황룡원 중도타워', '경주여행 야경 좋은곳 경주여행 야경 좋은곳  경주의 야간 관광명소 베스트 5 동궁과월지 월정교 신라밀레니엄파크 첨성대 황룡원 중도타워']

# %%
# !pip install openai
# Out:
# Collecting openai
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/b6/a4/dcecd835eeba1275c8a2db87f261a70c53f17a69072d153ac322123edb59/openai-1.3.8-py3-none-any.whl.metadata
#   Downloading openai-1.3.8-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\pee\anaconda3\lib\site-packages (from openai) (3.5.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/a2/65/6940eeb21dcb2953778a6895281c179efd9100463ff08cb6232bb6480da7/httpx-0.25.2-py3-none-any.whl.metadata
#   Downloading httpx-0.25.2-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\pee\anaconda3\lib\site-packages (from openai) (1.10.8)
# Requirement already satisfied: sniffio in c:\users\pee\anaconda3\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in c:\users\pee\anaconda3\lib\site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\pee\anaconda3\lib\site-packages (from openai) (4.7.1)
# Requirement already satisfied: idna>=2.8 in c:\users\pee\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in c:\users\pee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/56/ba/78b0a99c4da0ff8b0f59defa2f13ca4668189b134bd9840b6202a93d9a0f/httpcore-1.0.2-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\pee\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.3.8-py3-none-any.whl (221 kB)
#    ---------------------------------------- 0.0/221.5 kB ? eta -:--:--
#    ---------------------------------------- 221.5/221.5 kB 6.6 MB/s eta 0:00:00
# Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------------------------------- 75.0/75.0 kB 4.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    ---------------------------------------- 76.9/76.9 kB ? eta 0:00:00
# Installing collected packages: h11, distro, httpcore, httpx, openai
# Successfully installed distro-1.8.0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 openai-1.3.8

# %%
response = requests.get("https://api.coinone.co.kr/public/v2/markets/KRW")

# %%
res = response.json()
res
# Out:
# {'result': 'success',
#  'error_code': '0',
#  'server_time': 1702292997589,
#  'markets': [{'quote_currency': 'KRW',
#    'target_currency': 'STG',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ALGO',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ANKR',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'APT',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'DODO',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'WLD',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'GLM',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'NEST',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'TVK',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'FIS',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'DVI',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'APE',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BAT',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BLUR',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SSX',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ASTR',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BAND',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'KSM',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'EGG',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'PENDLE',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'FIL',
#    'price_unit': '5.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'PYTH',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'KSP',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BAL',
#    'price_unit': '5.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'QTCON',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'AOA',
#    'price_unit': '0.0001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'WEMIX',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'LDN',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'MANA',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'KSC',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'MINA',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'FRONT',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'XLM',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'IOTA',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '1000000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BTT',
#    'price_unit': '0.0001',
#    'qty_unit': '0.0001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '100000000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.0001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HPO',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'JTO',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'CVX',
#    'price_unit': '5.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'WAVES',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ABL',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'STORJ',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ONG',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ARB',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BTC',
#    'price_unit': '1000.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '1000000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10000.0', '100000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SEI',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'TWT',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SHIB',
#    'price_unit': '0.0001',
#    'qty_unit': '0.0001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '100000000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.0001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BTG',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '1000000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'IOTX',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'NEAR',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'STPT',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SUI',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ZRX',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '1000000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BCH',
#    'price_unit': '100.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '1000000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1000.0', '10000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BSV',
#    'price_unit': '50.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'JST',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SUN',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'QTUM',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '1000000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'GMT',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'CEP',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HOT',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'LINK',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'TOMOE',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'IPX',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'STX',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'IOST',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'VOLT',
#    'price_unit': '0.0001',
#    'qty_unit': '0.0001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '100000000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.0001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'AAVE',
#    'price_unit': '100.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1000.0', '10000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ATT',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'MLK',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SXP',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'LIT',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HARD',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'MASK',
#    'price_unit': '5.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'LZM',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ICX',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ADA',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BAAS',
#    'price_unit': '0.0001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ISK',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'WIKEN',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ACH',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'TIA',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BEL',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ISR',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ONT',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SPURS',
#    'price_unit': '5.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'T',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'CFX',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ASM',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ZTX',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'BIGTIME',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'THN',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'DIA',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'LQTY',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ORC',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SIX',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'GRT',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'VSYS',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'GAL',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ALPHA',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HBAR',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'DOGE',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'GAS',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ORB',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'PEPE',
#    'price_unit': '0.0001',
#    'qty_unit': '0.0001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '100000000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.0001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'WBTC',
#    'price_unit': '1000.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
# ...
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SNX',
#    'price_unit': '5.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'RNDR',
#    'price_unit': '5.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'GALA',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'SNT',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HUNT',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'FXS',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'OP',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'CRO',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'CRV',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'CRU',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'INJ',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'RPL',
#    'price_unit': '10.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '100.0', '1000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'CBK',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'KAI',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HIGH',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'REAP',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'USDT',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'IMX',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'MEV',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'DATA',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '1000000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'KAS',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'MVC',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'AMO',
#    'price_unit': '0.0001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'WNCG',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ORBS',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HANDY',
#    'price_unit': '0.01',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.1', '1.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'AMP',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'RDNT',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'ILV',
#    'price_unit': '100.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1000.0', '10000.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'LBL',
#    'price_unit': '0.001',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '0.01', '0.1'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'EDU',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'HIFI',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'NFT',
#    'price_unit': '0.0001',
#    'qty_unit': '0.0001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '100000000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.0001',
#    'order_book_units': ['0.0', '0.001', '0.01'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'TRX',
#    'price_unit': '0.1',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '1.0', '10.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']},
#   {'quote_currency': 'KRW',
#    'target_currency': 'LBR',
#    'price_unit': '1.0',
#    'qty_unit': '0.00000001',
#    'max_order_amount': '1000000000.0',
#    'max_price': '10000000000.0',
#    'max_qty': '10000000000.0',
#    'min_order_amount': '5000.0',
#    'min_price': '0.0001',
#    'min_qty': '0.00000001',
#    'order_book_units': ['0.0', '10.0', '100.0'],
#    'maintenance_status': 0,
#    'trade_status': 1,
#    'order_types': ['limit', 'market', 'stop_limit']}]}

# %%
data = res['markets']
type(data)
# Out:
# list

# %%
#for문을 돌려서 빈 리스트에 코인 이름을 담자
emp = []
for i in data :
    emp.append(i['target_currency'])

print(emp)
# Out:
# ['STG', 'ALGO', 'ANKR', 'APT', 'DODO', 'WLD', 'GLM', 'NEST', 'TVK', 'FIS', 'DVI', 'APE', 'BAT', 'BLUR', 'SSX', 'ASTR', 'BAND', 'KSM', 'EGG', 'PENDLE', 'FIL', 'PYTH', 'KSP', 'BAL', 'QTCON', 'AOA', 'WEMIX', 'LDN', 'MANA', 'KSC', 'MINA', 'FRONT', 'XLM', 'IOTA', 'BTT', 'HPO', 'JTO', 'CVX', 'WAVES', 'ABL', 'STORJ', 'ONG', 'ARB', 'BTC', 'SEI', 'TWT', 'SHIB', 'BTG', 'IOTX', 'NEAR', 'STPT', 'SUI', 'ZRX', 'BCH', 'BSV', 'JST', 'SUN', 'QTUM', 'GMT', 'CEP', 'HOT', 'LINK', 'TOMOE', 'IPX', 'STX', 'IOST', 'VOLT', 'AAVE', 'ATT', 'MLK', 'SXP', 'LIT', 'HARD', 'MASK', 'LZM', 'ICX', 'ADA', 'BAAS', 'ISK', 'WIKEN', 'ACH', 'TIA', 'BEL', 'ISR', 'ONT', 'SPURS', 'T', 'CFX', 'ASM', 'ZTX', 'BIGTIME', 'THN', 'DIA', 'LQTY', 'ORC', 'SIX', 'GRT', 'VSYS', 'GAL', 'ALPHA', 'HBAR', 'DOGE', 'GAS', 'ORB', 'PEPE', 'WBTC', 'CLBK', 'SKLAY', 'MEGA', 'MATIC', 'WE', 'AUCTION', 'UMA', 'XRP', 'KAVA', 'CTSI', 'IDV', 'BWO', 'SAND', 'ATOM', 'ARKM', 'IQ', 'KLAY', 'FORTH', 'CLV', 'SKL', 'XEC', 'CELO', 'PROM', 'HVH', 'SKU', 'ZIL', 'TARI', '1INCH', 'UOS', 'AXS', 'MEME', 'WAXL', 'EOS', 'KDAG', 'FNCY', 'BORA', 'RUNE', 'UNI', 'MNR', 'NPT', 'MNT', 'CKB', 'XTZ', 'ONIT', 'HIBS', 'ERN', 'KNC', 'MAV', 'EVER', 'PHA', 'GET', 'SML', 'TON', 'MAP', 'FLOW', 'AVAX', 'FTM', 'TEMCO', 'NEXT', 'DOT', 'HFT', 'COMP', 'SPA', 'MTL', 'AGIX', 'BNT', 'DAO', 'OGN', 'ARPA', 'GRND', 'SOL', 'BNB', 'FET', 'DRC', 'ETC', 'SEILOR', 'DYDX', 'ETH', 'FLUX', 'NEO', 'MTA', 'SUSHI', 'COS', 'DAD', 'BMP', 'PIB', 'TIDE', 'MBL', 'CYBER', 'SNX', 'RNDR', 'GALA', 'SNT', 'HUNT', 'FXS', 'OP', 'CRO', 'CRV', 'CRU', 'INJ', 'RPL', 'CBK', 'KAI', 'HIGH', 'REAP', 'USDT', 'IMX', 'MEV', 'DATA', 'KAS', 'MVC', 'AMO', 'WNCG', 'ORBS', 'HANDY', 'AMP', 'RDNT', 'ILV', 'LBL', 'EDU', 'HIFI', 'NFT', 'TRX', 'LBR']

# %%
response1 = requests.get("https://api.coinone.co.kr/public/v2/ticker_new/KRW")
res1 = response1.json()
res1
# Out:
# {'result': 'success',
#  'error_code': '0',
#  'server_time': 1702294343274,
#  'tickers': [{'quote_currency': 'krw',
#    'target_currency': 'stg',
#    'timestamp': 1702294333093,
#    'high': '849.0',
#    'low': '731.1',
#    'first': '835.0',
#    'last': '731.2',
#    'quote_volume': '95743.3483',
#    'target_volume': '129.05686301',
#    'best_asks': [{'price': '849.0', 'qty': '0.86119873'}],
#    'best_bids': [{'price': '731.5', 'qty': '41.01161995'}],
#    'id': '1702294333093001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'algo',
#    'timestamp': 1702294323200,
#    'high': '349.9',
#    'low': '240.0',
#    'first': '266.0',
#    'last': '261.0',
#    'quote_volume': '19421412.0803',
#    'target_volume': '72819.58625294',
#    'best_asks': [{'price': '263.7', 'qty': '3495.0589'}],
#    'best_bids': [{'price': '260.0', 'qty': '0.0925'}],
#    'id': '1702294323200001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ankr',
#    'timestamp': 1702294324732,
#    'high': '38.97',
#    'low': '34.0',
#    'first': '38.37',
#    'last': '35.82',
#    'quote_volume': '4473756.5087',
#    'target_volume': '124071.95383083',
#    'best_asks': [{'price': '36.54', 'qty': '38425.8339114'}],
#    'best_bids': [{'price': '35.95', 'qty': '37986.7009'}],
#    'id': '1702294324732001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'apt',
#    'timestamp': 1702294334854,
#    'high': '13490.0',
#    'low': '10570.0',
#    'first': '11100.0',
#    'last': '10850.0',
#    'quote_volume': '23391746.0879',
#    'target_volume': '2093.96337094',
#    'best_asks': [{'price': '10840.0', 'qty': '195.857'}],
#    'best_bids': [{'price': '10740.0', 'qty': '191.6793'}],
#    'id': '1702294334854001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'dodo',
#    'timestamp': 1702294341232,
#    'high': '249.9',
#    'low': '216.8',
#    'first': '249.9',
#    'last': '216.8',
#    'quote_volume': '438438.8357',
#    'target_volume': '2013.1533412',
#    'best_asks': [{'price': '216.8', 'qty': '0.8826732'}],
#    'best_bids': [{'price': '202.2', 'qty': '124.73293768'}],
#    'id': '1702294341232001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'wld',
#    'timestamp': 1702294320571,
#    'high': '3743.0',
#    'low': '3312.0',
#    'first': '3574.0',
#    'last': '3428.0',
#    'quote_volume': '143105914.166',
#    'target_volume': '40401.9197729',
#    'best_asks': [{'price': '3428.0', 'qty': '0.00006599'}],
#    'best_bids': [{'price': '3409.0', 'qty': '610.0'}],
#    'id': '1702294320571001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'glm',
#    'timestamp': 1702294328010,
#    'high': '410.8',
#    'low': '342.9',
#    'first': '357.6',
#    'last': '410.8',
#    'quote_volume': '25354689.3023',
#    'target_volume': '68192.1805441',
#    'best_asks': [{'price': '410.8', 'qty': '955.6453'}],
#    'best_bids': [{'price': '343.0', 'qty': '16.00297946'}],
#    'id': '1702294328010001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'nest',
#    'timestamp': 1702294320002,
#    'high': '9.347',
#    'low': '5.245',
#    'first': '9.347',
#    'last': '7.0',
#    'quote_volume': '726451.2086',
#    'target_volume': '119004.29245538',
#    'best_asks': [{'price': '6.999', 'qty': '2858.77644368'}],
#    'best_bids': [{'price': '5.247', 'qty': '1048.21802935'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'tvk',
#    'timestamp': 1702294339556,
#    'high': '138.1',
#    'low': '65.23',
#    'first': '65.23',
#    'last': '75.0',
#    'quote_volume': '5978941.6062',
#    'target_volume': '49274.35114791',
#    'best_asks': [{'price': '137.9', 'qty': '436.15877148'}],
#    'best_bids': [{'price': '75.0', 'qty': '35.34403839'}],
#    'id': '1702294339556001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'fis',
#    'timestamp': 1702294320000,
#    'high': '682.0',
#    'low': '666.0',
#    'first': '682.0',
#    'last': '666.0',
#    'quote_volume': '181631.5726',
#    'target_volume': '266.99820112',
#    'best_asks': [{'price': '661.9', 'qty': '3135.86653162'}],
#    'best_bids': [{'price': '492.8', 'qty': '18.5504'}],
#    'id': '1702294320000001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'dvi',
#    'timestamp': 1702294324551,
#    'high': '20.7',
#    'low': '17.2',
#    'first': '19.01',
#    'last': '18.41',
#    'quote_volume': '2218917.9202',
#    'target_volume': '116993.00003272',
#    'best_asks': [{'price': '20.42', 'qty': '5158.168'}],
#    'best_bids': [{'price': '18.41', 'qty': '3866.13642688'}],
#    'id': '1702294324551001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ape',
#    'timestamp': 1702294320003,
#    'high': '2500.0',
#    'low': '2500.0',
#    'first': '2500.0',
#    'last': '2500.0',
#    'quote_volume': '0.0',
#    'target_volume': '0.0',
#    'best_asks': [{'price': '2497.0', 'qty': '54.1056'}],
#    'best_bids': [{'price': '1949.0', 'qty': '1236.5224'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bat',
#    'timestamp': 1702294333074,
#    'high': '340.3',
#    'low': '322.1',
#    'first': '340.3',
#    'last': '323.3',
#    'quote_volume': '318263.5079',
#    'target_volume': '974.34448963',
#    'best_asks': [{'price': '325.8', 'qty': '4259.8459'}],
#    'best_bids': [{'price': '322.7', 'qty': '148.74496436'}],
#    'id': '1702294333074001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'blur',
#    'timestamp': 1702294330218,
#    'high': '729.8',
#    'low': '600.0',
#    'first': '711.0',
#    'last': '662.3',
#    'quote_volume': '37245171.423',
#    'target_volume': '55412.07749107',
#    'best_asks': [{'price': '662.7', 'qty': '3335.17801314'}],
#    'best_bids': [{'price': '662.3', 'qty': '3055.72801792'}],
#    'id': '1702294330218001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ssx',
#    'timestamp': 1702294323922,
#    'high': '30.05',
#    'low': '29.72',
#    'first': '30.05',
#    'last': '30.0',
#    'quote_volume': '1804300.957',
#    'target_volume': '60662.06807307',
#    'best_asks': [{'price': '31.16', 'qty': '2328.0073'}],
#    'best_bids': [{'price': '29.67', 'qty': '182.3256875'}],
#    'id': '1702294323922001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'astr',
#    'timestamp': 1702294322928,
#    'high': '108.2',
#    'low': '98.18',
#    'first': '101.8',
#    'last': '108.2',
#    'quote_volume': '3700196.4668',
#    'target_volume': '36937.82579552',
#    'best_asks': [{'price': '108.1', 'qty': '788.09288537'}],
#    'best_bids': [{'price': '103.7', 'qty': '13139.7347'}],
#    'id': '1702294322928001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'band',
#    'timestamp': 1702294337718,
#    'high': '2300.0',
#    'low': '2030.0',
#    'first': '2300.0',
#    'last': '2135.0',
#    'quote_volume': '1481047.7354',
#    'target_volume': '660.77887211',
#    'best_asks': [{'price': '2109.0', 'qty': '651.3564'}],
#    'best_bids': [{'price': '2076.0', 'qty': '16.004'}],
#    'id': '1702294337718001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ksm',
#    'timestamp': 1702294326110,
#    'high': '42380.0',
#    'low': '41980.0',
#    'first': '41980.0',
#    'last': '42380.0',
#    'quote_volume': '1451852.0816',
#    'target_volume': '34.27221538',
#    'best_asks': [{'price': '41490.0', 'qty': '33.4187'}],
#    'best_bids': [{'price': '40800.0', 'qty': '0.6882'}],
#    'id': '1702294326110001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'egg',
#    'timestamp': 1702294338836,
#    'high': '6.476',
#    'low': '5.615',
#    'first': '6.476',
#    'last': '5.615',
#    'quote_volume': '137445.1462',
#    'target_volume': '21758.92767665',
#    'best_asks': [{'price': '6.447', 'qty': '973.92156779'}],
#    'best_bids': [{'price': '5.003', 'qty': '8955.7799'}],
#    'id': '1702294338836001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'pendle',
#    'timestamp': 1702294342597,
#    'high': '1668.0',
#    'low': '1598.0',
#    'first': '1668.0',
#    'last': '1598.0',
#    'quote_volume': '51856.446',
#    'target_volume': '31.15330813',
#    'best_asks': [{'price': '1589.0', 'qty': '2457.45908607'}],
#    'best_bids': [{'price': '1564.0', 'qty': '19.1272'}],
#    'id': '1702294342597001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'fil',
#    'timestamp': 1702294325166,
#    'high': '7100.0',
#    'low': '6455.0',
#    'first': '6925.0',
#    'last': '6475.0',
#    'quote_volume': '1027384578.533',
#    'target_volume': '153021.28962649',
#    'best_asks': [{'price': '6475.0', 'qty': '543.64275095'}],
#    'best_bids': [{'price': '6470.0', 'qty': '5.0'}],
#    'id': '1702294325166001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'pyth',
#    'timestamp': 1702294329464,
#    'high': '719.7',
#    'low': '568.3',
#    'first': '615.0',
#    'last': '585.5',
#    'quote_volume': '186916000.5643',
#    'target_volume': '302852.87318158',
#    'best_asks': [{'price': '584.7', 'qty': '2380.0964'}],
#    'best_bids': [{'price': '583.3', 'qty': '32.7498'}],
#    'id': '1702294329464001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ksp',
#    'timestamp': 1702294337272,
#    'high': '839.4',
#    'low': '773.0',
#    'first': '808.9',
#    'last': '834.4',
#    'quote_volume': '95826909.3702',
#    'target_volume': '118759.57970643',
#    'best_asks': [{'price': '834.1', 'qty': '179.327'}],
#    'best_bids': [{'price': '802.0', 'qty': '6.84416703'}],
#    'id': '1702294337272001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bal',
#    'timestamp': 1702294342743,
#    'high': '5960.0',
#    'low': '5515.0',
#    'first': '5930.0',
#    'last': '5610.0',
#    'quote_volume': '2804380.0028',
#    'target_volume': '478.86146541',
#    'best_asks': [{'price': '5585.0', 'qty': '15.6917'}],
#    'best_bids': [{'price': '5515.0', 'qty': '0.00001207'}],
#    'id': '1702294342743001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'qtcon',
#    'timestamp': 1702294336302,
#    'high': '2.555',
#    'low': '2.114',
#    'first': '2.555',
#    'last': '2.45',
#    'quote_volume': '1874538.1519',
#    'target_volume': '809813.66688822',
#    'best_asks': [{'price': '2.473', 'qty': '17061.8377'}],
#    'best_bids': [{'price': '2.45', 'qty': '54393.3343'}],
#    'id': '1702294336302001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'aoa',
#    'timestamp': 1702294321809,
#    'high': '0.2555',
#    'low': '0.2149',
#    'first': '0.2555',
#    'last': '0.215',
#    'quote_volume': '1537277.6567',
#    'target_volume': '6367973.44800294',
#    'best_asks': [{'price': '0.2485', 'qty': '137042.82881284'}],
#    'best_bids': [{'price': '0.215', 'qty': '1873701.75309533'}],
#    'id': '1702294321809001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'wemix',
#    'timestamp': 1702294335780,
#    'high': '5150.0',
#    'low': '4765.0',
#    'first': '4970.0',
#    'last': '4918.0',
#    'quote_volume': '12644306111.8606',
#    'target_volume': '2560374.10251017',
#    'best_asks': [{'price': '4924.0', 'qty': '100.0'}],
#    'best_bids': [{'price': '4918.0', 'qty': '4.8609539'}],
#    'id': '1702294335780001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ldn',
#    'timestamp': 1702294321534,
#    'high': '3.689',
#    'low': '2.6',
#    'first': '2.945',
#    'last': '2.811',
#    'quote_volume': '112936756.4252',
#    'target_volume': '38926806.17080604',
#    'best_asks': [{'price': '2.811', 'qty': '1893798.50853571'}],
#    'best_bids': [{'price': '2.808', 'qty': '2000.0'}],
#    'id': '1702294321534001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mana',
#    'timestamp': 1702294333861,
#    'high': '748.5',
#    'low': '665.0',
#    'first': '747.4',
#    'last': '678.9',
#    'quote_volume': '115530270.11',
#    'target_volume': '162339.33515675',
#    'best_asks': [{'price': '678.9', 'qty': '123.02385815'}],
#    'best_bids': [{'price': '677.9', 'qty': '2450.98'}],
#    'id': '1702294333861001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ksc',
#    'timestamp': 1702294340300,
#    'high': '1.464',
#    'low': '0.8',
#    'first': '1.29',
#    'last': '1.08',
#    'quote_volume': '140568232.4936',
#    'target_volume': '129130853.27415824',
#    'best_asks': [{'price': '1.079', 'qty': '15137.1939'}],
#    'best_bids': [{'price': '1.071', 'qty': '5135.38748832'}],
#    'id': '1702294340300001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mina',
#    'timestamp': 1702294341932,
#    'high': '1263.0',
#    'low': '1093.0',
#    'first': '1094.0',
#    'last': '1114.0',
#    'quote_volume': '11813616.7881',
#    'target_volume': '9950.09690303',
#    'best_asks': [{'price': '1139.0', 'qty': '932.7154'}],
#    'best_bids': [{'price': '1120.0', 'qty': '1219.6582'}],
#    'id': '1702294341932001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'front',
#    'timestamp': 1702294325145,
#    'high': '495.0',
#    'low': '495.0',
#    'first': '495.0',
#    'last': '495.0',
#    'quote_volume': '9871.983',
#    'target_volume': '19.9434',
#    'best_asks': [{'price': '479.6', 'qty': '712.4026'}],
#    'best_bids': [{'price': '471.7', 'qty': '19.9416'}],
#    'id': '1702294325145001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'xlm',
#    'timestamp': 1702294320150,
#    'high': '200.0',
#    'low': '169.9',
#    'first': '182.0',
#    'last': '173.0',
#    'quote_volume': '187689314.8837',
#    'target_volume': '1042929.20592477',
#    'best_asks': [{'price': '174.1', 'qty': '32541.29238035'}],
#    'best_bids': [{'price': '172.8', 'qty': '31222.57592889'}],
#    'id': '1702294320150001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'iota',
#    'timestamp': 1702294343061,
#    'high': '396.3',
#    'low': '360.0',
#    'first': '390.5',
#    'last': '371.5',
#    'quote_volume': '95482463.051',
#    'target_volume': '254646.15092881',
#    'best_asks': [{'price': '374.9', 'qty': '1953.20466693'}],
#    'best_bids': [{'price': '371.5', 'qty': '1990.30674605'}],
#    'id': '1702294343061001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'btt',
#    'timestamp': 1702294328495,
#    'high': '0.0023',
#    'low': '0.0017',
#    'first': '0.0017',
#    'last': '0.0019',
#    'quote_volume': '448525038.95',
#    'target_volume': '232960785740.6192',
#    'best_asks': [{'price': '0.002', 'qty': '1192067908.145'}],
#    'best_bids': [{'price': '0.0019', 'qty': '7564402529.5304'}],
#    'id': '1702294328495001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'hpo',
#    'timestamp': 1702294335655,
#    'high': '118.0',
#    'low': '116.0',
#    'first': '116.0',
#    'last': '118.0',
#    'quote_volume': '2623737.3891',
#    'target_volume': '22240.70658726',
#    'best_asks': [{'price': '131.0', 'qty': '332.994'}],
#    'best_bids': [{'price': '116.0', 'qty': '51.1744098'}],
#    'id': '1702294335655001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'jto',
#    'timestamp': 1702294338199,
#    'high': '4297.0',
#    'low': '4165.0',
#    'first': '4285.0',
#    'last': '4245.0',
#    'quote_volume': '166430172.7759',
#    'target_volume': '39318.65441804',
#    'best_asks': [{'price': '4248.0', 'qty': '400.0'}],
#    'best_bids': [{'price': '4245.0', 'qty': '349.30613794'}],
#    'id': '1702294338199001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'cvx',
#    'timestamp': 1702294341232,
#    'high': '8695.0',
#    'low': '5335.0',
#    'first': '5530.0',
#    'last': '5335.0',
#    'quote_volume': '195908257.6452',
#    'target_volume': '28649.8248676',
#    'best_asks': [{'price': '5375.0', 'qty': '10.621'}],
#    'best_bids': [{'price': '5285.0', 'qty': '256.9989'}],
#    'id': '1702294341232001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'waves',
#    'timestamp': 1702294326090,
#    'high': '4899.0',
#    'low': '2700.0',
#    'first': '3949.0',
#    'last': '3123.0',
#    'quote_volume': '6452997.216',
#    'target_volume': '1935.8702931',
#    'best_asks': [{'price': '3167.0', 'qty': '0.0000676'}],
#    'best_bids': [{'price': '3125.0', 'qty': '32.0'}],
#    'id': '1702294326090001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'abl',
#    'timestamp': 1702294331568,
#    'high': '7.001',
#    'low': '7.0',
#    'first': '7.001',
#    'last': '7.0',
#    'quote_volume': '349933.2121',
#    'target_volume': '49989.52380523',
#    'best_asks': [{'price': '7.396', 'qty': '751.61193429'}],
#    'best_bids': [{'price': '6.651', 'qty': '1503.53330326'}],
#    'id': '1702294331568001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'storj',
#    'timestamp': 1702294328984,
#    'high': '982.0',
#    'low': '111.5',
#    'first': '977.0',
#    'last': '905.2',
#    'quote_volume': '15810330.6559',
#    'target_volume': '23809.64767063',
#    'best_asks': [{'price': '917.1', 'qty': '10.0664'}],
#    'best_bids': [{'price': '905.3', 'qty': '10.4004'}],
#    'id': '1702294328984001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ong',
#    'timestamp': 1702294332143,
#    'high': '536.0',
#    'low': '494.9',
#    'first': '531.3',
#    'last': '499.4',
#    'quote_volume': '8159208.942',
#    'target_volume': '15772.01002942',
#    'best_asks': [{'price': '499.6', 'qty': '2376.72202507'}],
#    'best_bids': [{'price': '499.4', 'qty': '92.0791'}],
#    'id': '1702294332143001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'arb',
#    'timestamp': 1702294320003,
#    'high': '1797.0',
#    'low': '1444.0',
#    'first': '1570.0',
#    'last': '1495.0',
#    'quote_volume': '17552222.7453',
#    'target_volume': '11341.2168448',
#    'best_asks': [{'price': '1726.0', 'qty': '30.4021'}],
#    'best_bids': [{'price': '1513.0', 'qty': '1355.3793'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'btc',
#    'timestamp': 1702294336838,
#    'high': '60107000.0',
#    'low': '57000000.0',
#    'first': '59916000.0',
#    'last': '58051000.0',
#    'quote_volume': '29923708231.37',
#    'target_volume': '511.76583659',
#    'best_asks': [{'price': '58051000.0', 'qty': '0.27911904'}],
#    'best_bids': [{'price': '58038000.0', 'qty': '0.0171747'}],
#    'id': '1702294336838001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'sei',
#    'timestamp': 1702294343199,
#    'high': '364.9',
#    'low': '315.0',
#    'first': '354.4',
#    'last': '335.7',
#    'quote_volume': '129430515.3261',
#    'target_volume': '380349.77250723',
#    'best_asks': [{'price': '336.0', 'qty': '2020.56392251'}],
#    'best_bids': [{'price': '333.0', 'qty': '0.6513015'}],
#    'id': '1702294343199001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'twt',
#    'timestamp': 1702294339705,
#    'high': '1643.0',
#    'low': '1643.0',
#    'first': '1643.0',
#    'last': '1643.0',
#    'quote_volume': '131440.0',
#    'target_volume': '80.0',
#    'best_asks': [{'price': '1654.0', 'qty': '327.9114'}],
#    'best_bids': [{'price': '1619.0', 'qty': '5.8848'}],
#    'id': '1702294339705001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'shib',
#    'timestamp': 1702294321181,
#    'high': '0.0145',
#    'low': '0.0133',
#    'first': '0.0138',
#    'last': '0.0136',
#    'quote_volume': '134840410.4975',
#    'target_volume': '9693382453.1619',
#    'best_asks': [{'price': '0.0136', 'qty': '28211388.1525'}],
#    'best_bids': [{'price': '0.0134', 'qty': '381303.945'}],
#    'id': '1702294321181001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'btg',
#    'timestamp': 1702294329751,
#    'high': '26590.0',
#    'low': '22500.0',
#    'first': '24250.0',
#    'last': '22510.0',
#    'quote_volume': '13131766.2135',
#    'target_volume': '542.92680578',
#    'best_asks': [{'price': '23500.0', 'qty': '10.0'}],
#    'best_bids': [{'price': '22640.0', 'qty': '0.9366'}],
#    'id': '1702294329751001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'iotx',
#    'timestamp': 1702294320000,
#    'high': '44.14',
#    'low': '41.49',
#    'first': '44.13',
#    'last': '41.49',
#    'quote_volume': '445739.9057',
#    'target_volume': '10410.89866198',
#    'best_asks': [{'price': '42.43', 'qty': '980.9002'}],
#    'best_bids': [{'price': '41.72', 'qty': '920.1562'}],
#    'id': '1702294320000001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'near',
#    'timestamp': 1702294342369,
#    'high': '3441.0',
#    'low': '2551.0',
#    'first': '3297.0',
#    'last': '3200.0',
#    'quote_volume': '2468560.1857',
#    'target_volume': '766.59585373',
#    'best_asks': [{'price': '3251.0', 'qty': '5.6575'}],
#    'best_bids': [{'price': '3184.0', 'qty': '8.2571'}],
#    'id': '1702294342369001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'stpt',
#    'timestamp': 1702294320000,
#    'high': '90.65',
#    'low': '82.62',
#    'first': '89.94',
#    'last': '84.42',
#    'quote_volume': '12738409.5726',
#    'target_volume': '146396.72550223',
#    'best_asks': [{'price': '85.73', 'qty': '322.3384'}],
#    'best_bids': [{'price': '84.28', 'qty': '16200.8877'}],
#    'id': '1702294320000001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'sui',
#    'timestamp': 1702294320003,
#    'high': '973.6',
#    'low': '873.7',
#    'first': '936.8',
#    'last': '899.3',
#    'quote_volume': '1200903585.8141',
#    'target_volume': '1301900.33690441',
#    'best_asks': [{'price': '901.7', 'qty': '5983.7277'}],
#    'best_bids': [{'price': '899.3', 'qty': '3000.0'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'zrx',
#    'timestamp': 1702294320000,
#    'high': '582.7',
#    'low': '486.0',
#    'first': '582.7',
#    'last': '530.1',
#    'quote_volume': '2729005.9017',
#    'target_volume': '5155.6672557',
#    'best_asks': [{'price': '614.8', 'qty': '9.418363'}],
#    'best_bids': [{'price': '530.1', 'qty': '0.06452948'}],
#    'id': '1702294320000001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bch',
#    'timestamp': 1702294340550,
#    'high': '344200.0',
#    'low': '314300.0',
#    'first': '340100.0',
#    'last': '322800.0',
#    'quote_volume': '623821380.8365',
#    'target_volume': '1900.97984259',
#    'best_asks': [{'price': '322300.0', 'qty': '3.542'}],
#    'best_bids': [{'price': '321900.0', 'qty': '4.0'}],
#    'id': '1702294340550001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bsv',
#    'timestamp': 1702294331967,
#    'high': '74400.0',
#    'low': '66050.0',
#    'first': '71750.0',
#    'last': '67950.0',
#    'quote_volume': '15142586.0968',
#    'target_volume': '216.29563545',
#    'best_asks': [{'price': '68750.0', 'qty': '12.3848'}],
#    'best_bids': [{'price': '67650.0', 'qty': '20.4265'}],
#    'id': '1702294331967001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'jst',
#    'timestamp': 1702294339141,
#    'high': '49.8',
#    'low': '49.8',
#    'first': '49.8',
#    'last': '49.8',
#    'quote_volume': '5199.9999',
#    'target_volume': '104.41767068',
#    'best_asks': [{'price': '49.8', 'qty': '17624.04551762'}],
#    'best_bids': [{'price': '44.53', 'qty': '1277.48096889'}],
#    'id': '1702294339141001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'sun',
#    'timestamp': 1702294320001,
#    'high': '9.998',
#    'low': '9.57',
#    'first': '9.57',
#    'last': '9.998',
#    'quote_volume': '54601.6913',
#    'target_volume': '5621.50511738',
#    'best_asks': [{'price': '9.998', 'qty': '0.00002714'}],
#    'best_bids': [{'price': '9.567', 'qty': '4695.7736'}],
#    'id': '1702294320001001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'qtum',
#    'timestamp': 1702294333893,
#    'high': '4703.0',
#    'low': '4000.0',
#    'first': '4665.0',
#    'last': '4347.0',
#    'quote_volume': '37528734.5845',
#    'target_volume': '8524.64384729',
#    'best_asks': [{'price': '4376.0', 'qty': '126.5637'}],
#    'best_bids': [{'price': '4332.0', 'qty': '3.0'}],
#    'id': '1702294333893001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'gmt',
#    'timestamp': 1702294329192,
#    'high': '410.1',
#    'low': '348.0',
#    'first': '410.1',
#    'last': '379.7',
#    'quote_volume': '12899695.2167',
#    'target_volume': '33136.32564095',
#    'best_asks': [{'price': '381.0', 'qty': '1931.9731'}],
#    'best_bids': [{'price': '374.0', 'qty': '3654.3004'}],
#    'id': '1702294329192001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'cep',
#    'timestamp': 1702294329332,
#    'high': '8.219',
#    'low': '7.501',
#    'first': '7.714',
#    'last': '7.501',
#    'quote_volume': '12581258.8951',
#    'target_volume': '1623548.71038247',
#    'best_asks': [{'price': '7.502', 'qty': '33972.22607599'}],
#    'best_bids': [{'price': '7.501', 'qty': '71462.26653418'}],
#    'id': '1702294329332001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'hot',
#    'timestamp': 1702294335497,
#    'high': '3.794',
#    'low': '2.507',
#    'first': '3.793',
#    'last': '2.944',
#    'quote_volume': '2919876.1555',
#    'target_volume': '996707.49773155',
#    'best_asks': [{'price': '2.988', 'qty': '25894.7212'}],
#    'best_bids': [{'price': '2.944', 'qty': '3396.73913043'}],
#    'id': '1702294335497001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'link',
#    'timestamp': 1702294337590,
#    'high': '22460.0',
#    'low': '19640.0',
#    'first': '21860.0',
#    'last': '20620.0',
#    'quote_volume': '1511397016.6067',
#    'target_volume': '71697.30729498',
#    'best_asks': [{'price': '20630.0', 'qty': '280.0'}],
#    'best_bids': [{'price': '20610.0', 'qty': '280.48520135'}],
#    'id': '1702294337590001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'tomoe',
#    'timestamp': 1702294322324,
#    'high': '1599.0',
#    'low': '1599.0',
#    'first': '1599.0',
#    'last': '1599.0',
#    'quote_volume': '0.0',
#    'target_volume': '0.0',
#    'best_asks': [{'price': '1599.0', 'qty': '11.71025654'}],
#    'best_bids': [{'price': '1352.0', 'qty': '14.7928994'}],
#    'id': '1702294322324001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ipx',
#    'timestamp': 1702294320002,
#    'high': '1.795',
#    'low': '1.001',
#    'first': '1.455',
#    'last': '1.2',
#    'quote_volume': '5626381.8116',
#    'target_volume': '4612098.54645448',
#    'best_asks': [{'price': '1.487', 'qty': '2929042.40466524'}],
#    'best_bids': [{'price': '1.21', 'qty': '50000.0'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'stx',
#    'timestamp': 1702294339551,
#    'high': '1366.0',
#    'low': '1300.0',
#    'first': '1361.0',
#    'last': '1300.0',
#    'quote_volume': '18328375.6806',
#    'target_volume': '13915.26052699',
#    'best_asks': [{'price': '1335.0', 'qty': '529.1089355'}],
#    'best_bids': [{'price': '1293.0', 'qty': '77.33952049'}],
#    'id': '1702294339551001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'iost',
#    'timestamp': 1702294326508,
#    'high': '14.78',
#    'low': '12.71',
#    'first': '13.56',
#    'last': '13.1',
#    'quote_volume': '2235782.5103',
#    'target_volume': '168556.27490769',
#    'best_asks': [{'price': '13.21', 'qty': '24202.383'}],
#    'best_bids': [{'price': '12.94', 'qty': '2288.9845'}],
#    'id': '1702294326508001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'volt',
#    'timestamp': 1702294320000,
#    'high': '0.0005',
#    'low': '0.0004',
#    'first': '0.0005',
#    'last': '0.0005',
#    'quote_volume': '6942821.1095',
#    'target_volume': '15173073420.5702',
#    'best_asks': [{'price': '0.0005', 'qty': '85493173506.1882'}],
#    'best_bids': [{'price': '0.0004', 'qty': '105789250944.2897'}],
#    'id': '1702294320000001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'aave',
#    'timestamp': 1702294320001,
#    'high': '134000.0',
#    'low': '123600.0',
#    'first': '133900.0',
#    'last': '125800.0',
#    'quote_volume': '9066858.8309',
#    'target_volume': '71.58774292',
#    'best_asks': [{'price': '126200.0', 'qty': '12.20469475'}],
#    'best_bids': [{'price': '124700.0', 'qty': '0.4009623'}],
#    'id': '1702294320001001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'att',
#    'timestamp': 1702294320002,
#    'high': '1.09',
#    'low': '0.8301',
#    'first': '1.05',
#    'last': '0.9755',
#    'quote_volume': '106918604.1311',
#    'target_volume': '111026291.00762505',
#    'best_asks': [{'price': '1.029', 'qty': '21483.45188292'}],
#    'best_bids': [{'price': '0.9755', 'qty': '197723.31385233'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mlk',
#    'timestamp': 1702294337529,
#    'high': '480.0',
#    'low': '450.0',
#    'first': '475.0',
#    'last': '450.5',
#    'quote_volume': '14205806.8625',
#    'target_volume': '30925.08515898',
#    'best_asks': [{'price': '471.9', 'qty': '11.89387206'}],
#    'best_bids': [{'price': '450.5', 'qty': '4546.92001474'}],
#    'id': '1702294337529001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'sxp',
#    'timestamp': 1702294327425,
#    'high': '550.9',
#    'low': '506.0',
#    'first': '542.9',
#    'last': '506.9',
#    'quote_volume': '7893465.0589',
#    'target_volume': '14911.25361393',
#    'best_asks': [{'price': '512.8', 'qty': '15.0'}],
#    'best_bids': [{'price': '506.8', 'qty': '46.0674'}],
#    'id': '1702294327425001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'lit',
#    'timestamp': 1702294332119,
#    'high': '1343.0',
#    'low': '1283.0',
#    'first': '1321.0',
#    'last': '1283.0',
#    'quote_volume': '1714501.434',
#    'target_volume': '1295.6003',
#    'best_asks': [{'price': '1285.0', 'qty': '88.8582'}],
#    'best_bids': [{'price': '1267.0', 'qty': '7.474'}],
#    'id': '1702294332119001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'hard',
#    'timestamp': 1702294320002,
#    'high': '263.0',
#    'low': '239.8',
#    'first': '263.0',
#    'last': '239.8',
#    'quote_volume': '271056.2368',
#    'target_volume': '1126.89264716',
#    'best_asks': [{'price': '282.3', 'qty': '38.918'}],
#    'best_bids': [{'price': '262.8', 'qty': '5130.572'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mask',
#    'timestamp': 1702294321162,
#    'high': '5165.0',
#    'low': '5155.0',
#    'first': '5160.0',
#    'last': '5165.0',
#    'quote_volume': '370433.6043',
#    'target_volume': '71.78231484',
#    'best_asks': [{'price': '5365.0', 'qty': '7.336807'}],
#    'best_bids': [{'price': '5165.0', 'qty': '20.0'}],
#    'id': '1702294321162001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'lzm',
#    'timestamp': 1702294323066,
#    'high': '59.44',
#    'low': '50.99',
#    'first': '54.08',
#    'last': '50.99',
#    'quote_volume': '5541404.768',
#    'target_volume': '103402.97701306',
#    'best_asks': [{'price': '53.99', 'qty': '1330.28631862'}],
#    'best_bids': [{'price': '51.01', 'qty': '1324.71604722'}],
#    'id': '1702294323066001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'icx',
#    'timestamp': 1702294320002,
#    'high': '382.4',
#    'low': '330.0',
#    'first': '375.7',
#    'last': '349.2',
#    'quote_volume': '10220839.9354',
#    'target_volume': '29439.22754879',
#    'best_asks': [{'price': '353.9', 'qty': '3923.8692'}],
#    'best_bids': [{'price': '349.3', 'qty': '95.0973'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ada',
#    'timestamp': 1702294320002,
#    'high': '837.3',
#    'low': '740.0',
#    'first': '810.0',
#    'last': '757.8',
#    'quote_volume': '4055529883.6178',
#    'target_volume': '5115006.14613582',
#    'best_asks': [{'price': '758.2', 'qty': '7500.0'}],
#    'best_bids': [{'price': '757.3', 'qty': '7500.0'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'baas',
#    'timestamp': 1702294333978,
#    'high': '0.9358',
#    'low': '0.705',
#    'first': '0.9358',
#    'last': '0.85',
#    'quote_volume': '14576614.6087',
#    'target_volume': '18345276.81222443',
#    'best_asks': [{'price': '0.85', 'qty': '2108340.15914001'}],
#    'best_bids': [{'price': '0.8005', 'qty': '6856.99182522'}],
#    'id': '1702294333978001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'isk',
#    'timestamp': 1702294342665,
#    'high': '274.4',
#    'low': '221.2',
#    'first': '240.0',
#    'last': '222.2',
#    'quote_volume': '16381414.1329',
#    'target_volume': '70394.63917317',
#    'best_asks': [{'price': '269.9', 'qty': '296.4849'}],
#    'best_bids': [{'price': '233.4', 'qty': '427.59382691'}],
#    'id': '1702294342665001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'wiken',
#    'timestamp': 1702294331006,
#    'high': '12.59',
#    'low': '10.61',
#    'first': '12.0',
#    'last': '11.4',
#    'quote_volume': '10280643.0701',
#    'target_volume': '890943.88821376',
#    'best_asks': [{'price': '11.78', 'qty': '6874.6948'}],
#    'best_bids': [{'price': '11.4', 'qty': '74737.63393389'}],
#    'id': '1702294331006001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ach',
#    'timestamp': 1702294321218,
#    'high': '30.09',
#    'low': '27.0',
#    'first': '29.72',
#    'last': '27.94',
#    'quote_volume': '16690669.6053',
#    'target_volume': '583065.0537433',
#    'best_asks': [{'price': '28.01', 'qty': '425984.98954556'}],
#    'best_bids': [{'price': '27.81', 'qty': '1202.32293772'}],
#    'id': '1702294321218001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'tia',
#    'timestamp': 1702294329544,
#    'high': '14700.0',
#    'low': '12400.0',
#    'first': '12890.0',
#    'last': '13950.0',
#    'quote_volume': '40220021.5045',
#    'target_volume': '2956.03268151',
#    'best_asks': [{'price': '13950.0', 'qty': '422.42665'}],
#    'best_bids': [{'price': '13900.0', 'qty': '1.0'}],
#    'id': '1702294329544001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bel',
#    'timestamp': 1702294341000,
#    'high': '1001.0',
#    'low': '950.0',
#    'first': '1001.0',
#    'last': '950.0',
#    'quote_volume': '141152.2403',
#    'target_volume': '144.55498961',
#    'best_asks': [{'price': '985.0', 'qty': '1861.44258996'}],
#    'best_bids': [{'price': '967.9', 'qty': '28.0728'}],
#    'id': '1702294341000001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'isr',
#    'timestamp': 1702294337209,
#    'high': '2.133',
#    'low': '1.5',
#    'first': '1.901',
#    'last': '1.861',
#    'quote_volume': '7025082.9967',
#    'target_volume': '3990874.97017177',
#    'best_asks': [{'price': '1.857', 'qty': '25329.63738698'}],
#    'best_bids': [{'price': '1.511', 'qty': '71829.06061158'}],
#    'id': '1702294337209001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ont',
#    'timestamp': 1702294329221,
#    'high': '370.0',
#    'low': '237.0',
#    'first': '337.9',
#    'last': '312.9',
#    'quote_volume': '7872262.1463',
#    'target_volume': '24334.30764648',
#    'best_asks': [{'price': '319.3', 'qty': '219.7812'}],
#    'best_bids': [{'price': '314.8', 'qty': '4343.1016'}],
#    'id': '1702294329221001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'spurs',
#    'timestamp': 1702294320003,
#    'high': '5235.0',
#    'low': '4200.0',
#    'first': '5055.0',
#    'last': '5055.0',
#    'quote_volume': '7580971.8939',
#    'target_volume': '1621.05478787',
#    'best_asks': [{'price': '5055.0', 'qty': '1.05569918'}],
#    'best_bids': [{'price': '4636.0', 'qty': '6.6151'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 't',
#    'timestamp': 1702294333957,
#    'high': '37.1',
#    'low': '34.7',
#    'first': '36.14',
#    'last': '37.1',
#    'quote_volume': '5070802.7997',
#    'target_volume': '143587.63313614',
#    'best_asks': [{'price': '37.1', 'qty': '766.93002534'}],
#    'best_bids': [{'price': '34.7', 'qty': '3052.31815046'}],
#    'id': '1702294333957001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'cfx',
#    'timestamp': 1702294331359,
#    'high': '389.0',
#    'low': '244.3',
#    'first': '264.7',
#    'last': '244.3',
#    'quote_volume': '2525715.4471',
#    'target_volume': '7131.20047044',
#    'best_asks': [{'price': '366.0', 'qty': '263.78466552'}],
#    'best_bids': [{'price': '236.7', 'qty': '119.2448'}],
#    'id': '1702294331359001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'asm',
#    'timestamp': 1702294334708,
#    'high': '69.98',
#    'low': '53.19',
#    'first': '67.0',
#    'last': '62.0',
#    'quote_volume': '3290407.917',
#    'target_volume': '54937.57872976',
#    'best_asks': [{'price': '62.0', 'qty': '0.00009682'}],
#    'best_bids': [{'price': '61.99', 'qty': '29.75827116'}],
#    'id': '1702294334708001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ztx',
#    'timestamp': 1702294334728,
#    'high': '51.39',
#    'low': '42.3',
#    'first': '48.35',
#    'last': '45.98',
#    'quote_volume': '27239005.71',
#    'target_volume': '596143.58040097',
#    'best_asks': [{'price': '47.22', 'qty': '507.9207'}],
#    'best_bids': [{'price': '42.64', 'qty': '33511.39054442'}],
#    'id': '1702294334728001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bigtime',
#    'timestamp': 1702294331472,
#    'high': '959.1',
#    'low': '769.0',
#    'first': '771.5',
#    'last': '907.6',
#    'quote_volume': '514925209.3431',
#    'target_volume': '583936.99991159',
#    'best_asks': [{'price': '915.6', 'qty': '2405.79208'}],
#    'best_bids': [{'price': '905.2', 'qty': '109.38137008'}],
#    'id': '1702294331472002'},
#   {'quote_currency': 'krw',
#    'target_currency': 'thn',
#    'timestamp': 1702294339553,
#    'high': '40.5',
#    'low': '38.0',
#    'first': '40.32',
#    'last': '39.68',
#    'quote_volume': '1657284358.1435',
#    'target_volume': '41749052.68585233',
#    'best_asks': [{'price': '39.71', 'qty': '3725.2893607'}],
#    'best_bids': [{'price': '39.65', 'qty': '47.26890958'}],
#    'id': '1702294339553001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'dia',
#    'timestamp': 1702294343213,
#    'high': '452.3',
#    'low': '451.6',
#    'first': '451.6',
#    'last': '451.6',
#    'quote_volume': '328784.5164',
#    'target_volume': '728.00938945',
#    'best_asks': [{'price': '458.3', 'qty': '31.02280857'}],
#    'best_bids': [{'price': '443.3', 'qty': '203.02278366'}],
#    'id': '1702294343213001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'lqty',
#    'timestamp': 1702294326032,
#    'high': '2399.0',
#    'low': '1706.0',
#    'first': '2395.0',
#    'last': '2099.0',
#    'quote_volume': '782067.9579',
#    'target_volume': '391.30141373',
#    'best_asks': [{'price': '2096.0', 'qty': '297.0308'}],
#    'best_bids': [{'price': '1832.0', 'qty': '43.66812227'}],
#    'id': '1702294326032001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'orc',
#    'timestamp': 1702294325766,
#    'high': '125.9',
#    'low': '114.0',
#    'first': '123.7',
#    'last': '120.0',
#    'quote_volume': '59813276.2786',
#    'target_volume': '500174.09475335',
#    'best_asks': [{'price': '120.8', 'qty': '423.78472385'}],
#    'best_bids': [{'price': '119.0', 'qty': '3924.36974789'}],
#    'id': '1702294325766001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'six',
#    'timestamp': 1702294320002,
#    'high': '56.31',
#    'low': '41.3',
#    'first': '56.31',
#    'last': '43.59',
#    'quote_volume': '3035188.659',
#    'target_volume': '64320.99164425',
#    'best_asks': [{'price': '53.98', 'qty': '105.53781881'}],
#    'best_bids': [{'price': '43.67', 'qty': '100082.8282'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'grt',
#    'timestamp': 1702294320003,
#    'high': '235.5',
#    'low': '195.0',
#    'first': '232.8',
#    'last': '220.4',
#    'quote_volume': '4008321.4498',
#    'target_volume': '18200.34932573',
#    'best_asks': [{'price': '224.3', 'qty': '206.14754098'}],
#    'best_bids': [{'price': '220.8', 'qty': '6178.9356'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'vsys',
#    'timestamp': 1702294339461,
#    'high': '2.002',
#    'low': '1.924',
#    'first': '2.0',
#    'last': '2.0',
#    'quote_volume': '251899.4156',
#    'target_volume': '128561.38248351',
#    'best_asks': [{'price': '2.0', 'qty': '17149.98792191'}],
#    'best_bids': [{'price': '1.9', 'qty': '5000.0'}],
#    'id': '1702294339461001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'gal',
#    'timestamp': 1702294320003,
#    'high': '2760.0',
#    'low': '2106.0',
#    'first': '2760.0',
#    'last': '2756.0',
#    'quote_volume': '2050335.2043',
#    'target_volume': '848.60258917',
#    'best_asks': [{'price': '2753.0', 'qty': '1199.69772769'}],
#    'best_bids': [{'price': '2113.0', 'qty': '14.197823'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'alpha',
#    'timestamp': 1702294327728,
#    'high': '149.1',
#    'low': '147.7',
#    'first': '147.7',
#    'last': '149.1',
#    'quote_volume': '1525034.9479',
#    'target_volume': '10228.8063738',
#    'best_asks': [{'price': '137.5', 'qty': '57.2016'}],
#    'best_bids': [{'price': '135.4', 'qty': '210.477'}],
#    'id': '1702294327728001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'hbar',
#    'timestamp': 1702294320002,
#    'high': '112.6',
#    'low': '92.51',
#    'first': '99.4',
#    'last': '93.07',
#    'quote_volume': '5625931.0794',
#    'target_volume': '54841.55003376',
#    'best_asks': [{'price': '101.6', 'qty': '238.2578'}],
#    'best_bids': [{'price': '94.62', 'qty': '474.6392'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'doge',
#    'timestamp': 1702294333954,
#    'high': '146.5',
#    'low': '132.0',
#    'first': '134.9',
#    'last': '135.4',
#    'quote_volume': '9088324755.424',
#    'target_volume': '66124110.25871618',
#    'best_asks': [{'price': '135.5', 'qty': '60000.0'}],
#    'best_bids': [{'price': '135.3', 'qty': '89940.47362615'}],
#    'id': '1702294333954001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'gas',
#    'timestamp': 1702294329957,
#    'high': '10850.0',
#    'low': '9740.0',
#    'first': '10800.0',
#    'last': '10140.0',
#    'quote_volume': '36416612.903',
#    'target_volume': '3486.98899868',
#    'best_asks': [{'price': '10140.0', 'qty': '0.79530598'}],
#    'best_bids': [{'price': '10090.0', 'qty': '22.07438924'}],
#    'id': '1702294329957001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'orb',
#    'timestamp': 1702294324780,
#    'high': '81.97',
#    'low': '45.93',
#    'first': '69.1',
#    'last': '58.5',
#    'quote_volume': '27888912.3049',
#    'target_volume': '498359.33051695',
#    'best_asks': [{'price': '58.6', 'qty': '93.8567'}],
#    'best_bids': [{'price': '58.51', 'qty': '903.28965381'}],
#    'id': '1702294324780001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'pepe',
#    'timestamp': 1702294320002,
#    'high': '0.0022',
#    'low': '0.0019',
#    'first': '0.0022',
#    'last': '0.0022',
#    'quote_volume': '13964534.2407',
#    'target_volume': '6681447082.5154',
#    'best_asks': [{'price': '0.0021', 'qty': '1120641435.979'}],
#    'best_bids': [{'price': '0.002', 'qty': '428484769.828'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'wbtc',
#    'timestamp': 1702294333274,
#    'high': '56057000.0',
#    'low': '56057000.0',
#    'first': '56057000.0',
#    'last': '56057000.0',
#    'quote_volume': '0.0',
#    'target_volume': '0.0',
#    'best_asks': [{'price': '58460000.0', 'qty': '0.0125645'}],
#    'best_bids': [{'price': '57077000.0', 'qty': '0.00008761'}],
#    'id': '1702294333274001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'clbk',
#    'timestamp': 1702294320000,
#    'high': '3.492',
#    'low': '3.1',
#    'first': '3.417',
#    'last': '3.101',
#    'quote_volume': '10546943.5849',
#    'target_volume': '3247346.87094964',
#    'best_asks': [{'price': '3.101', 'qty': '286427.67426223'}],
#    'best_bids': [{'price': '3.1', 'qty': '34339.55298709'}],
#    'id': '1702294320000001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'sklay',
#    'timestamp': 1702294334036,
#    'high': '423.9',
#    'low': '300.0',
#    'first': '406.9',
#    'last': '414.6',
#    'quote_volume': '84588927.4623',
#    'target_volume': '221837.48601816',
#    'best_asks': [{'price': '420.0', 'qty': '500.0'}],
#    'best_bids': [{'price': '410.3', 'qty': '13.3780696'}],
#    'id': '1702294334036001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mega',
#    'timestamp': 1702294326268,
#    'high': '11.22',
#    'low': '10.02',
#    'first': '11.14',
#    'last': '10.77',
#    'quote_volume': '167683433.1045',
#    'target_volume': '15724276.81372184',
#    'best_asks': [{'price': '10.77', 'qty': '3562.99232451'}],
#    'best_bids': [{'price': '10.5', 'qty': '656.0'}],
#    'id': '1702294326268001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'matic',
#    'timestamp': 1702294322348,
#    'high': '1285.0',
#    'low': '1151.0',
#    'first': '1223.0',
#    'last': '1180.0',
#    'quote_volume': '368442755.0263',
#    'target_volume': '299407.18109572',
#    'best_asks': [{'price': '1183.0', 'qty': '2388.2812'}],
#    'best_bids': [{'price': '1180.0', 'qty': '0.00000526'}],
#    'id': '1702294322348001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'we',
#    'timestamp': 1702294343258,
#    'high': '849.3',
#    'low': '550.0',
#    'first': '660.3',
#    'last': '633.7',
#    'quote_volume': '130611115.6306',
#    'target_volume': '194038.97094472',
#    'best_asks': [{'price': '634.1', 'qty': '420.37768997'}],
#    'best_bids': [{'price': '633.0', 'qty': '354.06091932'}],
#    'id': '1702294343258001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'auction',
#    'timestamp': 1702294320003,
#    'high': '23620.0',
#    'low': '22100.0',
#    'first': '22100.0',
#    'last': '22430.0',
#    'quote_volume': '340366.7782',
#    'target_volume': '14.96120249',
#    'best_asks': [{'price': '22760.0', 'qty': '0.4247'}],
#    'best_bids': [{'price': '21720.0', 'qty': '110.9397'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'uma',
#    'timestamp': 1702294320003,
#    'high': '2887.0',
#    'low': '2887.0',
#    'first': '2887.0',
#    'last': '2887.0',
#    'quote_volume': '0.0',
#    'target_volume': '0.0',
#    'best_asks': [{'price': '2797.0', 'qty': '102.2339'}],
#    'best_bids': [{'price': '2752.0', 'qty': '494.9232'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'xrp',
#    'timestamp': 1702294335685,
#    'high': '912.7',
#    'low': '849.4',
#    'first': '899.1',
#    'last': '857.5',
#    'quote_volume': '30007982709.6381',
#    'target_volume': '34352225.52020212',
#    'best_asks': [{'price': '857.7', 'qty': '24396.5881'}],
#    'best_bids': [{'price': '857.5', 'qty': '381.0334275'}],
#    'id': '1702294335685001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'kava',
#    'timestamp': 1702294329133,
#    'high': '1163.0',
#    'low': '1060.0',
#    'first': '1163.0',
#    'last': '1071.0',
#    'quote_volume': '14013033.781',
#    'target_volume': '12616.12050413',
#    'best_asks': [{'price': '1070.0', 'qty': '2357.8735824'}],
#    'best_bids': [{'price': '1065.0', 'qty': '28.8669'}],
#    'id': '1702294329133001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ctsi',
#    'timestamp': 1702294328435,
#    'high': '240.0',
#    'low': '218.4',
#    'first': '218.5',
#    'last': '218.8',
#    'quote_volume': '1357720.44',
#    'target_volume': '6019.96055886',
#    'best_asks': [{'price': '235.4', 'qty': '66.307'}],
#    'best_bids': [{'price': '218.5', 'qty': '25.12138195'}],
#    'id': '1702294328435001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'idv',
#    'timestamp': 1702294331598,
#    'high': '4.296',
#    'low': '3.7',
#    'first': '4.002',
#    'last': '4.19',
#    'quote_volume': '14160038.1824',
#    'target_volume': '3539448.78548458',
#    'best_asks': [{'price': '4.186', 'qty': '26433.5535'}],
#    'best_bids': [{'price': '3.732', 'qty': '200000.0'}],
#    'id': '1702294331598001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bwo',
#    'timestamp': 1702294320239,
#    'high': '88.91',
#    'low': '80.02',
#    'first': '85.06',
#    'last': '80.13',
#    'quote_volume': '149547485.2749',
#    'target_volume': '1781672.02168961',
#    'best_asks': [{'price': '81.75', 'qty': '800.0'}],
#    'best_bids': [{'price': '80.07', 'qty': '68.55279076'}],
#    'id': '1702294320239001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'sand',
#    'timestamp': 1702294340982,
#    'high': '787.2',
#    'low': '665.4',
#    'first': '783.4',
#    'last': '705.9',
#    'quote_volume': '665747265.8555',
#    'target_volume': '908566.62048745',
#    'best_asks': [{'price': '707.1', 'qty': '500.0'}],
#    'best_bids': [{'price': '705.0', 'qty': '500.0'}],
#    'id': '1702294340982001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'atom',
#    'timestamp': 1702294334722,
#    'high': '14620.0',
#    'low': '13500.0',
#    'first': '14000.0',
#    'last': '13740.0',
#    'quote_volume': '576916823.3337',
#    'target_volume': '41461.26521234',
#    'best_asks': [{'price': '13730.0', 'qty': '420.0'}],
#    'best_bids': [{'price': '13710.0', 'qty': '420.0'}],
#    'id': '1702294334722001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'arkm',
#    'timestamp': 1702294327010,
#    'high': '2500.0',
#    'low': '630.0',
#    'first': '691.0',
#    'last': '669.8',
#    'quote_volume': '252681900.2723',
#    'target_volume': '226491.00992863',
#    'best_asks': [{'price': '668.0', 'qty': '5866.19600909'}],
#    'best_bids': [{'price': '657.1', 'qty': '35.6364'}],
#    'id': '1702294327010001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'iq',
#    'timestamp': 1702294320002,
#    'high': '9.052',
#    'low': '7.603',
#    'first': '9.052',
#    'last': '8.052',
#    'quote_volume': '2297205.1001',
#    'target_volume': '289771.18059595',
#    'best_asks': [{'price': '9.048', 'qty': '4183.15711151'}],
#    'best_bids': [{'price': '8.5', 'qty': '9667.90980392'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'klay',
#    'timestamp': 1702294326251,
#    'high': '346.7',
#    'low': '309.8',
#    'first': '336.8',
#    'last': '341.5',
# ...
#    'timestamp': 1702294338650,
#    'high': '15.99',
#    'low': '13.65',
#    'first': '13.67',
#    'last': '13.65',
#    'quote_volume': '539313.7664',
#    'target_volume': '39425.12009758',
#    'best_asks': [{'price': '15.88', 'qty': '1242.9872'}],
#    'best_bids': [{'price': '13.65', 'qty': '6197.8021978'}],
#    'id': '1702294338650001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'bmp',
#    'timestamp': 1702294341250,
#    'high': '0.4339',
#    'low': '0.3409',
#    'first': '0.4319',
#    'last': '0.36',
#    'quote_volume': '58046738.8506',
#    'target_volume': '156415838.90500762',
#    'best_asks': [{'price': '0.3688', 'qty': '210000.0'}],
#    'best_bids': [{'price': '0.341', 'qty': '129266.979238'}],
#    'id': '1702294341250001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'pib',
#    'timestamp': 1702294337471,
#    'high': '1.05',
#    'low': '0.8',
#    'first': '0.9378',
#    'last': '0.8993',
#    'quote_volume': '138977144.497',
#    'target_volume': '152217219.3805037',
#    'best_asks': [{'price': '0.9087', 'qty': '12389.1704234'}],
#    'best_bids': [{'price': '0.8202', 'qty': '13384.59389439'}],
#    'id': '1702294337471001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'tide',
#    'timestamp': 1702294335475,
#    'high': '50.6',
#    'low': '44.1',
#    'first': '49.99',
#    'last': '44.97',
#    'quote_volume': '130153438.5704',
#    'target_volume': '2785938.45684355',
#    'best_asks': [{'price': '45.43', 'qty': '110.60684651'}],
#    'best_bids': [{'price': '44.85', 'qty': '154.91157484'}],
#    'id': '1702294335475001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mbl',
#    'timestamp': 1702294320002,
#    'high': '7.357',
#    'low': '6.932',
#    'first': '7.357',
#    'last': '6.932',
#    'quote_volume': '897967.875',
#    'target_volume': '124214.33658365',
#    'best_asks': [{'price': '7.409', 'qty': '14258.5979'}],
#    'best_bids': [{'price': '6.932', 'qty': '1864.65354708'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'cyber',
#    'timestamp': 1702294343096,
#    'high': '9425.0',
#    'low': '8600.0',
#    'first': '9130.0',
#    'last': '8600.0',
#    'quote_volume': '15002010.164',
#    'target_volume': '1648.70572518',
#    'best_asks': [{'price': '8700.0', 'qty': '5.0'}],
#    'best_bids': [{'price': '8585.0', 'qty': '437.68200349'}],
#    'id': '1702294343096001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'snx',
#    'timestamp': 1702294321057,
#    'high': '6350.0',
#    'low': '5730.0',
#    'first': '5745.0',
#    'last': '6350.0',
#    'quote_volume': '7194954.7426',
#    'target_volume': '1197.0320549',
#    'best_asks': [{'price': '6355.0', 'qty': '1987.55496689'}],
#    'best_bids': [{'price': '6270.0', 'qty': '4.7749'}],
#    'id': '1702294321057001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'rndr',
#    'timestamp': 1702294333790,
#    'high': '5820.0',
#    'low': '4895.0',
#    'first': '5820.0',
#    'last': '5750.0',
#    'quote_volume': '3950988.7523',
#    'target_volume': '718.83112787',
#    'best_asks': [{'price': '5750.0', 'qty': '0.94621432'}],
#    'best_bids': [{'price': '4898.0', 'qty': '9.1691'}],
#    'id': '1702294333790001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'gala',
#    'timestamp': 1702294320001,
#    'high': '48.8',
#    'low': '41.93',
#    'first': '44.72',
#    'last': '43.1',
#    'quote_volume': '43200589.405',
#    'target_volume': '969487.16416203',
#    'best_asks': [{'price': '43.1', 'qty': '37.02505351'}],
#    'best_bids': [{'price': '42.88', 'qty': '590.5933'}],
#    'id': '1702294320001001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'snt',
#    'timestamp': 1702294339313,
#    'high': '62.91',
#    'low': '57.57',
#    'first': '62.91',
#    'last': '59.05',
#    'quote_volume': '1254253.0769',
#    'target_volume': '20679.35850521',
#    'best_asks': [{'price': '59.8', 'qty': '18882.9059'}],
#    'best_bids': [{'price': '58.47', 'qty': '465.6638'}],
#    'id': '1702294339313001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'hunt',
#    'timestamp': 1702294320001,
#    'high': '623.9',
#    'low': '530.1',
#    'first': '563.2',
#    'last': '575.9',
#    'quote_volume': '546569.4049',
#    'target_volume': '957.38641634',
#    'best_asks': [{'price': '623.4', 'qty': '51.87693682'}],
#    'best_bids': [{'price': '530.1', 'qty': '10.35469148'}],
#    'id': '1702294320001001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'fxs',
#    'timestamp': 1702294323898,
#    'high': '12130.0',
#    'low': '12130.0',
#    'first': '12130.0',
#    'last': '12130.0',
#    'quote_volume': '80924.876',
#    'target_volume': '6.67146546',
#    'best_asks': [{'price': '14930.0', 'qty': '2.1115'}],
#    'best_bids': [{'price': '12300.0', 'qty': '3.6512'}],
#    'id': '1702294323898001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'op',
#    'timestamp': 1702294341190,
#    'high': '3201.0',
#    'low': '2840.0',
#    'first': '3020.0',
#    'last': '3201.0',
#    'quote_volume': '9185346.4775',
#    'target_volume': '3021.41243135',
#    'best_asks': [{'price': '3234.0', 'qty': '229.5096'}],
#    'best_bids': [{'price': '3177.0', 'qty': '430.856'}],
#    'id': '1702294341190001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'cro',
#    'timestamp': 1702294320001,
#    'high': '135.4',
#    'low': '128.6',
#    'first': '130.7',
#    'last': '133.9',
#    'quote_volume': '2486646.3638',
#    'target_volume': '18670.83461595',
#    'best_asks': [{'price': '143.7', 'qty': '154.32098765'}],
#    'best_bids': [{'price': '130.3', 'qty': '343.8662'}],
#    'id': '1702294320001001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'crv',
#    'timestamp': 1702294320002,
#    'high': '970.1',
#    'low': '932.6',
#    'first': '961.0',
#    'last': '932.6',
#    'quote_volume': '133453.9114',
#    'target_volume': '142.56723712',
#    'best_asks': [{'price': '951.1', 'qty': '3212.30522641'}],
#    'best_bids': [{'price': '936.1', 'qty': '10.3691'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'cru',
#    'timestamp': 1702294320001,
#    'high': '1500.0',
#    'low': '1500.0',
#    'first': '1500.0',
#    'last': '1500.0',
#    'quote_volume': '0.0',
#    'target_volume': '0.0',
#    'best_asks': [{'price': '1500.0', 'qty': '10.0'}],
#    'best_bids': [{'price': '1000.0', 'qty': '16.55946157'}],
#    'id': '1702294320001001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'inj',
#    'timestamp': 1702294320003,
#    'high': '31810.0',
#    'low': '25870.0',
#    'first': '25880.0',
#    'last': '30040.0',
#    'quote_volume': '28727758.6425',
#    'target_volume': '971.66471615',
#    'best_asks': [{'price': '31130.0', 'qty': '1.2234'}],
#    'best_bids': [{'price': '30660.0', 'qty': '44.5498'}],
#    'id': '1702294320003001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'rpl',
#    'timestamp': 1702294341019,
#    'high': '40990.0',
#    'low': '40990.0',
#    'first': '40990.0',
#    'last': '40990.0',
#    'quote_volume': '0.0',
#    'target_volume': '0.0',
#    'best_asks': [{'price': '64750.0', 'qty': '0.957'}],
#    'best_bids': [{'price': '40990.0', 'qty': '0.0357978'}],
#    'id': '1702294341019001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'cbk',
#    'timestamp': 1702294341407,
#    'high': '1729.0',
#    'low': '1051.0',
#    'first': '1510.0',
#    'last': '1350.0',
#    'quote_volume': '2136344.1877',
#    'target_volume': '1539.018299',
#    'best_asks': [{'price': '1350.0', 'qty': '60.25724307'}],
#    'best_bids': [{'price': '1116.0', 'qty': '1344.0869'}],
#    'id': '1702294341407001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'kai',
#    'timestamp': 1702294342681,
#    'high': '8.68',
#    'low': '6.518',
#    'first': '6.519',
#    'last': '6.7',
#    'quote_volume': '210771.8311',
#    'target_volume': '29634.13986564',
#    'best_asks': [{'price': '7.997', 'qty': '2264.72671467'}],
#    'best_bids': [{'price': '6.7', 'qty': '7842.49463674'}],
#    'id': '1702294342681001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'high',
#    'timestamp': 1702294328226,
#    'high': '2634.0',
#    'low': '2408.0',
#    'first': '2610.0',
#    'last': '2524.0',
#    'quote_volume': '7142973.6897',
#    'target_volume': '2789.53060485',
#    'best_asks': [{'price': '2500.0', 'qty': '23.5579'}],
#    'best_bids': [{'price': '2483.0', 'qty': '1861.90725007'}],
#    'id': '1702294328226001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'reap',
#    'timestamp': 1702294341249,
#    'high': '4.923',
#    'low': '4.153',
#    'first': '4.358',
#    'last': '4.153',
#    'quote_volume': '46280652.0306',
#    'target_volume': '10441816.63123164',
#    'best_asks': [{'price': '4.439', 'qty': '17024.93153889'}],
#    'best_bids': [{'price': '4.162', 'qty': '240269.10139355'}],
#    'id': '1702294341249001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'usdt',
#    'timestamp': 1702294338614,
#    'high': '1395.0',
#    'low': '1358.0',
#    'first': '1369.0',
#    'last': '1377.0',
#    'quote_volume': '1754158174.7217',
#    'target_volume': '1274282.68640155',
#    'best_asks': [{'price': '1377.0', 'qty': '28762.63877416'}],
#    'best_bids': [{'price': '1374.0', 'qty': '10000.0'}],
#    'id': '1702294338614001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'imx',
#    'timestamp': 1702294338786,
#    'high': '3423.0',
#    'low': '2300.0',
#    'first': '2541.0',
#    'last': '2728.0',
#    'quote_volume': '6092639.0209',
#    'target_volume': '2418.55299065',
#    'best_asks': [{'price': '3298.0', 'qty': '5.0'}],
#    'best_bids': [{'price': '2728.0', 'qty': '0.31378299'}],
#    'id': '1702294338786001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mev',
#    'timestamp': 1702294337727,
#    'high': '10.92',
#    'low': '9.113',
#    'first': '10.0',
#    'last': '9.127',
#    'quote_volume': '8934880.8441',
#    'target_volume': '892838.22335394',
#    'best_asks': [{'price': '9.97', 'qty': '2.0'}],
#    'best_bids': [{'price': '9.129', 'qty': '10000.0'}],
#    'id': '1702294337727001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'data',
#    'timestamp': 1702294329185,
#    'high': '45.98',
#    'low': '44.0',
#    'first': '45.98',
#    'last': '44.01',
#    'quote_volume': '720326.1208',
#    'target_volume': '16343.73261529',
#    'best_asks': [{'price': '45.97', 'qty': '417.1087'}],
#    'best_bids': [{'price': '44.0', 'qty': '24.94335972'}],
#    'id': '1702294329185001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'kas',
#    'timestamp': 1702294336384,
#    'high': '179.2',
#    'low': '159.8',
#    'first': '173.7',
#    'last': '167.2',
#    'quote_volume': '475345220.755',
#    'target_volume': '2809930.58053782',
#    'best_asks': [{'price': '167.1', 'qty': '619.5775'}],
#    'best_bids': [{'price': '166.8', 'qty': '8146.3059'}],
#    'id': '1702294336384001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'mvc',
#    'timestamp': 1702294339425,
#    'high': '2.689',
#    'low': '2.325',
#    'first': '2.617',
#    'last': '2.677',
#    'quote_volume': '4926143.2708',
#    'target_volume': '1948299.85510634',
#    'best_asks': [{'price': '2.677', 'qty': '674123.85335753'}],
#    'best_bids': [{'price': '2.393', 'qty': '25318.12278797'}],
#    'id': '1702294339425001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'amo',
#    'timestamp': 1702294335774,
#    'high': '0.8557',
#    'low': '0.7456',
#    'first': '0.8008',
#    'last': '0.7753',
#    'quote_volume': '6300861.5321',
#    'target_volume': '8162675.45096643',
#    'best_asks': [{'price': '0.7984', 'qty': '190314.77777239'}],
#    'best_bids': [{'price': '0.7681', 'qty': '8850.1431'}],
#    'id': '1702294335774001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'wncg',
#    'timestamp': 1702294339617,
#    'high': '139.9',
#    'low': '122.3',
#    'first': '133.4',
#    'last': '139.9',
#    'quote_volume': '1190776.9472',
#    'target_volume': '8906.1544915',
#    'best_asks': [{'price': '139.9', 'qty': '533.4411882'}],
#    'best_bids': [{'price': '125.5', 'qty': '357.018'}],
#    'id': '1702294339617001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'orbs',
#    'timestamp': 1702294341798,
#    'high': '62.15',
#    'low': '56.17',
#    'first': '60.94',
#    'last': '57.8',
#    'quote_volume': '9108644.9064',
#    'target_volume': '157189.25983118',
#    'best_asks': [{'price': '61.93', 'qty': '399.2933'}],
#    'best_bids': [{'price': '57.81', 'qty': '224.22603701'}],
#    'id': '1702294341798001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'handy',
#    'timestamp': 1702294342808,
#    'high': '19.5',
#    'low': '4.304',
#    'first': '14.83',
#    'last': '8.4',
#    'quote_volume': '2973056550.4028',
#    'target_volume': '325925935.86709859',
#    'best_asks': [{'price': '8.608', 'qty': '51193.34896236'}],
#    'best_bids': [{'price': '8.357', 'qty': '24927.60560009'}],
#    'id': '1702294342808001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'amp',
#    'timestamp': 1702294342490,
#    'high': '5.42',
#    'low': '3.875',
#    'first': '5.42',
#    'last': '5.395',
#    'quote_volume': '4427712.4199',
#    'target_volume': '989807.85590559',
#    'best_asks': [{'price': '5.422', 'qty': '13935.8036'}],
#    'best_bids': [{'price': '3.873', 'qty': '632584.55977495'}],
#    'id': '1702294342490001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'rdnt',
#    'timestamp': 1702294322630,
#    'high': '512.7',
#    'low': '349.6',
#    'first': '383.3',
#    'last': '351.4',
#    'quote_volume': '2495338.2243',
#    'target_volume': '6572.05726188',
#    'best_asks': [{'price': '358.9', 'qty': '15.58053351'}],
#    'best_bids': [{'price': '354.5', 'qty': '3833.6161'}],
#    'id': '1702294322630001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'ilv',
#    'timestamp': 1702294322896,
#    'high': '145800.0',
#    'low': '140000.0',
#    'first': '145800.0',
#    'last': '140000.0',
#    'quote_volume': '325541.269',
#    'target_volume': '2.28341126',
#    'best_asks': [{'price': '141800.0', 'qty': '0.3541'}],
#    'best_bids': [{'price': '139200.0', 'qty': '9.7624'}],
#    'id': '1702294322896001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'lbl',
#    'timestamp': 1702294320002,
#    'high': '3.656',
#    'low': '3.313',
#    'first': '3.636',
#    'last': '3.654',
#    'quote_volume': '1189279.0078',
#    'target_volume': '326934.34675961',
#    'best_asks': [{'price': '3.653', 'qty': '13396.5114'}],
#    'best_bids': [{'price': '3.314', 'qty': '13520.147'}],
#    'id': '1702294320002001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'edu',
#    'timestamp': 1702294324440,
#    'high': '980.3',
#    'low': '886.6',
#    'first': '974.9',
#    'last': '915.8',
#    'quote_volume': '3465830.7288',
#    'target_volume': '3688.8401133',
#    'best_asks': [{'price': '915.9', 'qty': '87.35451667'}],
#    'best_bids': [{'price': '915.8', 'qty': '5248.72728991'}],
#    'id': '1702294324440001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'hifi',
#    'timestamp': 1702294339320,
#    'high': '1196.0',
#    'low': '969.7',
#    'first': '1069.0',
#    'last': '1022.0',
#    'quote_volume': '2797518.8747',
#    'target_volume': '2553.80102183',
#    'best_asks': [{'price': '1188.0', 'qty': '421.9863'}],
#    'best_bids': [{'price': '981.7', 'qty': '45.6409'}],
#    'id': '1702294339320001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'nft',
#    'timestamp': 1702294322265,
#    'high': '0.0007',
#    'low': '0.0005',
#    'first': '0.0007',
#    'last': '0.0007',
#    'quote_volume': '36984477.5364',
#    'target_volume': '59982285811.4064',
#    'best_asks': [{'price': '0.0007', 'qty': '47170959623.2378'}],
#    'best_bids': [{'price': '0.0006', 'qty': '107163523062.6905'}],
#    'id': '1702294322265001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'trx',
#    'timestamp': 1702294330713,
#    'high': '148.1',
#    'low': '139.0',
#    'first': '146.8',
#    'last': '145.5',
#    'quote_volume': '3221995093.4011',
#    'target_volume': '22103035.21125995',
#    'best_asks': [{'price': '145.3', 'qty': '67000.0'}],
#    'best_bids': [{'price': '145.1', 'qty': '95405.0509'}],
#    'id': '1702294330713001'},
#   {'quote_currency': 'krw',
#    'target_currency': 'lbr',
#    'timestamp': 1702294322854,
#    'high': '2397.0',
#    'low': '2397.0',
#    'first': '2397.0',
#    'last': '2397.0',
#    'quote_volume': '6004.2109',
#    'target_volume': '2.50488566',
#    'best_asks': [{'price': '2397.0', 'qty': '149.64620834'}],
#    'best_bids': [{'price': '1703.0', 'qty': '3.22314854'}],
#    'id': '1702294322854001'}]}

# %%
data1 = res1['tickers']
empty = []

# %%
name, high, low, first, last = [], [], [], [], []

for i in data1 :
    name.append(i['target_currency'])
    high.append(i['high'])
    low.append(i['low'])
    first.append(i['first'])
    last.append(i['last'])
# Out:
# ['stg', 'algo', 'ankr', 'apt', 'dodo', 'wld', 'glm', 'nest', 'tvk', 'fis', 'dvi', 'ape', 'bat', 'blur', 'ssx', 'astr', 'band', 'ksm', 'egg', 'pendle', 'fil', 'pyth', 'ksp', 'bal', 'qtcon', 'aoa', 'wemix', 'ldn', 'mana', 'ksc', 'mina', 'front', 'xlm', 'iota', 'btt', 'hpo', 'jto', 'cvx', 'waves', 'abl', 'storj', 'ong', 'arb', 'btc', 'sei', 'twt', 'shib', 'btg', 'iotx', 'near', 'stpt', 'sui', 'zrx', 'bch', 'bsv', 'jst', 'sun', 'qtum', 'gmt', 'cep', 'hot', 'link', 'tomoe', 'ipx', 'stx', 'iost', 'volt', 'aave', 'att', 'mlk', 'sxp', 'lit', 'hard', 'mask', 'lzm', 'icx', 'ada', 'baas', 'isk', 'wiken', 'ach', 'tia', 'bel', 'isr', 'ont', 'spurs', 't', 'cfx', 'asm', 'ztx', 'bigtime', 'thn', 'dia', 'lqty', 'orc', 'six', 'grt', 'vsys', 'gal', 'alpha', 'hbar', 'doge', 'gas', 'orb', 'pepe', 'wbtc', 'clbk', 'sklay', 'mega', 'matic', 'we', 'auction', 'uma', 'xrp', 'kava', 'ctsi', 'idv', 'bwo', 'sand', 'atom', 'arkm', 'iq', 'klay', 'forth', 'clv', 'skl', 'xec', 'celo', 'prom', 'hvh', 'sku', 'zil', 'tari', '1inch', 'uos', 'axs', 'meme', 'waxl', 'eos', 'kdag', 'fncy', 'bora', 'rune', 'uni', 'mnr', 'npt', 'mnt', 'ckb', 'xtz', 'onit', 'hibs', 'ern', 'knc', 'mav', 'ever', 'pha', 'get', 'sml', 'ton', 'map', 'flow', 'avax', 'ftm', 'temco', 'next', 'dot', 'hft', 'comp', 'spa', 'mtl', 'agix', 'bnt', 'dao', 'ogn', 'arpa', 'grnd', 'sol', 'bnb', 'fet', 'drc', 'etc', 'seilor', 'dydx', 'eth', 'flux', 'neo', 'mta', 'sushi', 'cos', 'dad', 'bmp', 'pib', 'tide', 'mbl', 'cyber', 'snx', 'rndr', 'gala', 'snt', 'hunt', 'fxs', 'op', 'cro', 'crv', 'cru', 'inj', 'rpl', 'cbk', 'kai', 'high', 'reap', 'usdt', 'imx', 'mev', 'data', 'kas', 'mvc', 'amo', 'wncg', 'orbs', 'handy', 'amp', 'rdnt', 'ilv', 'lbl', 'edu', 'hifi', 'nft', 'trx', 'lbr']

# %%
df = pd.DataFrame({
    '이름' : name,
    '시가' : first,
    '고가' : high,
    '저가' : low,
    '종가' : last,
})

df
# Out:
#        이름       시가       고가       저가       종가
# 0     stg    835.0    849.0    731.1    731.2
# 1    algo    266.0    349.9    240.0    261.0
# 2    ankr    38.37    38.97     34.0    35.82
# 3     apt  11100.0  13490.0  10570.0  10850.0
# 4    dodo    249.9    249.9    216.8    216.8
# ..    ...      ...      ...      ...      ...
# 225   edu    974.9    980.3    886.6    915.8
# 226  hifi   1069.0   1196.0    969.7   1022.0
# 227   nft   0.0007   0.0007   0.0005   0.0007
# 228   trx    146.8    148.1    139.0    145.5
# 229   lbr   2397.0   2397.0   2397.0   2397.0
#
# [230 rows x 5 columns]

# %%
list1 = []

for i in data1 :
    temp = []
    temp.append(i['target_currency'])
    temp.append(i['high'])
    temp.append(i['low'])
    temp.append(i['first'])
    temp.append(i['last'])
    list1.append(temp)

list1

df = pd.DataFrame(list1, columns = ['이름','고가','저가','시가','종가'])
df
# Out:
#        이름       고가       저가       시가       종가
# 0     stg    849.0    731.1    835.0    731.2
# 1    algo    349.9    240.0    266.0    261.0
# 2    ankr    38.97     34.0    38.37    35.82
# 3     apt  13490.0  10570.0  11100.0  10850.0
# 4    dodo    249.9    216.8    249.9    216.8
# ..    ...      ...      ...      ...      ...
# 225   edu    980.3    886.6    974.9    915.8
# 226  hifi   1196.0    969.7   1069.0   1022.0
# 227   nft   0.0007   0.0005   0.0007   0.0007
# 228   trx    148.1    139.0    146.8    145.5
# 229   lbr   2397.0   2397.0   2397.0   2397.0
#
# [230 rows x 5 columns]

# %%
url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5"

# %%
import requests
from bs4 import BeautifulSoup

response2 = requests.get(url)
soup = BeautifulSoup(response2.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="인공지능 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'인공지능'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'인공지능'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>인공지능 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_231207.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_231207.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; var g_er_image, g_er_count = 0 ; function g_er (msg) { if (g_er_count++ > 0) return ; g_er_image = new Image() ; g_er_image.src = "http://er.search.naver.com/er?f="+g_tab+"&w="+g_stab+"&q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&u="+encodeURIComponent(document.location)+"&m="+encodeURIComponent(msg) ; } function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=d ...
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl && _elAdIndLayerPl.visible()) {
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elAdIndLayerPl = _elDscNcautionPl.next().next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         _elAdIndLayerPl.hide();
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <script>
#     (function () {
#       var defaultFavicon = "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png";
#       naver.common.imageLazyLoader.onError(
#               naver.common.LazySrc.Handler.create({
#                 "power-link-favicon-error": function ($img) {
#                   $img.attr("src", defaultFavicon);
#                 }
#               })
#       );
#     })();
#   </script>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/231206/css/nx_powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="sc_new ad_section section _pl_section bg_type_v2">
# <div class="api_subject_bx">
# <div class="mod_title_area">
# <div class="title_wrap">
# <h2 class="title">파워링크</h2>
# <span class="sub">
# <span class="title_text">
# <em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">인공지능</strong>
# <em class="dsc_ncaution_quotation">’</em>관련 광고입니다.
#             </span>
# </span>
# <a class="api_ad_link" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" role="button">
# <i class="spnew api_ico_alert">이 광고가 표시된 이유</i>
# </a>
# </div>
# <div class="title_sub">
# <a class="sub_link" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ly_api_info" style="display: none;">
# <p class="dsc">광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다.</p>
# <div class="btn_area">
# <a class="link" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a>
# </div>
# <button class="btn_close" onclick="adInfoHidePl();" type="button">
# <i class="spnew ico_close">정보확인 레이어 닫기</i>
# </button>
# </div>
# </div>
# <div class="nad_area" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=if-...">
# <ul class="lst_type">
# <li class="lst type_more type_subtitle ext_link type_img" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=2eTaaWYw9AgAU3s3j9R5Dv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d='+urlencode('https://w.assist.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMjAyMDhfMjA1/MDAxNjQ0MzE3NjM5MDEw.aSlyjpom1BhidyAUuiQm7qPQS-4zGwO5UlONDrOy2NYg.z23zWsoESGLM9b5XNGm-ymLkbdfZJhw7NDrBwraSuscg.JPEG/2470191-2e9db128-aa8f-40d9-b30e-ac98b59c7b97.jpg?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=Sp0uFxAWK3b9m9BFGodprv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d='+urlencode('https://w.assist.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Sp0uFxAWK3b9m9BFGodprv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d='+urlencode('https://w.assist.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">w.assist.ac.kr</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=Sp0uFxAWK3b9m9BFGodprv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d=' + urlencode('https://w.assist.ac.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">인공지능 석사과정 신입생모집</span><span class="lnk_tit">정부인가 AI 첨단대학원</span><span class="lnk_tit">현장중심 AI 최단기 석사</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=Sp0uFxAWK3b9m9BFGodprv///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d=' + urlencode('https://w.assist.ac.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">교육부승인 AI 첨단대학원 aSSIST, 핀테크/융합공학/빅데이터/전략경영 특강</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=LlLPVjBhZlj+bBFyLD75jf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d='+urlencode('https://w.assist.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">과정소개</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=s41x8uIBShkX7vM3XZnPmv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d='+urlencode('https://w.assist.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">브로슈어</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=MhlZa66EbJJt/nKH7jM8gv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d='+urlencode('https://w.assist.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">모집요강</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=0VM9ThdqzXAUQ4obsBuDg////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000276323576&amp;d='+urlencode('https://w.assist.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">1:1 상담</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_place" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=+M0yvc33/gXQJm8QsWgS+v///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=2&amp;i=nad-a001-01-000000242595666&amp;d='+urlencode('http://www.giec.or.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.giec.or.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=+M0yvc33/gXQJm8QsWgS+v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000242595666&amp;d='+urlencode('http://www.giec.or.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.giec.or.kr</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=+M0yvc33/gXQJm8QsWgS+v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000242595666&amp;d=' + urlencode('http://www.giec.or.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">직업교육 글로벌산업기술교육원</span><span class="lnk_tit">독산역에서 도보 10분</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=+M0yvc33/gXQJm8QsWgS+v///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=2&amp;i=nad-a001-01-000000242595666&amp;d=' + urlencode('http://www.giec.or.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">정부지원교육, 빅데이터, <strong class="hl">인공지능</strong>, 딥러닝, 파이썬, JAVA, 프론트, 백엔드 대학생도 직장인도 내일배움카드로 국비지원 받으며 무료 수강하자!</a>
# </div>
# <div class="place_image">
# <div class="thumb_list flicking-camera" id="place_flicking">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150901_88%2F1441057562985gsKRP_JPEG%2F116077525839767_0.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20230526_39%2F1685064009276dwbx8_JPEG%2F%25B1%25DB%25B7%25CE%25B9%25FA%25B3%25BB%25BA%25CE%25B0%25A3%25C6%25C7.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20230526_94%2F1685064072789alIvn_JPEG%2FKakaoTalk_20200909_100336786.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20171129_62%2F1511964390893NrwNc_JPEG%2Fimage.JPEG&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20171129_39%2F1511964395401RGCoK_JPEG%2Fimage.JPEG&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20201104_197%2F1604470299253EaHlR_JPEG%2FNx6NP4us_VaZnzaq139NtGWP.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20201104_99%2F1604470322963G6EUq_JPEG%2FwBanejKQ9YtAyi43hI9ezVT2.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20201104_204%2F1604470322951HOeGb_JPEG%2F5Du7DvgaoMfatC88n0UlJy5x.jpg&amp;type=a380"/>
# <span class="img_thumb_more"></span>
# </a>
# </div>
# <button class="prev_button" id="_place_prev_button" style="display:none">
# <span class="blind">이전으로 이동</span>
# </button>
# <button class="next_button" id="_place_next_button" style="display:none">
# <span class="blind">다음으로 이동</span>
# </button>
# </div>
# <a class="place_info" href="https://adcr.naver.com/adcr?x=4mJVIsipk5SWMDDpzm9lXf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.place&amp;r=2&amp;i=nad-a001-01-000000242595666&amp;d='+urlencode('http://www.giec.or.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <div class="keyword_area">
# <span class="item">CAD_CAM_CAE</span><span class="item">전산세무회계</span><span class="item">IT_소프트웨어개발</span><span class="item">평생교육</span><span class="item">기계엔지니어링</span>
# </div>
# <div class="etc_area">
# <span class="item">방문자리뷰 2</span>
# </div>
# </a>
# </div>
# </li>
# <li class="lst type_more ext_link type_img" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=QjQsx2b35yLycKXVVcbLMv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d='+urlencode('http://www.brickmate.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMzEyMDZfNDUg/MDAxNzAxODQ0NjA3NDc1.yRvIahf7QZqwjs9ERGhxdMuo4Q0zZ0qG-w1Cti2NhKog.ytMtaEdXasDt5S5R_Y_VRyp11MosW_g1IqvOilhFkpgg.JPEG/2398921-f16961b6-6f15-46f6-8cb7-5c8c00d509ea.jpg?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=nHbCO+pVLVmEAvwPje+DXf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d='+urlencode('http://www.brickmate.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.brickmate.kr%2Fassets%2Fimages%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=nHbCO+pVLVmEAvwPje+DXf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d='+urlencode('http://www.brickmate.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.brickmate.kr</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=nHbCO+pVLVmEAvwPje+DXf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d=' + urlencode('http://www.brickmate.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">앱개발 전문 제작 브릭메이트</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=nHbCO+pVLVmEAvwPje+DXf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d=' + urlencode('http://www.brickmate.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">1:1 담당 PM과 함께 기획,디자인,<strong class="hl">인공지능</strong>제작까지 한 번에 해결 합리적인 가격에 필요한 기능으로 빠르고 안전한 개발</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=94MVVDi9rwzewPK7UgPv4P///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d='+urlencode('http://www.brickmate.kr')+'&amp;u='+urlencode(this.href));" target="_blank">기술 질문 </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Ye2mihU3p6BvfbWcmCj1F////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d='+urlencode('http://www.brickmate.kr')+'&amp;u='+urlencode(this.href));" target="_blank">견적 문의</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=15DqnhCxmfyflGTtgF8V5////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d='+urlencode('http://www.brickmate.kr')+'&amp;u='+urlencode(this.href));" target="_blank">개발 상담</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=XLWS4wihEB7RMPVMeBKn6P///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000277053468&amp;d='+urlencode('http://www.brickmate.kr')+'&amp;u='+urlencode(this.href));" target="_blank">포트폴리오</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=j/zWPW2yMkiBPrjREKQzKP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000266112805&amp;d='+urlencode('http://spartacodingclub.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMjExMjJfODUg/MDAxNjY5MDc5MjcxODc3.iu1EQX9CGKF-gGww6NX__f5HgRQArWgAEvXheTiGmrAg.8yC8xGhvEx_LBco0YQJea_2OOAUcYbY_G6KGUY9nGFgg.PNG/1739570-1faa21b7-983d-416b-a53b-96a4bf54daec.png?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=7/gTfhlEulgDtiitlMjHlv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=4&amp;i=nad-a001-01-000000266112805&amp;d='+urlencode('http://spartacodingclub.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fspartacodingclub.kr%2Fcss%2Fimages%2Ffavicon.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=7/gTfhlEulgDtiitlMjHlv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000266112805&amp;d='+urlencode('http://spartacodingclub.kr')+'&amp;u='+urlencode(this.href));" target="_blank">spartacodingclub.kr</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=7/gTfhlEulgDtiitlMjHlv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000266112805&amp;d=' + urlencode('http://spartacodingclub.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">스파르타 AI 종합반 강의</span><span class="lnk_tit">누구나 큰일 낼 수 있도록</span><span class="lnk_tit">완주까지 찐~한 학습 관리</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=7/gTfhlEulgDtiitlMjHlv///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=4&amp;i=nad-a001-01-000000266112805&amp;d=' + urlencode('http://spartacodingclub.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">AI 활용 방법이 궁금하다면, 이 강의 하나로 21개 실습 예제를 체험해보세요</a>
# </div>
# </div>
# </li>
# <li class="lst type_more type_img" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=fXhT1gFANLa7SGRUUDCDYP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000277385220&amp;d='+urlencode('http://www.coding.ne.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMzEwMTZfMTc3/MDAxNjk3NDM2NDg1MTk2.I-PIOZuULO02JJD--bEZCsFqJIJJpqZAy2g0EXMlFnEg.qNSoFR1VU_bQq2aZGbeiIv_Im3KnvYy7tT4I7Zsutnsg.JPEG/1189746-de1e5e9c-7cde-4fb9-83cc-359e024323c9.jpg?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=AIij/SKBHyWvwxfJgYJ3rP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=5&amp;i=nad-a001-01-000000277385220&amp;d='+urlencode('http://www.coding.ne.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=http%3A%2F%2Fwww.coding.ne.kr%2Fcode%2Fdata%2Fbiz_img%2Fhome_favicon.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=AIij/SKBHyWvwxfJgYJ3rP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000277385220&amp;d='+urlencode('http://www.coding.ne.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.coding.ne.kr</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=AIij/SKBHyWvwxfJgYJ3rP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000277385220&amp;d=' + urlencode('http://www.coding.ne.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">인공지능이샘코딩전문학원</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=AIij/SKBHyWvwxfJgYJ3rP///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=5&amp;i=nad-a001-01-000000277385220&amp;d=' + urlencode('http://www.coding.ne.kr') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">인공지능</strong><strong class="hl">인공지능</strong> 데이터를 활용해서 머신러닝 알고리즘을 통해 학습python</a>
# </div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="5" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=cxlfw69C9sdWAroLtfrYhv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=6&amp;i=nad-a001-01-000000063147512&amp;d='+urlencode('http://www.lunasoft.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAxOTA1MTZfMjgx/MDAxNTU3OTk1NDYyNzAw.-23XQ_pcQe6Nh9m9sr4XBn2mj5F_9EYcAMigw83grQgg.6guUk93m69Hr1qcF3nx9gQ9Xk81VVuC44WQZ96w9Aagg.PNG/535230-ff1df071-35c9-4f75-b5ef-812bcc3cd10e.png?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=bprW6T/l/kukBCohceIDZf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=6&amp;i=nad-a001-01-000000063147512&amp;d='+urlencode('http://www.lunasoft.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Flunasoft.co.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=bprW6T/l/kukBCohceIDZf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000063147512&amp;d='+urlencode('http://www.lunasoft.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.lunasoft.co.kr</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=bprW6T/l/kukBCohceIDZf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000063147512&amp;d=' + urlencode('http://www.lunasoft.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">인공지능 루나소프트</span><span class="lnk_tit">상담톡 공식딜러사 루나소프트</span><span class="lnk_tit">임대형 호스팅사 완벽지원</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=bprW6T/l/kukBCohceIDZf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=6&amp;i=nad-a001-01-000000063147512&amp;d=' + urlencode('http://www.lunasoft.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">카카오 공식 딜러사. cafe24,메이크샵,고도몰 주문 및 고객정보 완벽연동.</a>
# </div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="6" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=GeJK+/9RbyUrD3G6GBNS4f///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=7&amp;i=nad-a001-01-000000276132827&amp;d='+urlencode('http://consultant.maclaurin.ai/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMjA3MjJfMjcw/MDAxNjU4NDg3OTA0ODk4.adTtEiX8ewED6rpJnHOyTUOZexTGccBCSzzYX3_EeTMg.g2sRVAJoawIhVopLhtTcjyHqxEdDm3ZUzn0QhpuaLTcg.JPEG/2598657-6256fdfc-074d-4c4e-9014-9f2befdc0b69.jpg?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=VYW22q2Z6VquQWhQTuZkI////w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=7&amp;i=nad-a001-01-000000276132827&amp;d='+urlencode('http://consultant.maclaurin.ai/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fconsultant.maclaurin.ai%2Fstatic%2Fpublish%2Fimg%2Ffavicon%2Fandroid-icon-192x192.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=VYW22q2Z6VquQWhQTuZkI////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000276132827&amp;d='+urlencode('http://consultant.maclaurin.ai/')+'&amp;u='+urlencode(this.href));" target="_blank">consultant.maclaurin.ai/</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=VYW22q2Z6VquQWhQTuZkI////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000276132827&amp;d=' + urlencode('http://consultant.maclaurin.ai/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">AI 개발 컨설팅 맥클로린</span><span class="lnk_tit"><strong class="hl">인공지능</strong> 챔피언십 우승 기업</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=VYW22q2Z6VquQWhQTuZkI////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=7&amp;i=nad-a001-01-000000276132827&amp;d=' + urlencode('http://consultant.maclaurin.ai/') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">인공지능</strong>챔피언쉽 우승기업, <strong class="hl">인공지능</strong> 개발 지원 및 컨설팅</a>
# </div>
# </div>
# </li>
# <li class="lst" num="7" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=8UNLaOQ+tzufz0aDyLzNxf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=8&amp;i=nad-a001-01-000000237617845&amp;d='+urlencode('http://www.wiseai.co.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.wiseai.co.kr%2Fimg%2Fwiseai.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=8UNLaOQ+tzufz0aDyLzNxf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000237617845&amp;d='+urlencode('http://www.wiseai.co.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">www.wiseai.co.kr/</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=8UNLaOQ+tzufz0aDyLzNxf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000237617845&amp;d=' + urlencode('http://www.wiseai.co.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">인공지능, 와이즈에이아이</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=8UNLaOQ+tzufz0aDyLzNxf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=8&amp;i=nad-a001-01-000000237617845&amp;d=' + urlencode('http://www.wiseai.co.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">병,의원 전문 AI 솔루션, 상담부터 예약까지 원스톱 서비스, <strong class="hl">인공지능</strong></a>
# </div>
# </div>
# </li>
# <li class="lst" num="8" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=JFf6mzd3/8aXsktpaYWrxP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=9&amp;i=nad-a001-01-000000238435130&amp;d='+urlencode('http://sbs.sogang.ac.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fsbs.sogang.ac.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=JFf6mzd3/8aXsktpaYWrxP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000238435130&amp;d='+urlencode('http://sbs.sogang.ac.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">sbs.sogang.ac.kr/</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=JFf6mzd3/8aXsktpaYWrxP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000238435130&amp;d=' + urlencode('http://sbs.sogang.ac.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">서강대학교 S-MBA</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=JFf6mzd3/8aXsktpaYWrxP///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=9&amp;i=nad-a001-01-000000238435130&amp;d=' + urlencode('http://sbs.sogang.ac.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">4차 산업시대에서 전문가 역량을 가진 경영자 양성을 위한 다양한 전공의 기회 제공</a>
# </div>
# </div>
# </li>
# <li class="lst" num="9" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=FXfKmWWUCN/CS3IeFgre7////w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=10&amp;i=nad-a001-01-000000260086698&amp;d='+urlencode('http://www.artnstudy.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.artnstudy.com%2Fans.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=10&amp;i=nad-a001-01-000000260086698&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# <span class="ico">
# <span class="sp_nad ico_talktalk" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 톡톡</span>
# <a class="ly_ad _tooltip" href="//talk.naver.com/intro" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.talktalk&amp;r=10&amp;i=nad-a001-01-000000260086698&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버톡톡으로 상담이 가능한 사이트입니다.</p>
# <p class="ly_ad_go"><strong>톡톡</strong> 서비스 보기<span class="sp_nad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=FXfKmWWUCN/CS3IeFgre7////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000260086698&amp;d='+urlencode('http://www.artnstudy.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.artnstudy.com</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=FXfKmWWUCN/CS3IeFgre7////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000260086698&amp;d=' + urlencode('http://www.artnstudy.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">인문교양 강의, 아트앤스터디</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=FXfKmWWUCN/CS3IeFgre7////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=10&amp;i=nad-a001-01-000000260086698&amp;d=' + urlencode('http://www.artnstudy.com') + '&amp;u='+ urlencode(this.href));" target="_blank">20년 역사의 인문학 강의 사이트에서 정통 인문학과 만나다</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="mod_more_wrap">
# <a class="group_more" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;referenceId=iUk8Xlqo1e8sssdMKnossssstQw-448225" onclick="return goOtherCR(this, 'a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u='+urlencode(this.href));" target="_blank">
# <span class="etc">더보기<i class="spnew ico_arr"></i></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     (function () {
#       var createPlaceImageConveyer = function () {
#         var prev = document.getElementById("_place_prev_button");
#         var next = document.getElementById("_place_next_button");
#         if (prev == null || next == null) {
#           return;
#         }
#         prev.style.display = "none";
#         var require = window.require.config({
#           context: "impression_neo_place_extension",
#           paths: {
#             "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#           }
#         });
#         require(["egjsConveyer"], function (egjsConveyer) {
#           var conveyer = new egjsConveyer("#place_flicking", {autoInit: false, preventClickOnDrag: true});
#
#
#           conveyer.subscribe("isReachStart", function (isReachStart) {
#             prev.style.display = isReachStart ? "none" : "block";
#           });
#
#           conveyer.subscribe("isReachEnd", function (isReachEnd) {
#             next.style.display = isReachEnd ? "none" : "block";
#           });
#           conveyer.init();
#
#           if (!conveyer.isReachEnd) {
#             next.style.display = "block";
#           }
#
#           prev.addEventListener("click", function () {
#             conveyer.scrollIntoView("start", {
#               align: "end",
#               duration: 500,
#               excludeStand: true,
#             });
#           });
#           next.addEventListener("click", function () {
#             conveyer.scrollIntoView("end", {
#               align: "start",
#               duration: 500,
#               excludeStand: true,
#             });
#           });
#         });
#       };
#       nhn.common.load_js(null, createPlaceImageConveyer, true, 150);
#     })();
#   </script>
# <section class="sc_new sp_ntotal _fe_root_ksn_kdc"><div class="api_subject_bx type_noline"><ul class="lst_total"><li class="bx"><div class="bx_snippet"><div class="_panel_wrap"><div class="snippet_inner _panel"><div class="kin_snippet"><div class="snippet_dsc"><a class="dsc_area" href="https://terms.naver.com/entry.naver?docId=1136027&amp;cid=40942&amp;categoryId=32845" onclick='goOtherCR(this,"a=ksn_kdc*t.link&amp;r=1&amp;i=88000010_00000000000000000001f865&amp;u="+urlencode(this.href))' target="_blank"><div class="api_txt_lines dsc_txt"><span class="hlt"><strong class="hl">인간의 인지·추론·판단 등의 능력을 컴퓨터로 구현하기 위한 기술</strong></span> 혹은 그 연구 분야 등을 총칭하는 용어로 사용된다.<br/>컴퓨터와 같은 기계는 인간에 비해 제어, 연산 등의 능력이 뛰어나지만, 사람이 가지고 있는 지능을 기반으로 하는 인지·추론·판단 등의 능력은 가지고 있지 않다.</div></a></div></div><div class="total_wrap"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://terms.naver.com/entry.naver?docId=1136027&amp;cid=40942&amp;categoryId=32845" href="#" onclick='tCR("a=ksn_kdc*t.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=ksn_kdc*t.kepoff" data-cr-on="a=ksn_kdc*t.kepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=ksn_kdc*t.kephome&amp;r=1&amp;i=88000010_00000000000000000001f865&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="total_tit_group"><div class="total_source"><div class="source_box"><a class="txt elss" href="https://terms.naver.com/entry.naver?docId=1136027&amp;cid=40942&amp;categoryId=32845" onclick='goOtherCR(this,"a=ksn_kdc*t.link&amp;r=1&amp;i=88000010_00000000000000000001f865&amp;u="+urlencode(this.href))' target="_blank">두산백과 두피디아 terms.naver.com</a></div></div><div class="total_tit"><a class="link_tit" href="https://terms.naver.com/entry.naver?docId=1136027&amp;cid=40942&amp;categoryId=32845" onclick='goOtherCR(this,"a=ksn_kdc*t.link&amp;r=1&amp;i=88000010_00000000000000000001f865&amp;u="+urlencode(this.href))' target="_blank"><mark>인공지능</mark><span class="badge_kindic">지식백과</span></a></div></div></div></div></div></div><div class="kin_snippet_info _info_layer_wrap"><span class="dsc"><a class="link" href="https://help.naver.com/support/alias/search/integration/intergration_90.naver" onclick='goOtherCR(this,"a=ksn_kdc*t.err&amp;r=&amp;i=&amp;u="+urlencode(this.href))'>정보오류 수정요청</a></span>
# <strong class="tit"><i class="spnew ico_kin_snippet">지식스니펫</i><a class="btn_help _trigger" href="#" onclick='tCR("a=ksn_kdc*t.iopen&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew api_ico_alert">이 정보가 표시된 이유</i></a></strong><div class="ly_api_info _content"><p class="dsc">네이버 AI 기반 분석 알고리즘을 적용하여 찾고자 하는 정보에 근접한 텍스트를 자동으로 추출하였습니다.</p><div class="btn_area"><a class="link" href="https://help.naver.com/alias/search/view/view_1.naver" onclick='goOtherCR(this,"a=ksn_kdc*t.help&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">네이버 고객센터</a></div><button class="btn_close _close" onclick='tCR("a=ksn_kdc*t.iclose&amp;r=&amp;i=&amp;u=javascript")' type="button"><i class="spnew ico_close">정보확인 레이어 닫기</i></button></div></div></li></ul></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/commonPortal/pc/Controller_231017_a.js",t=function(){var e=window.require.config({context:"search_common_modules"});e(["VideoPlayer2"],n)},n=function(){var t=window.require.config({context:"_fe_web_commonportal",paths:{Controller:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Controller"],function(e){var n,t=jQuery("._fe_root_ksn_kdc"),s=new e(t);s.on({"tab-scroll":function(e){e.isTrusted&&tCR("a=ksn_kdc.sflick&r=&i=&u=javascript")},"content-scroll":function(e){e.isTrusted},"click-infolayer-trigger-button":function(e){e.isOn},"click-snippetfold-trigger":function(e){var t=e.crlog;tCR("a="+t+"&r=&i=&u=javascript")}}),n=new naver.common.VideoPlayer2({$base:t,template:"common"}),n.on({triggerClick:function(e){var s=e.$item,t=e.$trigger,n=t.attr("data-cr-area");tCR("a="+n+"&r=&i=&u=javascript")},closeClick:function(e){var t=e.$item}})})},s=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:s,t,!0,150)})()</script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_intent_faq_231019.css" rel="stylesheet"/><section class="sc_new sp_intent_faq type_snippet _au_sp_intent_faq_with_kin _prs_exB_qaT"><div class="api_subject_bx"><div class="mod_title_area _fe_faq_tooltip"><div class="title_wrap"><h2 class="title">인공 지능 FAQ</h2><span class="sub"><a class="api_ad_link _trigger" href="javascript:;" onclick='return tCR("a=exB_qaT.info&amp;r=0&amp;i=&amp;u=javascript")' role="button"><i class="spnew api_ico_alert">이 정보가 표시된 이유</i></a></span></div><div class="ly_api_info _content"><p class="dsc">네이버 AI 기반 분석 알고리즘을 적용하여 사용자들이 많이 물어보고, 궁금해할 정보들을 자동으로 추출하였습니다.</p><div class="btn_area"><a class="link" href="https://help.naver.com/service/5626/contents/21454?lang=ko" target="_blank">네이버 고객센터</a></div><button class="btn_close _trigger" type="button"><i class="spnew ico_close">정보확인 레이어 닫기</i></button></div></div><ul class="faq_list _au_faq_list"><li class="faq_item"><a aria-expanded="false" class="question_wrap _au_question_wrap" data-query="&amp;faq_opened=" href="https://blog.naver.com/iknowiknow/221809981058" role="button" target="_blank"><i class="spnew api_ico_q">Q</i>
# <strong class="title" onclick='return tCR("a=exB_qaT*q.paa&amp;r=1&amp;i=90000003_0000000000000033A4E7B682&amp;u=javascript")'>인공지능 채용의 단점은 무엇인가요?</strong>
# <i class="spib ico_faq_fold" onclick='return tCR("a=exB_qaT*q.paafold&amp;r=1&amp;i=90000003_0000000000000033A4E7B682&amp;u=javascript")'>접기</i></a><div class="answer_wrap type_paa"><div class="user_box"><a class="profile_link" href="https://blog.naver.com/iknowiknow/221809981058" onclick='return goOtherCR(this,"a=exB_qaT*q.paaprofile&amp;r=1&amp;i=90000003_0000000000000033A4E7B682&amp;u="+urlencode(urlexpand(this.href)))' target="_blank"><span class="thumb"><i class="spib ico_web_default"></i></span>
# <span class="info_group"><span class="name">blog.naver.com</span></span></a><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=exB_qaT*q.keep&amp;r=1&amp;i=90000003_0000000000000033A4E7B682&amp;u=javascript" data-cr-on="a=exB_qaT*q.keep&amp;r=1&amp;i=90000003_0000000000000033A4E7B682&amp;u=javascript" data-url="https://blog.naver.com/iknowiknow/221809981058" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer" style="display:none;"><a class="spnew_af item item_save _keep_save" data-cr-off="a=exB_qaT*q.keepoff&amp;r=1&amp;i=90000003_0000000000000033A4E7B682&amp;u=javascript" data-cr-on="a=exB_qaT*q.keepon&amp;r=1&amp;i=90000003_0000000000000033A4E7B682&amp;u=javascript" href="#" role="button">Keep에 저장</a>
# ...
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=3kzluTQ5MPNOZEVDe36Eo////w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=2&amp;i=nad-a001-01-000000262958596&amp;d=' + urlencode('http://analytics-brochure.konantech.com') + '&amp;u='+ urlencode(this.href));" target="_blank">데이터를 분석하여 더 나은 의사결정을 도와주는 빅데이터 분석엔진입니다.</a>
# </div>
# </div>
# </li>
# <li class="lst type_biz" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=uYdOQmfuKTaAtSJ1ossZBv///w==..." onclick="return goOtherCR(this,'a=biz_nop.favicon&amp;r=13&amp;i=nad-a001-01-000000116816086&amp;d='+urlencode('http://www.ssdfactory.com/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.ssdfactory.com%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <div class="url_area">
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=uYdOQmfuKTaAtSJ1ossZBv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000116816086&amp;d='+urlencode('http://www.ssdfactory.com/')+'&amp;u='+urlencode(this.href));" target="_blank">www.ssdfactory.com/</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=uYdOQmfuKTaAtSJ1ossZBv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000116816086&amp;d=' + urlencode('http://www.ssdfactory.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">DELL워크스테이션 서버전문</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=uYdOQmfuKTaAtSJ1ossZBv///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=3&amp;i=nad-a001-01-000000116816086&amp;d=' + urlencode('http://www.ssdfactory.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">T3640 T5820 T7920 GPU HP웍스 Z2 Z4 Z6 Z8 가격비교</a>
# </div>
# </div>
# </li>
# <li class="lst type_biz" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=qUPHveBvZLVG4AhVAWRu+////w==..." onclick="return goOtherCR(this,'a=biz_nop.favicon&amp;r=14&amp;i=nad-a001-01-000000234853143&amp;d='+urlencode('https://www.etsne.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.etsne.com%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <div class="url_area">
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=qUPHveBvZLVG4AhVAWRu+////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000234853143&amp;d='+urlencode('https://www.etsne.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.etsne.com</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=qUPHveBvZLVG4AhVAWRu+////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000234853143&amp;d=' + urlencode('https://www.etsne.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">Discovery체험판 실습</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=qUPHveBvZLVG4AhVAWRu+////w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=4&amp;i=nad-a001-01-000000234853143&amp;d=' + urlencode('https://www.etsne.com') + '&amp;u='+ urlencode(this.href));" target="_blank">태성에스엔이에서 다양한 시뮬레이션 단계별 예제로 체험해보세요!</a>
# </div>
# </div>
# </li>
# <li class="lst type_biz" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=ka3XcHb2dDW3nkNALmtnCP///w==..." onclick="return goOtherCR(this,'a=biz_nop.favicon&amp;r=15&amp;i=nad-a001-01-000000271575613&amp;d='+urlencode('https://www.pulsek.com/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.pulsek.com%2Fportal%2Fresources%2Fimg%2Ffavicon_16.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <div class="url_area">
# <span class="icon_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=ka3XcHb2dDW3nkNALmtnCP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000271575613&amp;d='+urlencode('https://www.pulsek.com/')+'&amp;u='+urlencode(this.href));" target="_blank">www.pulsek.com/</a>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=ka3XcHb2dDW3nkNALmtnCP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000271575613&amp;d=' + urlencode('https://www.pulsek.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">코난 데이터 딜리버리 서비스</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=ka3XcHb2dDW3nkNALmtnCP///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=5&amp;i=nad-a001-01-000000271575613&amp;d=' + urlencode('https://www.pulsek.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">365일 24시간 AI 학습용 데이터 수집을 진행하여 차별화된 데이터 수급력!</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="mod_more_wrap">
# <a class="group_more" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;referenceId=iUk8Xlqo1e8sssdMKnossssstQw-448225" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
# <span class="etc">더보기<i class="spnew ico_arr"></i></span></a>
# </div>
# </div>
# </div>
# </div>
# <section class="sc_new sp_ntotal _sp_ntotal _prs_wbb_gen _fe_root_wbb_gen"><div class="api_subject_bx"><ul class="lst_total"><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://www.korea.kr/" href="#" onclick='tCR("a=wbb_gen.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=wbb_gen.keepoff" data-cr-on="a=wbb_gen.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=wbb_gen.kep&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://www.korea.kr/" onclick='goOtherCR(this,"a=wbb_gen*w.link&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.korea.kr%2Fimages%2Fcommon%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://www.korea.kr/" target="_blank">
# www.korea.kr</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://www.korea.kr/" onclick='goOtherCR(this,"a=wbb_gen*w.link&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">대한민국 정책브리핑</a><div class="ico_wrap"><span class="api_service_wrap _tooltip_wrap"><a aria-expanded="false" aria-haspopup="false" class="btn_open _button" href="#" role="button"><i class="spnew api_ico_nlogin">네이버로그인</i></a><span class="ly_service"><span class="ly_service_box spnew_bf"><span class="text">네이버 아이디로 로그인이 가능합니다.</span><a class="link" href="https://nid.naver.com/user2/campaign/introNaverIdLogin.nhn" target="_blank">서비스 자세히 보기<i class="spnew ico_arr"></i></a></span></span></span></div></div><div class="group_item"><ul class="list_item"><li class="item"><a href="https://www.korea.kr/briefing/pressReleaseList.do" onclick='goOtherCR(this,"a=wbb_gen*b.sublink&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">보도자료</a></li><li class="item"><a href="https://www.korea.kr/news/policyNewsList.do" onclick='goOtherCR(this,"a=wbb_gen*b.sublink&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">정책뉴스</a></li><li class="item"><a href="https://www.korea.kr/archive/govVisionList.do" onclick='goOtherCR(this,"a=wbb_gen*b.sublink&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">국정과제</a></li><li class="item"><a href="https://www.korea.kr/multi/mediaNewsList.do" onclick='goOtherCR(this,"a=wbb_gen*b.sublink&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">영상</a></li><li class="item"><a href="https://gonggam.korea.kr/" onclick='goOtherCR(this,"a=wbb_gen*b.sublink&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">K-공감</a></li><li class="item"><a href="https://www.korea.kr/briefing/speechList.do" onclick='goOtherCR(this,"a=wbb_gen*b.sublink&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">연설문</a></li></ul></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://www.korea.kr/" onclick='goOtherCR(this,"a=wbb_gen*w.link&amp;r=0&amp;i=a00000fa_5a3e1054b23ac748cc49bfa2&amp;u="+urlencode(this.href))' target="_blank">문화체육관광부 국민소통실에서 운영하는 대한민국 정부 정책뉴스포털. ... 주요뉴스 국민이 말하는 정책 오늘 하루 그만보기 닫기 이 누리집은 대한민국 공식 전자정부 누리집입니다. 공직메일 대한민국 대통령실 알림설정OFF 뉴스 멀티미디어 브리핑룸 소통채널+ 정책자료 구독&amp;참여 상세검색 범정부 공급망 컨트롤타워 구축…경제안보품목 지정·관리 정부가 공급망 안정화 정책을 심의·조정하는 공급망위원회를 설치, 구성한다. 또 경제 안보 품목을</a></div></div></div></li><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://cloud.google.com/learn/what-is-artificial-intelligence?hl=ko" href="#" onclick='tCR("a=wbb_gen.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=wbb_gen.keepoff" data-cr-on="a=wbb_gen.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=wbb_gen.kep&amp;r=1&amp;i=a00000fa_ce5d4af85ec8320842992d17&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://cloud.google.com/learn/what-is-artificial-intelligence?hl=ko" onclick='goOtherCR(this,"a=wbb_gen*w.link&amp;r=1&amp;i=a00000fa_ce5d4af85ec8320842992d17&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.gstatic.com%2Fdevrel-devsite%2Fprod%2Fv8968f24824135f40588bee141def93b2aa6ccdc7d86f8afca8cdd685d8fa94b7%2Fcloud%2Fimages%2Ffavicons%2Fonecloud%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://cloud.google.com/learn/what-is-artificial-intelligence?hl=ko" target="_blank">
# cloud.google.com<i class="divide">›</i>learn</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://cloud.google.com/learn/what-is-artificial-intelligence?hl=ko" onclick='goOtherCR(this,"a=wbb_gen*w.link&amp;r=1&amp;i=a00000fa_ce5d4af85ec8320842992d17&amp;u="+urlencode(this.href))' target="_blank"><mark>인공지능</mark>(AI)이란 무엇인가요? | Google Cloud</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://cloud.google.com/learn/what-is-artificial-intelligence?hl=ko" onclick='goOtherCR(this,"a=wbb_gen*w.link&amp;r=1&amp;i=a00000fa_ce5d4af85ec8320842992d17&amp;u="+urlencode(this.href))' target="_blank"><mark>인공지능</mark>이란 무엇인가요? <mark>인공</mark> 신경망이란 무엇인가요? AI의 이점, 사용 사례, 예시</a></div></div></div></li></ul></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/commonPortal/pc/Controller_231017_a.js",t=function(){var t=window.require.config({context:"_fe_web_commonportal",paths:{Controller:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Controller"],function(e){var t=jQuery("._fe_root_wbb_gen"),n=new e(t);n.on({"tab-scroll":function(e){e.isTrusted},"content-scroll":function(e){e.isTrusted},"click-infolayer-trigger-button":function(e){e.isOn}})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/projectChannel/pc/Controller_230920.js",t=function(){var t=window.require.config({context:"_pc_project_channel",paths:{Channel:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Channel"],function(e){var t=jQuery("._fe_root_wbb_gen");new e(t).on("moveEnd",function(){tCR("a=wbb_gen*s.nflicking&r=&i=&u=javascript")})})},n="https://ssl.pstatic.net/sstatic/au/module/requirejs/require-2.3.5.js";nhn.common.load_js(window.require?null:n,t,!0,150)})()</script><script>(function(){var e,n="_sp_ntotal",s="type_margin",t=Array.prototype.slice.call(document.querySelectorAll("section."+n));function o(e,t){return e.matches?e.matches(t):!!e.msMatchesSelector&&e.msMatchesSelector(t)}function i(e){var t=e,s=t.tagName.toLowerCase();do t=t.previousElementSibling,s=t?t.tagName.toLowerCase():"";while(t!==null&&(s==="script"||s==="link"))return t!==null&&s==="section"&&o(t,"."+n)}for(e=0;e<t.length;++e)i(t[e])&&t[e].classList.add(s)})()</script><div class="sp_feed_more _prs_btm"><a class="link_feed_more" href="?nso=&amp;page=2&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=btm.more2&amp;r=&amp;i=&amp;u="+urlencode(this.href))'>검색결과 더보기<i class="spnew ico_arr"></i></a></div><div class="sp_nfeed_more _sp_nfeed_more"> <i class="spnew ico_feed_txt">서치피드에서 더 많은 콘텐츠를 탐색해보세요!</i> <div class="feed_arr"> <i class="spnew ico_feed_arr2 ico4"></i> <i class="spnew ico_feed_arr ico3"></i> <i class="spnew ico_feed_arr2 ico2"></i> <i class="spnew ico_feed_arr ico1"></i> </div> <div class="info_area _togglor_root"> <a class="btn_info _togglor_trigger" href="#" onclick="return tCR('a=sfI_ntT.info');"> <i class="spnew api_ico_alert4">이 정보가 표시된 이유</i> </a> <div class="ly_api_info _togglor_cont"> <p class="dsc">서치피드는 검색 결과 하단에서 사용자의 관심사와 관련된 새로운 콘텐츠를 탐색하고 발견할 수 있는 피드 영역으로서, 입력된 검색어와 일치하지 않는 콘텐츠가 노출될 수 있습니다.</p> <button class="btn_close _togglor_trigger" onclick="return tCR('a=sfI_ntT.info');" type="button"><i class="spnew ico_close">정보확인 레이어 닫기</i></button> </div> </div> </div><div class="feed_wrap _feed_wrap"></div> <div class="sp_nfeed_loading _sp_nfeed_loading"> <div class="feed_loading"> <div class="api_error_wrap"> <div class="api_loading"> <div class="api_load_wrap"> <div class="api_load"> <div class="load_dot dot1"></div> <div class="load_dot dot2"></div> <div class="load_dot dot3"></div> <div class="load_dot dot4"></div> <div class="load_dot dot5"></div> <div class="load_dot dot6"></div> </div> </div> </div> </div> </div> </div> <div class="s ...

# %%
import requests, json, pandas as pd
news = soup.select_one(".group_news > span.info")
time = news.select("span.info")
title = news.select(".news_tit")

시간 = []
제목 = []
#딕셔너리 형태로 넣기
for i in range(0,len(title)):
    시간.append(time[i].text)
    제목.append(title[i].text)
    
df = pd.DataFrame({
    '제목': 제목,
    '시간': 시간
})
df

최종 = []
#리스트 형태로 넣기
for i in range(0,len(title)):
    임시 = []
    임시.append(title[i].text)
    임시.append(time[i].text)
    최종.append(임시)

df = pd.DataFrame(최종, columns = ['제목','시간'])
df
# Out:
#                                               제목      시간
# 0            “얼굴인식 수집하지마” 세계최초 인공지능 규제법, 유럽서 나왔다  21시간 전
# 1             SKT "AI 기억훈련 했더니…치매 이환율 5분의 1로 줄어"  11시간 전
# 2  "모빌리티ㆍAI 기술 대거 선봬"…LG이노텍, CES 2024 부스 2배로 키웠다  11시간 전
# 3                   IITP, ‘2023 인공지능 그랜드 챌린지’ 개최   6시간 전
# 4                  인공지능 스피커 활용 인지훈련 '두뇌톡톡' 성과 입증   7시간 전

# %%
time = soup.select(".group_news span.info")
title = soup.select(".group_news .news_tit")
title
# Out:
# [<a class="news_tit" href="https://www.mk.co.kr/article/10895184" onclick="return goOtherCR(this, 'a=nws_all*j.tit&amp;r=1&amp;i=880000BC_000000000000000005228010&amp;g=009.0005228010&amp;u='+urlencode(this.href));" target="_blank" title="“얼굴인식 수집하지마” 세계최초 인공지능 규제법, 유럽서 나왔다">“얼굴인식 수집하지마” 세계최초 <mark>인공지능</mark> 규제법, 유럽서 나왔다</a>,
#  <a class="news_tit" href="http://www.newsis.com/view/?id=NISX20231211_0002553016&amp;cID=13004&amp;pID=13100" onclick="return goOtherCR(this, 'a=nws_all*j.tit&amp;r=2&amp;i=88000127_000000000000000012258812&amp;g=003.0012258812&amp;u='+urlencode(this.href));" target="_blank" title='SKT "AI 기억훈련 했더니…치매 이환율 5분의 1로 줄어"'>SKT "AI 기억훈련 했더니…치매 이환율 5분의 1로 줄어"</a>,
#  <a class="news_tit" href="https://www.etoday.co.kr/news/view/2310531" onclick="return goOtherCR(this, 'a=nws_all*f.tit&amp;r=3&amp;i=88000393_000000000000000001905559&amp;g=5003.0001905559&amp;u='+urlencode(this.href));" target="_blank" title='"모빌리티ㆍAI 기술 대거 선봬"…LG이노텍, CES 2024 부스 2배로 키웠다'>"모빌리티ㆍAI 기술 대거 선봬"…LG이노텍, CES 2024 부스 2배로 키웠다</a>,
#  <a class="news_tit" href="http://news.heraldcorp.com/view.php?ud=20231211000522" onclick="return goOtherCR(this, 'a=nws_all*e.tit&amp;r=4&amp;i=8800010E_000000000000000002237245&amp;g=016.0002237245&amp;u='+urlencode(this.href));" target="_blank" title="IITP, ‘2023 인공지능 그랜드 챌린지’ 개최">IITP, ‘2023 <mark>인공지능</mark> 그랜드 챌린지’ 개최</a>,
#  <a class="news_tit" href="https://www.aitimes.kr/news/articleView.html?idxno=29665" onclick="return goOtherCR(this, 'a=nws_all*f.tit&amp;r=5&amp;i=88202ra5_000000000000000000011223&amp;g=5830.0000011223&amp;u='+urlencode(this.href));" target="_blank" title="인공지능 스피커 활용 인지훈련 '두뇌톡톡' 성과 입증"><mark>인공지능</mark> 스피커 활용 인지훈련 '두뇌톡톡' 성과 입증</a>]
